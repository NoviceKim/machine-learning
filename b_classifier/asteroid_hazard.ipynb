# %% [markdown]
# ### 📑 자료 분석
# - NASA에서 특정 소행성의 여러 Feature를 측정, 해당 소행성이 위험한지 아닌지를 이진 분류한 데이터 세트

# %% [markdown]
# ### Features
#
# - 명칭
# > - Neo Reference ID: 소행성의 고유 ID
# > - Name: 소행성 이름
#
# - 소행성의 절대등급
# > - Absolute Magnitude: 절대등급 (모든 천체를 동일한 거리에 놓고 봤을 때의 밝기)
#
# - 소행성의 직경
# > - Est Dia in KM(min): 최소 예상 직경 (km)
# > - Est Dia in KM(max): 최대 예상 직경 (km)
# > - Est Dia in M(min): 최소 예상 직경 (m)
# > - Est Dia in M(max): 최대 예상 직경 (m)
# > - Est Dia in Miles(min): 최소 예상 직경 (mile)
# > - Est Dia in Miles(max): 최대 예상 직경 (mile)
# > - Est Dia in Feet(min): 최소 예상 직경 (feet)
# > - Est Dia in Feet(max): 최대 예상 직경 (feet)
#
# - 소행성의 특정 행동을 관찰한 날짜 데이터
# > - Close Approach Date: 최접근 날짜. 소행성이 지구에 가장 가까워진 날짜
# > - Epoch Date Close Approach: 위의 최접근 날짜를 유닉스 시간으로 변환한 값(정수형)
#
# - 소행성의 속도
# > - Relative Velocity km per sec: 상대 속도 (km/초)
# > - Relative Velocity km per hr: 상대 속도 (km/시)
# > - Miles per hour: 상대 속도 (mile/시)
#
# - 지구와 소행성 사이의 거리
# > - Miss Dist.(Astronomical): 소행성과의 거리 (AU, 태양 - 지구 궤도까지의 거리가 1AU)
# > - Miss Dist.(lunar): 소행성과의 거리 (LD, 지구 - 달까지의 거리가 1LD)
# > - Miss Dist.(kilometers): 소행성과의 거리 (km)
# > - Miss Dist.(Astronomical): 소행성과의 거리 (AU)
#
# - 소행성의 궤도
# > - Orbiting Body: 궤도의 중심 (지구)
# > - Orbit ID: 소행성 별 궤도의 ID
# > - Orbit Determination Date: 궤도 수립 날짜
# > - Orbit Uncertainty: 궤도의 불확실성 변수. 궤도의 불안정한 정도를 수치화한 것 (범주형)
# > - Minimum Orbit Intersection: 지구와의 최소 궤도 교차 거리
# > - Jupiter Tisserand Invariant: 티세랑 불변량. 궤도 구별 시 사용
# > - Epoch Osculation: 소행성의 진동 궤도
# > - Eccentricity: 궤도 이심률. 궤도가 얼마나 원에 가까운지를 나타내는 지표
# >> 0: 완벽한 원
# >> 0 ~ 1: 타원형
# >> 1: 포물선 탈출
# >> 1 초과: 쌍곡선
# > - Semi Major Axis: 타원형 궤도의 긴반지름
# > - Inclination: 궤도의 기울기
# > - Asc Node Longitude: 승교점 경도. 기준면에서 승교점까지의 반시계방향 각도
# > - Orbital Period: 공전 주기
# > - Perihelion Distance: 페리헬리온 거리. 해당 소행성과 태양 사이의 최소 거리
# > - Perihelion Arg: 페리헬리온 인수. 태양과 거리가 가장 가까울 때의 각도
# > - Aphelion Dist: 아펠리온 거리. 해당 소행성과 태양 사이의 최대 거리
# > - Perihelion Time: 페리헬리온 시간. 다음 번에 해당 소행성이 태양과 가장 가까워지는 시간
# > - Mean Anomaly: 평균 근점 이각
# > - Mean Motion: 평균 운동. 천체의 평균 공전 속도
# > - Equinox: 천문학에서의 시간 체계

# %% [markdown]
# #### Target
# > - Hazardous: 해당 소행성의 위험 여부 (True: 위험, False: 안전)

# %% [markdown]
# ### 데이터 세트 확인

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

ah_df = pd.read_csv('./datasets/nasa.csv')

ah_df
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
ah_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neo Reference ID              4687 non-null   int64
#  1   Name                          4687 non-null   int64
#  2   Absolute Magnitude            4687 non-null   float64
#  3   Est Dia in KM(min)            4687 non-null   float64
#  4   Est Dia in KM(max)            4687 non-null   float64
#  5   Est Dia in M(min)             4687 non-null   float64
#  6   Est Dia in M(max)             4687 non-null   float64
#  7   Est Dia in Miles(min)         4687 non-null   float64
#  8   Est Dia in Miles(max)         4687 non-null   float64
#  9   Est Dia in Feet(min)          4687 non-null   float64
#  10  Est Dia in Feet(max)          4687 non-null   float64
#  11  Close Approach Date           4687 non-null   object
# ...

# %% [markdown]
# #### 특정 컬럼 내 데이터 확인

# %%
# 중심점(Orbiting Body) 종류 확인 - 지구의 한 가지만 존재
ah_df['Orbiting Body'].value_counts()
# Out:
# Orbiting Body
# Earth    4687
# Name: count, dtype: int64

# %%
# 궤도 ID 종류 확인 - 겹치는 행이 매우 많음을 확인함
ah_df['Orbit ID'].value_counts()
# Out:
# Orbit ID
# 8      235
# 9      227
# 7      212
# 10     205
# 11     198
#       ...
# 130      1
# 170      1
# 324      1
# 127      1
# 107      1
# Name: count, Length: 188, dtype: int64

# %%
# Equinox 종류 확인 - J2000의 한 가지만 존재
ah_df['Equinox'].value_counts()
# Out:
# Equinox
# J2000    4687
# Name: count, dtype: int64

# %% [markdown]
# #### 데이터 중복 확인

# %%
ah_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 결측치 확인

# %%
ah_df.isna().sum()
# Out:
# Neo Reference ID                0
# Name                            0
# Absolute Magnitude              0
# Est Dia in KM(min)              0
# Est Dia in KM(max)              0
# Est Dia in M(min)               0
# Est Dia in M(max)               0
# Est Dia in Miles(min)           0
# Est Dia in Miles(max)           0
# Est Dia in Feet(min)            0
# Est Dia in Feet(max)            0
# Close Approach Date             0
# Epoch Date Close Approach       0
# Relative Velocity km per sec    0
# Relative Velocity km per hr     0
# Miles per hour                  0
# Miss Dist.(Astronomical)        0
# Miss Dist.(lunar)               0
# Miss Dist.(kilometers)          0
# Miss Dist.(miles)               0
# Orbiting Body                   0
# Orbit ID                        0
# Orbit Determination Date        0
# Orbit Uncertainity              0
# Minimum Orbit Intersection      0
# Jupiter Tisserand Invariant     0
# Epoch Osculation                0
# ...

# %% [markdown]
# #### 수치 데이터 확인

# %%
ah_df.describe().T
# Out:
#                                count          mean           std  \
# Neo Reference ID              4687.0  3.272298e+06  5.486011e+05
# Name                          4687.0  3.272298e+06  5.486011e+05
# Absolute Magnitude            4687.0  2.226786e+01  2.890972e+00
# Est Dia in KM(min)            4687.0  2.046042e-01  3.695734e-01
# Est Dia in KM(max)            4687.0  4.575089e-01  8.263912e-01
# Est Dia in M(min)             4687.0  2.046042e+02  3.695734e+02
# Est Dia in M(max)             4687.0  4.575089e+02  8.263912e+02
# Est Dia in Miles(min)         4687.0  1.271351e-01  2.296422e-01
# Est Dia in Miles(max)         4687.0  2.842828e-01  5.134956e-01
# Est Dia in Feet(min)          4687.0  6.712737e+02  1.212511e+03
# Est Dia in Feet(max)          4687.0  1.501014e+03  2.711257e+03
# Epoch Date Close Approach     4687.0  1.179881e+12  1.981540e+11
# Relative Velocity km per sec  4687.0  1.397081e+01  7.293223e+00
# ...

# %% [markdown]
# #### 불필요한 Feature 제거
# - 소행성의 이름이나 ID 등은 위험도에 직접적인 영향이 없으므로 삭제
# - 또한 겹치는 대상을 서로 다른 단위로 나타낸 feature 역시 일부 삭제

# %%
# 불필요하거나 겹치는 Feature들을 파이썬 list 형태로 모음
drop_columns = [
    'Neo Reference ID', 'Name', 'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
    'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)', 'Close Approach Date',
    'Relative Velocity km per sec', 'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
    'Miss Dist.(miles)', 'Orbiting Body', 'Orbit Determination Date', 'Equinox'
]

# %%
# 위의 feature들 제거
ah_df = ah_df.drop(labels=drop_columns, axis=1)

ah_df
# Out:
#       Absolute Magnitude  Est Dia in KM(min)  Est Dia in KM(max)  \
# 0                 21.600            0.127220            0.284472
# 1                 21.300            0.146068            0.326618
# 2                 20.300            0.231502            0.517654
# 3                 27.400            0.008801            0.019681
# 4                 21.600            0.127220            0.284472
# ...                  ...                 ...                 ...
# 4682              23.900            0.044112            0.098637
# 4683              28.200            0.006089            0.013616
# 4684              22.700            0.076658            0.171412
# 4685              21.800            0.116026            0.259442
# 4686              19.109            0.400641            0.895860
#
#       Epoch Date Close Approach  Relative Velocity km per hr  \
# 0                  7.889470e+11                  22017.00380
# ...

# %% [markdown]
# ### 이상치 확인
# - 각 컬럼 별 데이터들의 분포를 시각화하여 특정 위치에 분포가 몰려있는지 확인하고,
#   만약 그런 데이터가 존재한다면 이상치 해결

# %%
# 남은 feature들의 수치 데이터 재출력
ah_df.describe().T
# Out:
#                               count          mean           std           min  \
# Absolute Magnitude           4687.0  2.226786e+01  2.890972e+00  1.116000e+01
# Est Dia in KM(min)           4687.0  2.046042e-01  3.695734e-01  1.010543e-03
# Est Dia in KM(max)           4687.0  4.575089e-01  8.263912e-01  2.259644e-03
# Epoch Date Close Approach    4687.0  1.179881e+12  1.981540e+11  7.889470e+11
# Relative Velocity km per hr  4687.0  5.029492e+04  2.625560e+04  1.207815e+03
# Miss Dist.(kilometers)       4687.0  3.841347e+07  2.181110e+07  2.660989e+04
# Orbit ID                     4687.0  2.830062e+01  3.829967e+01  1.000000e+00
# Orbit Uncertainity           4687.0  3.516962e+00  3.078307e+00  0.000000e+00
# Minimum Orbit Intersection   4687.0  8.232007e-02  9.029997e-02  2.060000e-06
# Jupiter Tisserand Invariant  4687.0  5.056111e+00  1.237818e+00  2.196000e+00
# Epoch Osculation             4687.0  2.457724e+06  9.202975e+02  2.450164e+06
# ...

# %% [markdown]
# #### Feature 시각화

# %% [markdown]
# ##### 절대등급

# %%
import matplotlib.pyplot as plt 
from scipy import stats
import numpy as np

# kde = stats.gaussian_kde(ah_df['Absolute Magnitude'])
# line = np.linspace(0, 122, 768, endpoint=True)

plt.hist(ah_df['Absolute Magnitude'], density=True, bins=100, color='red')
# plt.plot(line, kde(line))
plt.show()

# %% [markdown]
# ##### 최소 예상 직경

# %%
plt.hist(ah_df['Est Dia in KM(min)'], bins=100, color='blue')
plt.show()

# %% [markdown]
# ##### 최대 예상 직경

# %%
plt.hist(ah_df['Est Dia in KM(max)'], bins=100, color='green')
plt.show()

# %% [markdown]
# ##### 최근접 시간 (UNIX)

# %%
plt.hist(ah_df['Epoch Date Close Approach'], bins=100, color='yellow')
plt.show()

# %% [markdown]
# ##### 상대 시속

# %%
plt.hist(ah_df['Relative Velocity km per hr'], bins=100, color='skyblue')
plt.show()

# %% [markdown]
# ##### 지구 - 소행성 사이의 거리

# %%
plt.hist(ah_df['Miss Dist.(kilometers)'], bins=100, color='red')
plt.show()

# %% [markdown]
# ##### 궤도 번호

# %%
plt.hist(ah_df['Orbit ID'], bins=100, color='blue')
plt.show()

# %% [markdown]
# ##### 지구와의 최소 궤도 교차 거리

# %%
plt.hist(ah_df['Minimum Orbit Intersection'], bins=100, color='green')
plt.show()

# %% [markdown]
# ##### 티세랑 불변량

# %%
plt.hist(ah_df['Jupiter Tisserand Invariant'], bins=100, color='yellow')
plt.show()

# %% [markdown]
# ##### 소행성의 진동 궤도

# %%
plt.hist(ah_df['Epoch Osculation'], bins=100, color='skyblue')
plt.show()

# %% [markdown]
# ##### 궤도 이심률

# %%
plt.hist(ah_df['Eccentricity'], bins=100, color='red')
plt.show()

# %% [markdown]
# ##### 궤도의 긴반지름

# %%
plt.hist(ah_df['Semi Major Axis'], bins=100, color='blue')
plt.show()

# %% [markdown]
# ##### 궤도의 기울기

# %%
plt.hist(ah_df['Inclination'], bins=100, color='green')
plt.show()

# %% [markdown]
# ##### 승교점 경도

# %%
plt.hist(ah_df['Asc Node Longitude'], bins=100, color='yellow')
plt.show()

# %% [markdown]
# ##### 공전 주기

# %%
plt.hist(ah_df['Orbital Period'], bins=100, color='skyblue')
plt.show()

# %% [markdown]
# ##### 태양과 소행성 사이의 최소 거리

# %%
plt.hist(ah_df['Perihelion Distance'], bins=100, color='red')
plt.show()

# %% [markdown]
# ##### 태양과 소행성 사이의 거리가 가장 가까울 때의 각도

# %%
plt.hist(ah_df['Perihelion Arg'], bins=100, color='blue')
plt.show()

# %% [markdown]
# ##### 태양과 소행성 사이의 최대 거리

# %%
plt.hist(ah_df['Aphelion Dist'], bins=100, color='green')
plt.show()

# %% [markdown]
# ##### 다음 번에 태양과 가장 가까워지는 시간

# %%
plt.hist(ah_df['Perihelion Time'], bins=100, color='yellow')
plt.show()

# %% [markdown]
# ##### 평균 근점 이각

# %%
plt.hist(ah_df['Mean Anomaly'], bins=100, color='skyblue')
plt.show()

# %% [markdown]
# ##### 평균 운동: 평균 공전 속도

# %%
plt.hist(ah_df['Mean Motion'], bins=100, color='red')
plt.show()

# %% [markdown]
# #### 상대 시속을 기준으로 데이터 표준화(StandardScaler) 후, 이상치 검사
# - 이 feature가 충돌 확률에 영향을 크게 미친다고 판단했으며,
#   데이터 분포 역시 표준 정규 분포에 가장 가까웠기 때문
