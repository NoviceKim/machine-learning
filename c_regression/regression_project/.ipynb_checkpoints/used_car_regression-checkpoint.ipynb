# %% [markdown]
# ### 주제: CarDecko 사이트에 올라온 중고차 가격을 회귀 예측
# - CarDecko는 인도의 중고차 관련 웹 사이트
#
# ---
#
# #### Features (총 65개)
#
#
# #### Targets
# - listed_price: 판매 사이트에 제시된 가격

# %%
import pandas as pd
import numpy as np

# 데이터 세트 불러오기
c_df = pd.read_csv('../datasets/cars_data_clean.csv', low_memory=False)
c_df
# Out:
#                                usedCarSkuId             loc  myear       body  \
# 0      7111bf25-97af-47f9-867b-40879190d800     gomti nagar   2016  hatchback
# 1      c309efc1-efaf-4f82-81ad-dcb38eb36665   borivali west   2015  hatchback
# 2      7609f710-0c97-4f00-9a47-9b9284b62d3a          jasola   2015      sedan
# 3      278b76e3-5539-4a5e-ae3e-353a2e3b6d7d          jasola   2013  hatchback
# 4      b1eab99b-a606-48dd-a75b-57feb8a9ad92   mumbai g.p.o.   2022        muv
# ...                                     ...             ...    ...        ...
# 37808  ee6ce523-2aa6-4852-96a1-86b9bc277377      thathawade   2018        suv
# 37809  ba1994ac-53ab-4baf-913e-b72f01a37b5d         kharadi   2011      sedan
# 37810  8f4448ae-53f5-4a3f-b13d-2401dd60c624         kothrud   2020  hatchback
# 37811  dbf9b629-7215-494b-a62d-ba1408531362         kothrud   2014  hatchback
# 37812  a96fbcd7-c183-4829-ae97-b2581afe4bac  ambegaon narhe   2018      sedan
#
#       transmission    fuel        km  ip  \
# 0           manual     cng   69162.0   0
# 1           manual     cng   45864.0   0
# 2           manual     cng   81506.0   0
# 3           manual     cng  115893.0   0
# 4           manual     cng   18900.0   0
# ...            ...     ...       ...  ..
# 37808       manual  diesel   49882.0   0
# 37809       manual  diesel   82843.0   0
# 37810       manual  diesel   58000.0   0
# 37811       manual  diesel   62000.0   0
# 37812       manual  diesel   54000.0   0
#
#                                                   images  imgCount  ...  \
# 0      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 1      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 2      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 3                                          [{'img': ''}]         0  ...
# 4      [{'img': 'https://images10.gaadi.com/usedcar_i...         6  ...
# ...                                                  ...       ...  ...
# 37808  [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 37809  [{'img': 'https://images10.gaadi.com/usedcar_i...        27  ...
# 37810  [{'img': 'https://images10.gaadi.com/usedcar_i...        11  ...
# 37811  [{'img': 'https://images10.gaadi.com/usedcar_i...         8  ...
# 37812                                      [{'img': ''}]         0  ...
#
#                 Fuel Suppy System Compression Ratio Alloy Wheel Size  \
# 0                             NaN               NaN              NaN
# 1         Gasoline Port Injection              11.0              NaN
# 2                             NaN               NaN              NaN
# 3      Multi-Point Fuel Injection               NaN             13.0
# 4                             NaN              12.0              NaN
# ...                           ...               ...              ...
# 37808       Common Rail Injection               NaN             16.0
# 37809       Common Rail Injection               NaN             15.0
# 37810                         NaN               NaN             16.0
# 37811       Common Rail Injection               NaN              NaN
# 37812       Common Rail Injection              16.0             14.0
#
#       Ground Clearance Unladen Max Power Delivered Max Power At  \
# 0                          NaN               58.16       6200.0
# 1                          NaN               58.20       6000.0
# 2                          NaN               86.70       6000.0
# 3                          NaN               58.20       6200.0
# 4                          NaN               86.63       5500.0
# ...                        ...                 ...          ...
# 37808                    209.0              108.50       3750.0
# 37809                      NaN               88.80       4000.0
# 37810                      NaN               88.77       4000.0
# 37811                      NaN               69.00       4000.0
# 37812                      NaN               69.00       4000.0
#
#        Max Torque Delivered  Max Torque At  Bore Stroke
# 0                      77.0         3500.0  69.0    NaN
# 1                      78.0         3500.0  73.0    NaN
# 2                     109.0         4500.0   NaN    NaN
# 3                      77.0         3500.0   NaN    NaN
# 4                     121.5         4200.0   NaN    NaN
# ...                     ...            ...   ...    ...
# 37808                 260.0         2125.0  76.0   82.5
# 37809                 200.0         2375.0   NaN    NaN
# 37810                 200.0         2125.0   NaN    NaN
# 37811                 140.0         2400.0   NaN    NaN
# 37812                 140.0         2400.0  75.0    NaN
#
# [37813 rows x 66 columns]

# %%
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37813 entries, 0 to 37812
# Data columns (total 66 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   usedCarSkuId              37813 non-null  object
#  1   loc                       31963 non-null  object
#  2   myear                     37813 non-null  int64
#  3   body                      37794 non-null  object
#  4   transmission              37813 non-null  object
#  5   fuel                      37813 non-null  object
#  6   km                        37813 non-null  float64
#  7   ip                        37813 non-null  int64
#  8   images                    37813 non-null  object
#  9   imgCount                  37813 non-null  int64
#  10  threesixty                37813 non-null  bool
#  11  dvn                       37813 non-null  object
#  12  oem                       37813 non-null  object
#  13  model                     37813 non-null  object
#  14  variant                   37813 non-null  object
#  15  City                      37813 non-null  object
#  16  listed_price              37813 non-null  float64
#  17  discountValue             37813 non-null  int64
#  18  utype                     37813 non-null  object
#  19  carType                   37813 non-null  object
#  20  top_features              37813 non-null  object
#  21  comfort_features          37813 non-null  object
#  22  interior_features         37813 non-null  object
#  23  exterior_features         37813 non-null  object
#  24  safety_features           37813 non-null  object
#  25  Color                     37653 non-null  object
#  26  Engine Type               36945 non-null  object
#  27  No of Cylinder            37670 non-null  float64
#  28  Valves per Cylinder       37585 non-null  float64
#  29  Valve Configuration       29851 non-null  object
#  30  Turbo Charger             37813 non-null  bool
#  31  Super Charger             37813 non-null  bool
#  32  Length                    37451 non-null  float64
#  33  Width                     37442 non-null  float64
#  34  Height                    37450 non-null  float64
#  35  Wheel Base                37257 non-null  float64
#  36  Front Tread               21939 non-null  float64
#  37  Rear Tread                21938 non-null  float64
#  38  Kerb Weight               24674 non-null  float64
#  39  Gross Weight              16923 non-null  float64
#  40  Gear Box                  37342 non-null  object
#  41  Drive Type                33316 non-null  object
#  42  Seats                     37795 non-null  float64
#  43  Steering Type             37005 non-null  object
#  44  Turning Radius            31965 non-null  float64
#  45  Front Brake Type          37486 non-null  object
#  46  Rear Brake Type           37487 non-null  object
#  47  Top Speed                 22461 non-null  float64
#  48  Acceleration              23825 non-null  float64
#  49  Tyre Type                 37556 non-null  object
#  50  Doors                     37769 non-null  float64
#  51  Cargo Volume              31081 non-null  float64
#  52  model_type_new            37813 non-null  object
#  53  state                     37813 non-null  object
#  54  exterior_color            37690 non-null  object
#  55  owner_type                37813 non-null  object
#  56  Fuel Suppy System         32311 non-null  object
#  57  Compression Ratio         10012 non-null  float64
#  58  Alloy Wheel Size          23352 non-null  float64
#  59  Ground Clearance Unladen  2152 non-null   float64
#  60  Max Power Delivered       37582 non-null  float64
#  61  Max Power At              35566 non-null  float64
#  62  Max Torque Delivered      37582 non-null  float64
#  63  Max Torque At             35837 non-null  float64
#  64  Bore                      12636 non-null  float64
#  65  Stroke                    513 non-null    float64
# dtypes: bool(3), float64(27), int64(4), object(32)
# memory usage: 18.3+ MB

# %% [markdown]
# #### 현재 데이터 세트에 필요한 것들
# - 불필요한 컬럼 제거
# - 결측치 조정: 데이터가 고작 513개인 컬럼이 있기 때문에 제거는 생각해볼 것. 참고로 중복 데이터는 없음
# - 차원 축소: **프로젝트의 목적**. 자세한 방식은 로지스틱 회귀 프로젝트 참고할 것
# - 인코딩: 문자열 컬럼은 unique()로 클래스 종류 확인해서 인코딩 방식 정할 것
# - 표준화 후 이상치 제거: 꿀 가격 예측 프로젝트 참고. 원래 수치형인 컬럼들만 따로 뺄 것

# %% [markdown]
# ### 데이터 전처리

# %%
# 데이터 세트 복사
pre_c_df = c_df.copy()
pre_c_df
# Out:
#                                usedCarSkuId             loc  myear       body  \
# 0      7111bf25-97af-47f9-867b-40879190d800     gomti nagar   2016  hatchback
# 1      c309efc1-efaf-4f82-81ad-dcb38eb36665   borivali west   2015  hatchback
# 2      7609f710-0c97-4f00-9a47-9b9284b62d3a          jasola   2015      sedan
# 3      278b76e3-5539-4a5e-ae3e-353a2e3b6d7d          jasola   2013  hatchback
# 4      b1eab99b-a606-48dd-a75b-57feb8a9ad92   mumbai g.p.o.   2022        muv
# ...                                     ...             ...    ...        ...
# 37808  ee6ce523-2aa6-4852-96a1-86b9bc277377      thathawade   2018        suv
# 37809  ba1994ac-53ab-4baf-913e-b72f01a37b5d         kharadi   2011      sedan
# 37810  8f4448ae-53f5-4a3f-b13d-2401dd60c624         kothrud   2020  hatchback
# 37811  dbf9b629-7215-494b-a62d-ba1408531362         kothrud   2014  hatchback
# 37812  a96fbcd7-c183-4829-ae97-b2581afe4bac  ambegaon narhe   2018      sedan
#
#       transmission    fuel        km  ip  \
# 0           manual     cng   69162.0   0
# 1           manual     cng   45864.0   0
# 2           manual     cng   81506.0   0
# 3           manual     cng  115893.0   0
# 4           manual     cng   18900.0   0
# ...            ...     ...       ...  ..
# 37808       manual  diesel   49882.0   0
# 37809       manual  diesel   82843.0   0
# 37810       manual  diesel   58000.0   0
# 37811       manual  diesel   62000.0   0
# 37812       manual  diesel   54000.0   0
#
#                                                   images  imgCount  ...  \
# 0      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 1      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 2      [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 3                                          [{'img': ''}]         0  ...
# 4      [{'img': 'https://images10.gaadi.com/usedcar_i...         6  ...
# ...                                                  ...       ...  ...
# 37808  [{'img': 'https://images10.gaadi.com/usedcar_i...        15  ...
# 37809  [{'img': 'https://images10.gaadi.com/usedcar_i...        27  ...
# 37810  [{'img': 'https://images10.gaadi.com/usedcar_i...        11  ...
# 37811  [{'img': 'https://images10.gaadi.com/usedcar_i...         8  ...
# 37812                                      [{'img': ''}]         0  ...
#
#                 Fuel Suppy System Compression Ratio Alloy Wheel Size  \
# 0                             NaN               NaN              NaN
# 1         Gasoline Port Injection              11.0              NaN
# 2                             NaN               NaN              NaN
# 3      Multi-Point Fuel Injection               NaN             13.0
# 4                             NaN              12.0              NaN
# ...                           ...               ...              ...
# 37808       Common Rail Injection               NaN             16.0
# 37809       Common Rail Injection               NaN             15.0
# 37810                         NaN               NaN             16.0
# 37811       Common Rail Injection               NaN              NaN
# 37812       Common Rail Injection              16.0             14.0
#
#       Ground Clearance Unladen Max Power Delivered Max Power At  \
# 0                          NaN               58.16       6200.0
# 1                          NaN               58.20       6000.0
# 2                          NaN               86.70       6000.0
# 3                          NaN               58.20       6200.0
# 4                          NaN               86.63       5500.0
# ...                        ...                 ...          ...
# 37808                    209.0              108.50       3750.0
# 37809                      NaN               88.80       4000.0
# 37810                      NaN               88.77       4000.0
# 37811                      NaN               69.00       4000.0
# 37812                      NaN               69.00       4000.0
#
#        Max Torque Delivered  Max Torque At  Bore Stroke
# 0                      77.0         3500.0  69.0    NaN
# 1                      78.0         3500.0  73.0    NaN
# 2                     109.0         4500.0   NaN    NaN
# 3                      77.0         3500.0   NaN    NaN
# 4                     121.5         4200.0   NaN    NaN
# ...                     ...            ...   ...    ...
# 37808                 260.0         2125.0  76.0   82.5
# 37809                 200.0         2375.0   NaN    NaN
# 37810                 200.0         2125.0   NaN    NaN
# 37811                 140.0         2400.0   NaN    NaN
# 37812                 140.0         2400.0  75.0    NaN
#
# [37813 rows x 66 columns]

# %%
pre_c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37813 entries, 0 to 37812
# Data columns (total 66 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   usedCarSkuId              37813 non-null  object
#  1   loc                       31963 non-null  object
#  2   myear                     37813 non-null  int64
#  3   body                      37794 non-null  object
#  4   transmission              37813 non-null  object
#  5   fuel                      37813 non-null  object
#  6   km                        37813 non-null  float64
#  7   ip                        37813 non-null  int64
#  8   images                    37813 non-null  object
#  9   imgCount                  37813 non-null  int64
#  10  threesixty                37813 non-null  bool
#  11  dvn                       37813 non-null  object
#  12  oem                       37813 non-null  object
#  13  model                     37813 non-null  object
#  14  variant                   37813 non-null  object
#  15  City                      37813 non-null  object
#  16  listed_price              37813 non-null  float64
#  17  discountValue             37813 non-null  int64
#  18  utype                     37813 non-null  object
#  19  carType                   37813 non-null  object
#  20  top_features              37813 non-null  object
#  21  comfort_features          37813 non-null  object
#  22  interior_features         37813 non-null  object
#  23  exterior_features         37813 non-null  object
#  24  safety_features           37813 non-null  object
#  25  Color                     37653 non-null  object
#  26  Engine Type               36945 non-null  object
#  27  No of Cylinder            37670 non-null  float64
#  28  Valves per Cylinder       37585 non-null  float64
#  29  Valve Configuration       29851 non-null  object
#  30  Turbo Charger             37813 non-null  bool
#  31  Super Charger             37813 non-null  bool
#  32  Length                    37451 non-null  float64
#  33  Width                     37442 non-null  float64
#  34  Height                    37450 non-null  float64
#  35  Wheel Base                37257 non-null  float64
#  36  Front Tread               21939 non-null  float64
#  37  Rear Tread                21938 non-null  float64
#  38  Kerb Weight               24674 non-null  float64
#  39  Gross Weight              16923 non-null  float64
#  40  Gear Box                  37342 non-null  object
#  41  Drive Type                33316 non-null  object
#  42  Seats                     37795 non-null  float64
#  43  Steering Type             37005 non-null  object
#  44  Turning Radius            31965 non-null  float64
#  45  Front Brake Type          37486 non-null  object
#  46  Rear Brake Type           37487 non-null  object
#  47  Top Speed                 22461 non-null  float64
#  48  Acceleration              23825 non-null  float64
#  49  Tyre Type                 37556 non-null  object
#  50  Doors                     37769 non-null  float64
#  51  Cargo Volume              31081 non-null  float64
#  52  model_type_new            37813 non-null  object
#  53  state                     37813 non-null  object
#  54  exterior_color            37690 non-null  object
#  55  owner_type                37813 non-null  object
#  56  Fuel Suppy System         32311 non-null  object
#  57  Compression Ratio         10012 non-null  float64
#  58  Alloy Wheel Size          23352 non-null  float64
#  59  Ground Clearance Unladen  2152 non-null   float64
#  60  Max Power Delivered       37582 non-null  float64
#  61  Max Power At              35566 non-null  float64
#  62  Max Torque Delivered      37582 non-null  float64
#  63  Max Torque At             35837 non-null  float64
#  64  Bore                      12636 non-null  float64
#  65  Stroke                    513 non-null    float64
# dtypes: bool(3), float64(27), int64(4), object(32)
# memory usage: 18.3+ MB

# %%
pre_c_df[['Ground Clearance Unladen']]
# Out:
#        Ground Clearance Unladen
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 37808                     209.0
# 37809                       NaN
# 37810                       NaN
# 37811                       NaN
# 37812                       NaN
#
# [37813 rows x 1 columns]

# %%
pre_c_df['model_type_new'].unique()
# Out:
# array(['used'], dtype=object)

# %%
# 불필요한 컬럼들 삭제
columns = ['usedCarSkuId', 'loc', 'images', 'imgCount', 'threesixty', 'dvn', 'City',
           'top_features', 'comfort_features', 'interior_features', 'exterior_features',
           'safety_features', 'Color', 'Valve Configuration', 'model_type_new', 'state', 'exterior_color']

pre_c_df = pre_c_df.drop(labels=columns, axis=1)
pre_c_df
# Out:
#        myear       body transmission    fuel        km  ip     oem  \
# 0       2016  hatchback       manual     cng   69162.0   0  maruti
# 1       2015  hatchback       manual     cng   45864.0   0  maruti
# 2       2015      sedan       manual     cng   81506.0   0   honda
# 3       2013  hatchback       manual     cng  115893.0   0  maruti
# 4       2022        muv       manual     cng   18900.0   0  maruti
# ...      ...        ...          ...     ...       ...  ..     ...
# 37808   2018        suv       manual  diesel   49882.0   0    tata
# 37809   2011      sedan       manual  diesel   82843.0   0    tata
# 37810   2020  hatchback       manual  diesel   58000.0   0    tata
# 37811   2014  hatchback       manual  diesel   62000.0   0    tata
# 37812   2018      sedan       manual  diesel   54000.0   0    tata
#
#                  model               variant  listed_price  ...  \
# 0       maruti wagon r               lxi cng      370000.0  ...
# 1       maruti celerio             green vxi      365000.0  ...
# 2          honda amaze         s plus i-vtec      421000.0  ...
# 3       maruti wagon r               lxi cng      240000.0  ...
# 4        maruti ertiga               vxi cng     1175000.0  ...
# ...                ...                   ...           ...  ...
# 37808       tata nexon  1.5 revotorq xz plus      881000.0  ...
# 37809       tata manza  aura quadrajet bs iv      245000.0  ...
# 37810      tata altroz             xz diesel      735000.0  ...
# 37811  tata indica ev2                    ls      225000.0  ...
# 37812       tata tigor      1.05 revotorq xz      530000.0  ...
#
#                 Fuel Suppy System Compression Ratio Alloy Wheel Size  \
# 0                             NaN               NaN              NaN
# 1         Gasoline Port Injection              11.0              NaN
# 2                             NaN               NaN              NaN
# 3      Multi-Point Fuel Injection               NaN             13.0
# 4                             NaN              12.0              NaN
# ...                           ...               ...              ...
# 37808       Common Rail Injection               NaN             16.0
# 37809       Common Rail Injection               NaN             15.0
# 37810                         NaN               NaN             16.0
# 37811       Common Rail Injection               NaN              NaN
# 37812       Common Rail Injection              16.0             14.0
#
#       Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                          NaN                58.16        6200.0
# 1                          NaN                58.20        6000.0
# 2                          NaN                86.70        6000.0
# 3                          NaN                58.20        6200.0
# 4                          NaN                86.63        5500.0
# ...                        ...                  ...           ...
# 37808                    209.0               108.50        3750.0
# 37809                      NaN                88.80        4000.0
# 37810                      NaN                88.77        4000.0
# 37811                      NaN                69.00        4000.0
# 37812                      NaN                69.00        4000.0
#
#        Max Torque Delivered  Max Torque At  Bore  Stroke
# 0                      77.0         3500.0  69.0     NaN
# 1                      78.0         3500.0  73.0     NaN
# 2                     109.0         4500.0   NaN     NaN
# 3                      77.0         3500.0   NaN     NaN
# 4                     121.5         4200.0   NaN     NaN
# ...                     ...            ...   ...     ...
# 37808                 260.0         2125.0  76.0    82.5
# 37809                 200.0         2375.0   NaN     NaN
# 37810                 200.0         2125.0   NaN     NaN
# 37811                 140.0         2400.0   NaN     NaN
# 37812                 140.0         2400.0  75.0     NaN
#
# [37813 rows x 49 columns]

# %%
# 타겟 데이터를 맨 끝으로 이동
pre_c_df.loc[:, 'target'] = pre_c_df.listed_price
pre_c_df = pre_c_df.drop(labels=['listed_price'], axis=1)
pre_c_df
# Out:
#        myear       body transmission    fuel        km  ip     oem  \
# 0       2016  hatchback       manual     cng   69162.0   0  maruti
# 1       2015  hatchback       manual     cng   45864.0   0  maruti
# 2       2015      sedan       manual     cng   81506.0   0   honda
# 3       2013  hatchback       manual     cng  115893.0   0  maruti
# 4       2022        muv       manual     cng   18900.0   0  maruti
# ...      ...        ...          ...     ...       ...  ..     ...
# 37808   2018        suv       manual  diesel   49882.0   0    tata
# 37809   2011      sedan       manual  diesel   82843.0   0    tata
# 37810   2020  hatchback       manual  diesel   58000.0   0    tata
# 37811   2014  hatchback       manual  diesel   62000.0   0    tata
# 37812   2018      sedan       manual  diesel   54000.0   0    tata
#
#                  model               variant  discountValue  ...  \
# 0       maruti wagon r               lxi cng              0  ...
# 1       maruti celerio             green vxi              0  ...
# 2          honda amaze         s plus i-vtec              0  ...
# 3       maruti wagon r               lxi cng              0  ...
# 4        maruti ertiga               vxi cng              0  ...
# ...                ...                   ...            ...  ...
# 37808       tata nexon  1.5 revotorq xz plus              0  ...
# 37809       tata manza  aura quadrajet bs iv              0  ...
# 37810      tata altroz             xz diesel              0  ...
# 37811  tata indica ev2                    ls              0  ...
# 37812       tata tigor      1.05 revotorq xz              0  ...
#
#       Compression Ratio Alloy Wheel Size Ground Clearance Unladen  \
# 0                   NaN              NaN                      NaN
# 1                  11.0              NaN                      NaN
# 2                   NaN              NaN                      NaN
# 3                   NaN             13.0                      NaN
# 4                  12.0              NaN                      NaN
# ...                 ...              ...                      ...
# 37808               NaN             16.0                    209.0
# 37809               NaN             15.0                      NaN
# 37810               NaN             16.0                      NaN
# 37811               NaN              NaN                      NaN
# 37812              16.0             14.0                      NaN
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 0                    58.16        6200.0                  77.0         3500.0
# 1                    58.20        6000.0                  78.0         3500.0
# 2                    86.70        6000.0                 109.0         4500.0
# 3                    58.20        6200.0                  77.0         3500.0
# 4                    86.63        5500.0                 121.5         4200.0
# ...                    ...           ...                   ...            ...
# 37808               108.50        3750.0                 260.0         2125.0
# 37809                88.80        4000.0                 200.0         2375.0
# 37810                88.77        4000.0                 200.0         2125.0
# 37811                69.00        4000.0                 140.0         2400.0
# 37812                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke     target
# 0      69.0     NaN   370000.0
# 1      73.0     NaN   365000.0
# 2       NaN     NaN   421000.0
# 3       NaN     NaN   240000.0
# 4       NaN     NaN  1175000.0
# ...     ...     ...        ...
# 37808  76.0    82.5   881000.0
# 37809   NaN     NaN   245000.0
# 37810   NaN     NaN   735000.0
# 37811   NaN     NaN   225000.0
# 37812  75.0     NaN   530000.0
#
# [37813 rows x 49 columns]

# %% [markdown]
# #### 중간 분석
# - 현재 타겟은 연속형
# - 따라서 차원 축소 방식은 무조건 PCA
# > - LDA는 클래스 별로 나누는 것이 중점이라, 타겟 데이터가 연속형인 이번 프로젝트에서는 사용 불가

# %% [markdown]
# #### 결측치 조정
# - 결측치 비율이 10%(3700개) 미만인 컬럼들은 결측치 삭제
# - 10% 이상이면 대체(평균 or 중간값 or 최빈값)
#
# - 현재 10% 이상의 결측치가 발견된 컬럼은 Drive Type과 Fuel Suppy System을 제외하고 모두 수치형
#
# - 순서
# > 1. 결측치 10% 미만 컬럼 결측치 삭제
# > 2. Drive Type, Fuel Suppy System 결측치 조정
# > 3. 결측치 10% 이상 컬럼 결측치 조정
# > 4. 레이블 인코딩

# %%
# 결측치 확인
pre_c_df.isna().sum()
# Out:
# myear                           0
# body                           19
# transmission                    0
# fuel                            0
# km                              0
# ip                              0
# oem                             0
# model                           0
# variant                         0
# discountValue                   0
# utype                           0
# carType                         0
# Engine Type                   868
# No of Cylinder                143
# Valves per Cylinder           228
# Turbo Charger                   0
# Super Charger                   0
# Length                        362
# Width                         371
# Height                        363
# Wheel Base                    556
# Front Tread                 15874
# Rear Tread                  15875
# Kerb Weight                 13139
# Gross Weight                20890
# Gear Box                      471
# Drive Type                   4497
# Seats                          18
# Steering Type                 808
# Turning Radius               5848
# Front Brake Type              327
# Rear Brake Type               326
# Top Speed                   15352
# Acceleration                13988
# Tyre Type                     257
# Doors                          44
# Cargo Volume                 6732
# owner_type                      0
# Fuel Suppy System            5502
# Compression Ratio           27801
# Alloy Wheel Size            14461
# Ground Clearance Unladen    35661
# Max Power Delivered           231
# Max Power At                 2247
# Max Torque Delivered          231
# Max Torque At                1976
# Bore                        25177
# Stroke                      37300
# target                          0
# dtype: int64

# %%
# 결측치 10% 미만인 컬럼들 (+ Drive Type, Fuel Suppy System)
columns = ['body', 'Engine Type', 'No of Cylinder', 'Valves per Cylinder', 'Length', 'Width',
           'Height', 'Wheel Base', 'Gear Box', 'Drive Type', 'Seats', 'Steering Type',
           'Front Brake Type', 'Rear Brake Type', 'Tyre Type', 'Doors', 'Fuel Suppy System',
           'Max Power Delivered', 'Max Power At', 'Max Torque Delivered', 'Max Torque At']

# 반복문으로 위 컬럼들의 결측치 제거
for column in columns:
    pre_c_df = pre_c_df[~pre_c_df[column].isna()]

# 결측치 제거 후 데이터 세트 확인
pre_c_df
# Out:
#        myear       body transmission    fuel        km  ip      oem  \
# 1       2015  hatchback       manual     cng   45864.0   0   maruti
# 3       2013  hatchback       manual     cng  115893.0   0   maruti
# 7       2017  hatchback       manual     cng   58000.0   0  hyundai
# 8       2021  hatchback       manual     cng   54097.0   0   maruti
# 10      2018  hatchback       manual     cng   98083.0   0   maruti
# ...      ...        ...          ...     ...       ...  ..      ...
# 37806   2018        suv       manual  diesel   66000.0   0     tata
# 37808   2018        suv       manual  diesel   49882.0   0     tata
# 37809   2011      sedan       manual  diesel   82843.0   0     tata
# 37811   2014  hatchback       manual  diesel   62000.0   0     tata
# 37812   2018      sedan       manual  diesel   54000.0   0     tata
#
#                    model                   variant  discountValue  ...  \
# 1         maruti celerio                 green vxi              0  ...
# 3         maruti wagon r                   lxi cng              0  ...
# 7      hyundai grand i10  1.2 kappa magna cng bsiv              0  ...
# 8         maruti wagon r                   cng lxi              0  ...
# 10        maruti celerio     vxi cng optional bsiv              0  ...
# ...                  ...                       ...            ...  ...
# 37806         tata nexon           1.5 revotorq xm              0  ...
# 37808         tata nexon      1.5 revotorq xz plus              0  ...
# 37809         tata manza      aura quadrajet bs iv              0  ...
# 37811    tata indica ev2                        ls              0  ...
# 37812         tata tigor          1.05 revotorq xz              0  ...
#
#       Compression Ratio Alloy Wheel Size Ground Clearance Unladen  \
# 1                  11.0              NaN                      NaN
# 3                   NaN             13.0                      NaN
# 7                   NaN              NaN                      NaN
# 8                   NaN              NaN                      NaN
# 10                 11.0              NaN                      NaN
# ...                 ...              ...                      ...
# 37806               NaN              NaN                    209.0
# 37808               NaN             16.0                    209.0
# 37809               NaN             15.0                      NaN
# 37811               NaN              NaN                      NaN
# 37812              16.0             14.0                      NaN
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 1                    58.20        6000.0                  78.0         3500.0
# 3                    58.20        6200.0                  77.0         3500.0
# 7                    65.39        6000.0                  98.0         4000.0
# 8                    58.33        5500.0                  78.0         3500.0
# 10                   58.33        6000.0                  78.0         3500.0
# ...                    ...           ...                   ...            ...
# 37806               108.50        3750.0                 260.0         2125.0
# 37808               108.50        3750.0                 260.0         2125.0
# 37809                88.80        4000.0                 200.0         2375.0
# 37811                69.00        4000.0                 140.0         2400.0
# 37812                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke    target
# 1      73.0     NaN  365000.0
# 3       NaN     NaN  240000.0
# 7       NaN     NaN  465000.0
# 8      73.0     NaN  560000.0
# 10     73.0     NaN  425000.0
# ...     ...     ...       ...
# 37806  76.0    82.5  760000.0
# 37808  76.0    82.5  881000.0
# 37809   NaN     NaN  245000.0
# 37811   NaN     NaN  225000.0
# 37812  75.0     NaN  530000.0
#
# [28777 rows x 49 columns]

# %%
# 현재 결측치 수 확인
pre_c_df.isna().sum()
# Out:
# myear                           0
# body                            0
# transmission                    0
# fuel                            0
# km                              0
# ip                              0
# oem                             0
# model                           0
# variant                         0
# discountValue                   0
# utype                           0
# carType                         0
# Engine Type                     0
# No of Cylinder                  0
# Valves per Cylinder             0
# Turbo Charger                   0
# Super Charger                   0
# Length                          0
# Width                           0
# Height                          0
# Wheel Base                      0
# Front Tread                 10782
# Rear Tread                  10768
# Kerb Weight                  9540
# Gross Weight                15231
# Gear Box                        0
# Drive Type                      0
# Seats                           0
# Steering Type                   0
# Turning Radius               2979
# Front Brake Type                0
# Rear Brake Type                 0
# Top Speed                    9423
# Acceleration                 8400
# Tyre Type                       0
# Doors                           0
# Cargo Volume                 3672
# owner_type                      0
# Fuel Suppy System               0
# Compression Ratio           20161
# Alloy Wheel Size            11029
# Ground Clearance Unladen    27312
# Max Power Delivered             0
# Max Power At                    0
# Max Torque Delivered            0
# Max Torque At                   0
# Bore                        18355
# Stroke                      28384
# target                          0
# dtype: int64

# %% [markdown]
# #### 중간 분석
# - Drive Type, Fuel Suppy System 결측치
# > - 일단 제거해보고, 만약 결과 이상하면 다음 사이클에서는 결측치 대체

# %%
# 결측치 10% 이상인 컬럼들
columns = ['Front Tread', 'Rear Tread', 'Kerb Weight', 'Gross Weight', 'Turning Radius',
           'Top Speed', 'Acceleration', 'Cargo Volume', 'Compression Ratio',
           'Alloy Wheel Size', 'Ground Clearance Unladen', 'Bore', 'Stroke']

# 결측치 10% 이상인 컬럼들의 수치 데이터 출력
pre_c_df[columns].describe().T
# Out:
#                             count         mean         std      min      25%  \
# Front Tread               17995.0  1475.658294   84.654403  1205.00  1450.00
# Rear Tread                18009.0  1475.443445   97.040189    15.00  1450.00
# Kerb Weight               19237.0  1150.110360  313.456886   600.00   935.00
# Gross Weight              13546.0  1733.463605  440.505645  1000.00  1360.00
# Turning Radius            25798.0     5.117159    0.504058     4.00     4.80
# Top Speed                 19354.0   173.589852   25.371234    80.00   156.00
# Acceleration              20377.0    13.002799    3.185629     3.20    10.86
# Cargo Volume              25105.0   366.299661  128.987715    48.00   259.00
# Compression Ratio          8616.0    13.016141    5.330285     4.17    10.30
# Alloy Wheel Size          17748.0    15.460503    1.493007    12.00    14.00
# Ground Clearance Unladen   1465.0   176.630717   29.996029    91.00   155.00
# Bore                      10422.0    72.431925   12.218887     2.85    69.60
# Stroke                      393.0    83.587837    4.582524    76.00    82.50
#
#                              50%     75%      max
# Front Tread               1485.0  1530.0  1690.00
# Rear Tread                1493.0  1525.0  1713.00
# Kerb Weight               1066.0  1235.0  2750.00
# Gross Weight              1640.0  2017.0  3350.00
# Turning Radius               5.2     5.3    12.84
# Top Speed                  170.0   190.0   325.00
# Acceleration                13.0    14.5    44.04
# Cargo Volume               350.0   465.0  2055.00
# Compression Ratio           10.8    16.5    81.00
# Alloy Wheel Size            16.0    16.0    21.00
# Ground Clearance Unladen   190.0   190.0   210.00
# Bore                        73.0    77.0   165.00
# Stroke                      82.5    85.8   104.90

# %% [markdown]
# #### 중간 분석
# - 현재 위의 모든 컬럼들의 평균값과 중앙값이 비슷한 수치를 보임
# - 따라서 이번 프로젝트에서는 중앙값으로 결측치 대체

# %%
# 반복문으로 결측치를 중앙값으로 대체
for column in columns:
    pre_c_df[columns] = pre_c_df[columns].fillna(pre_c_df[columns].median())

# 결측치 조정 후의 데이터 세트 확인
pre_c_df
# Out:
#        myear       body transmission    fuel        km  ip      oem  \
# 1       2015  hatchback       manual     cng   45864.0   0   maruti
# 3       2013  hatchback       manual     cng  115893.0   0   maruti
# 7       2017  hatchback       manual     cng   58000.0   0  hyundai
# 8       2021  hatchback       manual     cng   54097.0   0   maruti
# 10      2018  hatchback       manual     cng   98083.0   0   maruti
# ...      ...        ...          ...     ...       ...  ..      ...
# 37806   2018        suv       manual  diesel   66000.0   0     tata
# 37808   2018        suv       manual  diesel   49882.0   0     tata
# 37809   2011      sedan       manual  diesel   82843.0   0     tata
# 37811   2014  hatchback       manual  diesel   62000.0   0     tata
# 37812   2018      sedan       manual  diesel   54000.0   0     tata
#
#                    model                   variant  discountValue  ...  \
# 1         maruti celerio                 green vxi              0  ...
# 3         maruti wagon r                   lxi cng              0  ...
# 7      hyundai grand i10  1.2 kappa magna cng bsiv              0  ...
# 8         maruti wagon r                   cng lxi              0  ...
# 10        maruti celerio     vxi cng optional bsiv              0  ...
# ...                  ...                       ...            ...  ...
# 37806         tata nexon           1.5 revotorq xm              0  ...
# 37808         tata nexon      1.5 revotorq xz plus              0  ...
# 37809         tata manza      aura quadrajet bs iv              0  ...
# 37811    tata indica ev2                        ls              0  ...
# 37812         tata tigor          1.05 revotorq xz              0  ...
#
#       Compression Ratio Alloy Wheel Size Ground Clearance Unladen  \
# 1                  11.0             16.0                    190.0
# 3                  10.8             13.0                    190.0
# 7                  10.8             16.0                    190.0
# 8                  10.8             16.0                    190.0
# 10                 11.0             16.0                    190.0
# ...                 ...              ...                      ...
# 37806              10.8             16.0                    209.0
# 37808              10.8             16.0                    209.0
# 37809              10.8             15.0                    190.0
# 37811              10.8             16.0                    190.0
# 37812              16.0             14.0                    190.0
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 1                    58.20        6000.0                  78.0         3500.0
# 3                    58.20        6200.0                  77.0         3500.0
# 7                    65.39        6000.0                  98.0         4000.0
# 8                    58.33        5500.0                  78.0         3500.0
# 10                   58.33        6000.0                  78.0         3500.0
# ...                    ...           ...                   ...            ...
# 37806               108.50        3750.0                 260.0         2125.0
# 37808               108.50        3750.0                 260.0         2125.0
# 37809                88.80        4000.0                 200.0         2375.0
# 37811                69.00        4000.0                 140.0         2400.0
# 37812                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke    target
# 1      73.0    82.5  365000.0
# 3      73.0    82.5  240000.0
# 7      73.0    82.5  465000.0
# 8      73.0    82.5  560000.0
# 10     73.0    82.5  425000.0
# ...     ...     ...       ...
# 37806  76.0    82.5  760000.0
# 37808  76.0    82.5  881000.0
# 37809  73.0    82.5  245000.0
# 37811  73.0    82.5  225000.0
# 37812  75.0    82.5  530000.0
#
# [28777 rows x 49 columns]

# %%
# 결측치 10% 이상인 컬럼들의 수치 데이터 출력
pre_c_df[columns].describe().T
# Out:
#                             count         mean         std      min      25%  \
# Front Tread               28777.0  1479.158390   67.094472  1205.00  1479.00
# Rear Tread                28777.0  1482.012892   77.234755    15.00  1485.00
# Kerb Weight               28777.0  1122.226535  259.323925   600.00  1025.00
# Gross Weight              28777.0  1683.995483  305.801338  1000.00  1640.00
# Turning Radius            28777.0     5.125735    0.477921     4.00     4.80
# Top Speed                 28777.0   172.414358   20.874664    80.00   164.00
# Acceleration              28777.0    13.001982    2.680646     3.20    12.36
# Cargo Volume              28777.0   364.219794  120.599811    48.00   280.00
# Compression Ratio         28777.0    11.463525    3.088081     4.17    10.80
# Alloy Wheel Size          28777.0    15.667269    1.201471    12.00    15.00
# Ground Clearance Unladen  28777.0   189.319387    7.376477    91.00   190.00
# Bore                      28777.0    72.794263    7.358179     2.85    73.00
# Stroke                    28777.0    82.514856    0.549551    76.00    82.50
#
#                              50%     75%      max
# Front Tread               1485.0  1501.0  1690.00
# Rear Tread                1493.0  1503.0  1713.00
# Kerb Weight               1066.0  1139.0  2750.00
# Gross Weight              1640.0  1640.0  3350.00
# Turning Radius               5.2     5.3    12.84
# Top Speed                  170.0   177.0   325.00
# Acceleration                13.0    14.0    44.04
# Cargo Volume               350.0   460.0  2055.00
# Compression Ratio           10.8    10.8    81.00
# Alloy Wheel Size            16.0    16.0    21.00
# Ground Clearance Unladen   190.0   190.0   210.00
# Bore                        73.0    73.0   165.00
# Stroke                      82.5    82.5   104.90

# %%
# 결측치 확인
pre_c_df.isna().sum().sum()
# Out:
# 0

# %%
# 중복 확인
pre_c_df.duplicated().sum()
# Out:
# 102

# %%
# 중복 데이터 삭제
pre_c_df = pre_c_df.drop_duplicates()
pre_c_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 레이블 인코딩

# %%
# 데이터 세트 내 컬럼들 중 문자열 데이터가 담긴 컬럼들만 가져오기
columns = pre_c_df.columns
object_columns = []

for column in columns:
    if pre_c_df[column].dtype == 'O':
        object_columns.append(column)

object_columns
# Out:
# ['body',
#  'transmission',
#  'fuel',
#  'oem',
#  'model',
#  'variant',
#  'utype',
#  'carType',
#  'Engine Type',
#  'Gear Box',
#  'Drive Type',
#  'Steering Type',
#  'Front Brake Type',
#  'Rear Brake Type',
#  'Tyre Type',
#  'owner_type',
#  'Fuel Suppy System']

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}

# 문자열 컬럼들에 레이블 인코더 적용
for column in object_columns:
    encoder = LabelEncoder()
    result = encoder.fit_transform(pre_c_df[column])
    pre_c_df.loc[:, column] = result
    encoders[column] = encoder.classes_

print(encoders)
# Out:
# {'body': array(['convertibles', 'coupe', 'hatchback', 'hybrids', 'luxury vehicles',
#        'minivans', 'muv', 'pickup trucks', 'sedan', 'suv', 'wagon'],
#       dtype=object), 'transmission': array(['automatic', 'manual'], dtype=object), 'fuel': array(['cng', 'diesel', 'electric', 'lpg', 'petrol'], dtype=object), 'oem': array(['ashok leyland', 'aston martin', 'audi', 'bentley', 'bmw',
#        'chevrolet', 'datsun', 'dc', 'fiat', 'force', 'ford', 'honda',
#        'hyundai', 'isuzu', 'jaguar', 'jeep', 'kia', 'lamborghini',
#        'land rover', 'lexus', 'mahindra', 'mahindra ssangyong', 'maruti',
#        'maserati', 'mercedes-benz', 'mini', 'mitsubishi', 'nissan',
#        'porsche', 'premier', 'renault', 'rolls-royce', 'skoda', 'tata',
#        'toyota', 'volkswagen', 'volvo'], dtype=object), 'model': array(['ashok leyland stile', 'aston martin vantage', 'audi a3',
#        'audi a3 cabriolet', 'audi a4', 'audi a5', 'audi a6', 'audi a7',
#        'audi a8', 'audi a8 2010-2013', 'audi q3', 'audi q5', 'audi q7',
#        'audi q8', 'audi rs5', 'audi s5', 'audi tt', 'bentley continental',
#        'bmw 1 series', 'bmw 3 series', 'bmw 3 series gt', 'bmw 5 series',
#        'bmw 6 series', 'bmw 7 series', 'bmw m series', 'bmw x1', 'bmw x3',
#        'bmw x4', 'bmw x5', 'bmw x6', 'bmw x7', 'bmw z4', 'chevrolet aveo',
#        'chevrolet aveo u-va', 'chevrolet beat', 'chevrolet captiva',
#        'chevrolet cruze', 'chevrolet enjoy', 'chevrolet optra',
#        'chevrolet sail', 'chevrolet sail hatchback', 'chevrolet spark',
#        'chevrolet tavera', 'chevrolet trailblazer', 'datsun go',
#        'datsun go plus', 'datsun redigo', 'dc avanti', 'fiat avventura',
#        'fiat avventura urban cross', 'fiat grande punto', 'fiat linea',
#        'fiat linea classic', 'fiat palio', 'fiat punto',
#        'fiat punto abarth', 'fiat punto evo', 'fiat punto pure',
#        'force gurkha', 'force one', 'ford aspire', 'ford classic',
#        'ford ecosport', 'ford endeavour', 'ford fiesta', 'ford figo',
#        'ford freestyle', 'ford ikon', 'ford mustang', 'honda accord',
#        'honda amaze', 'honda br-v', 'honda brio', 'honda city',
#        'honda civic', 'honda cr-v', 'honda jazz', 'honda mobilio',
#        'honda wr-v', 'hyundai accent', 'hyundai aura', 'hyundai creta',
#        'hyundai elantra', 'hyundai elite i20 2018', 'hyundai eon',
#        'hyundai grand i10', 'hyundai grand i10 nios', 'hyundai i10',
#        'hyundai i20', 'hyundai i20 active', 'hyundai santa fe',
#        'hyundai santro', 'hyundai santro xing', 'hyundai sonata',
#        'hyundai tucson', 'hyundai venue', 'hyundai verna',
#        'hyundai xcent', 'isuzu d-max', 'isuzu mu 7', 'isuzu mu-x',
#        'jaguar f-pace', 'jaguar f-type', 'jaguar xf', 'jaguar xj',
#        'jeep compass', 'kia carens', 'kia carnival', 'kia seltos',
#        'kia sonet', 'lamborghini huracan', 'land rover defender',
#        'land rover discovery 4', 'land rover discovery sport',
#        'land rover freelander 2', 'land rover range rover',
#        'land rover range rover evoque', 'land rover range rover sport',
#        'land rover range rover velar', 'lexus es', 'lexus lx', 'lexus nx',
#        'mahindra alturas g4', 'mahindra bolero',
#        'mahindra bolero power plus', 'mahindra e2o plus',
#        'mahindra kuv 100', 'mahindra kuv 100 nxt', 'mahindra marazzo',
#        'mahindra nuvosport', 'mahindra quanto', 'mahindra scorpio',
#        'mahindra ssangyong rexton', 'mahindra supro', 'mahindra thar',
#        'mahindra tuv 300', 'mahindra tuv 300 plus', 'mahindra verito',
#        'mahindra verito vibe', 'mahindra xuv300', 'mahindra xuv500',
#        'mahindra xuv700', 'mahindra xylo', 'maruti 800', 'maruti a-star',
#        'maruti alto', 'maruti alto 800', 'maruti alto k10',
#        'maruti baleno', 'maruti baleno rs', 'maruti celerio',
#        'maruti celerio x', 'maruti ciaz', 'maruti ciaz s', 'maruti eeco',
#        'maruti ertiga', 'maruti estilo', 'maruti gypsy', 'maruti ignis',
#        'maruti kizashi', 'maruti omni', 'maruti ritz', 'maruti swift',
#        'maruti swift dzire', 'maruti sx4', 'maruti sx4 s cross',
#        'maruti vitara brezza', 'maruti wagon r',
#        'maruti wagon r stingray', 'maruti zen estilo', 'maserati ghibli',
#        'mercedes-benz a class', 'mercedes-benz b class',
#        'mercedes-benz c-class', 'mercedes-benz cla',
#        'mercedes-benz cls-class', 'mercedes-benz e-class',
#        'mercedes-benz e-class all-terrain', 'mercedes-benz gl-class',
#        'mercedes-benz gla', 'mercedes-benz gla class',
#        'mercedes-benz glc', 'mercedes-benz gle', 'mercedes-benz gls',
#        'mercedes-benz m-class', 'mercedes-benz s-class',
#        'mercedes-benz slk-class', 'mini 3 door', 'mini 5 door',
#        'mini cooper convertible', 'mini cooper countryman',
#        'mitsubishi cedia', 'mitsubishi lancer', 'mitsubishi montero',
#        'mitsubishi outlander', 'mitsubishi pajero', 'nissan evalia',
#        'nissan kicks', 'nissan micra', 'nissan micra active',
#        'nissan sunny', 'nissan teana', 'nissan terrano', 'nissan x-trail',
#        'porsche 718', 'porsche cayenne', 'porsche macan',
#        'porsche panamera', 'premier rio', 'renault captur',
#        'renault duster', 'renault fluence', 'renault kiger',
#        'renault koleos', 'renault kwid', 'renault lodgy', 'renault pulse',
#        'renault scala', 'renault triber', 'rolls-royce phantom',
#        'skoda fabia', 'skoda karoq', 'skoda kodiaq', 'skoda kushaq',
#        'skoda new laura', 'skoda octavia', 'skoda rapid', 'skoda slavia',
#        'skoda superb', 'skoda yeti', 'tata altroz', 'tata aria',
#        'tata bolt', 'tata harrier', 'tata hexa', 'tata indica',
#        'tata indica ev2', 'tata indigo', 'tata manza', 'tata nano',
#        'tata new safari', 'tata nexon', 'tata safari storme', 'tata sumo',
#        'tata tiago', 'tata tiago nrg', 'tata tigor', 'tata venture',
#        'tata xenon xt', 'tata zest', 'toyota camry',
#        'toyota corolla altis', 'toyota etios', 'toyota etios 2014-2016',
#        'toyota etios cross', 'toyota etios liva', 'toyota fortuner',
#        'toyota innova', 'toyota innova crysta', 'toyota land cruiser',
#        'toyota platinum etios', 'toyota prado', 'toyota prius',
#        'toyota yaris', 'volkswagen ameo', 'volkswagen crosspolo',
#        'volkswagen gti', 'volkswagen jetta', 'volkswagen passat',
#        'volkswagen polo', 'volkswagen t-roc', 'volkswagen tiguan',
#        'volkswagen vento', 'volvo s 80', 'volvo s60', 'volvo v40',
#        'volvo v40 cross country', 'volvo xc 90', 'volvo xc60',
#        'volvo xc90'], dtype=object), 'variant': array(['(non-ac)', '1.0', '1.0 amt rxl', ..., 'zxi plus',
#        'zxi plus bs iv', 'zxi plus petrol'], dtype=object), 'utype': array(['dealer', 'individual'], dtype=object), 'carType': array(['assured', 'corporate', 'partner'], dtype=object), 'Engine Type': array(['0.8l petrol engine', '1-gd ftv engine', '1.0 l energy',
#        '1.0 l petrol engine', '1.0 l tsi petrol', '1.0 l turbo gdi',
#        '1.0 l turbocharged', '1.0 tsi petrol engine', '1.0l mpi petrol',
#        '1.0l petrol engine', '1.0l tsi petrol', '1.1 l bi-fuel',
#        '1.1 l petrol', '1.1 litre petrol engine', '1.2 l kappa petrol',
#        '1.2 l revotron', '1.2 l u2 crdi', '1.2 l u2 crdi diesel',
#        '1.2 litre petrol engine', '1.2 petrol engine',
#        '1.2-litre petrol engine', '1.2-litre vvt petrol engine',
#        '1.2l kappa dual vtvt petrol', '1.2l turbo petrol',
#        '1.2l u2 crdi diesel', '1.2l vvt engine',
#        '1.3 l hr13ddt turbo petrol', '1.3-litre ddis diesel engine',
#        '1.4-litre 4-cyl multiair engine', '1.4-litre tdi engine',
#        '1.4l gdi turbo petrol', '1.4tsi petrol engine',
#        '1.5 diesel engine', '1.5 dual vvt-i engine', '1.5 k9k diesel',
#        '1.5 l crdi vgt', '1.5 l crdi wgt', '1.5 l hr15 petrol',
#        '1.5 l tsi evo with act', '1.5 l tsi petrol', '1.5 l u2 diesel',
#        '1.5 litre diesel engine', '1.5 tsi petrol engine',
#        '1.5l crdi diesel', '1.5l crdi vgt', '1.5l crdi wgt',
#        '1.5l petrol engine', '1.5l revotorq turbocharged',
#        '1.5l turbo diesel', '1.5l turbo diesel engine',
#        '1.5l turbocharged petrol engine',
#        '1.6-litre i-dtec  diesel engine',
#        '1.8-litre i-vtec petrol engine', '1.8l tsi petrol engine',
#        '1.8tsi petrol engine', '16v dohc common rail cr4',
#        '16v dohc vtt dicor', '1nr-tv, diesel, 4-cylinde',
#        '1vd ftv diesel engine', '1vd-ftv - 8 cylinder v type',
#        '2-gd ftv engine', '2-tr-fe dual vvt-i engine',
#        '2.0  turbocharged petrol engine', '2.0 l tsi petrol engine',
#        '2.0 litre 4-cylinder in-line petrol',
#        '2.0 litre p300 petrol engine', '2.0 litre petrol engine',
#        '2.0 tdi diesel engine', '2.0 turbo diesel',
#        '2.0-litre 4-cyl multijet engine',
#        '2.0-litre 4-cyl multijet ii engine', '2.0-litre petrol engine',
#        '2.0-litre tdi diesel engine', '2.0l mid-engine',
#        '2.0l turbo petrol', '2.0l turbocharged petrol',
#        '2.0tdi diesel engine', '2.2 fmtech crdi engine',
#        '2.2 l turbo diesel', '2.2 ltr. varicor 320',
#        '2.2 ltr. varicor 400', '2.2-litre diesel engine',
#        '2.2l vgt diesel engine', '2.4 litre 16 valve petrol engine',
#        '2.4l diesel engine', '2.5 gasoline hybrid petrol engine',
#        '2.5-liter l4 engine', '2.5-litre, 4-cyl. in-line twin cam',
#        '2.7l dual vvt', '210ah lithium ion', '2ar-fe petrol engine',
#        '2ar-fxe petrol engine', '2cylinder petrol engine',
#        '2kd-ftv diesel engine', '2kd-ftv diesel with inter',
#        '2l petrol engine', '2nr-fe ,gasoline, 4 cylin',
#        '2zr-fe gasoline 4cylinder', '2zr-fe petrol engine',
#        '2zr-fxe petrol engine', '3.0tfsiq tiptronic petrol engine',
#        '4 cylinder in-line petrol', '4 cylinder, common rail s',
#        '4 cylinder, common rail,', '4 cylinder, mpfi, petrol',
#        '4 cylinders in-line', '4.8-litre v8 engine',
#        '4cylinder turbo intercool', '4cylinder,common rail sde',
#        '5.0l ti-vct v8', 'a25b-fxs, 4 cylinders in-line petrol eng',
#        'advanced multijet diesel', 'advanced multijet engine',
#        'aluminium', 'bi-fuel engine', 'bifuel engine',
#        'blue efficiency engine', 'blue efficiency petrol en',
#        'boosterjet petrol engine', 'cdi blue efficiency engin',
#        'cdi in-line engine', 'common rail cr4', 'common rail di-d engine',
#        'common rail diesel engine', 'common rail direct injection',
#        'cr4 diesel engine', 'cr4 turbo intercooled eng',
#        'crdi diesel engine', 'd-4d diesel engine', 'd13a shvs engine',
#        'd15 1.5 liter diesel engine', 'd22dtr', 'dci crdi diesel engine',
#        'dci diesel engine', 'dci engine',
#        'dci engine with fixed geometry turbo', 'dci engine with vgt',
#        'dci in-line diesel engine', 'dci thp diesel engine',
#        'ddis 190 engine', 'ddis 200 diesel engine', 'ddis 200 engine',
#        'ddis 200 smart hybrid', 'ddis 225 diesel engine',
#        'ddis diesel engin', 'ddis diesel engine',
#        'ddis smart hybrid diesel engine', 'di turbo diesel engine',
#        'di-diesel engine', 'dicor complaint with dual',
#        'dicor diesel engine', 'dicor engine', 'diesel', 'diesel engine',
#        'diesel engne', 'diesel s engine', 'dohc dual vvt-i petrol en',
#        'dohc engine', 'dohc i-vtec', 'dohc kappa2 engine',
#        'dual vtvt nu 2.0 petrol', 'dual vtvt petrol engine',
#        'dual vvti petrol engine', 'duramax engine',
#        'duratec petrol engine', 'duratorq', 'duratorq diesel engine',
#        'e- vgt r 2.0 diesel', 'e-vgt diesel engine',
#        'ecoboost petrol engine', 'f8d engine', 'f8d petrol engine',
#        'fc petrol engine', 'fire engine', 'fire petrol engine',
#        'five-cylinder turbo charg', 'fmtech engine', 'fti engine',
#        'g13bb mpfi gasoline engin', 'gamma vtvt petrol engine',
#        'gdi petrol engine', 'h4k petrol engine', 'hi-tech petrol engine',
#        'hr15 petrol engine', 'i dtec diesel engine', 'i vtec engine',
#        'i-dtec diesel engine', 'i-dtec engine', 'i-vtec', 'i-vtec engine',
#        'i-vtec petrol engine', 'idi diesel engine',
#        'in line diesel engine', 'in line engine', 'in line petrol engine',
#        'in line twin turbo engine', 'in line twinturbo engine',
#        'in-lie petrol engine', 'in-line',
#        'in-line 4 cylinder diesel engine',
#        'in-line 4 cylinder petrol engine', 'in-line diesel engine',
#        'in-line engine', 'in-line petrol engine', 'inline diesel engine',
#        'intercooled diesel engine', 'intercooled turbocharger',
#        'irde2 engine', 'isuzu ddi vgs turboengine', 'k 10b petrol engine',
#        'k series engine', 'k series petrol engine',
#        'k series petrol engine wi', 'k series vvt engine', 'k10b engine',
#        'k10b petrol engine', 'k12m petrol engine', 'k14b petrol engine',
#        'k14b vvt engine', 'k15 smart hybrid', 'k15b', 'k15b vvt engine',
#        'k4m petrol engine', 'k9k dci diesel engine', 'k9k diesel engine',
#        'k9k in-line diesel engine', 'kappa 1.0 l turbo gdi petrol',
#        'kappa 1.2 l mpi petrol', 'kappa dual vtvt petrol en',
#        'kappa dual vtvt petrol engine', 'kappa engine',
#        'kappa petrol engine', 'kappa vtvt petrol engine',
#        'kryotec 2.0 l turbocharged', 'kryotec 2.0lturbocharged engine',
#        'm 264 petrol engine', 'm2dicr diesel  engine',
#        'm2dicr diesel engine', 'm2dicr engine', 'm9r diesel engine',
#        'mcr100 diesel engine', 'mdi 3200tc engine',
#        'mdi crde diesel engine', 'meagle diesel engine',
#        'mfalcon d75 engine', 'mfalcon g80', 'mfalcon g80 engine',
#        'mhawk 100 diesel engine', 'mhawk 120 diesel engine',
#        'mhawk 130 engine', 'mhawk 80 diesel engine', 'mhawk crde engine',
#        'mhawk d70 diesel engine', 'mhawk diesel  engine',
#        'mhawk diesel engine', 'mhawk155 diesel engine',
#        'motronic engine managemen', 'mpfi petrol engine',
#        'mpi petrol engine', 'mpower petrol engine', 'multijet',
#        'multijet diesel engine', 'multijet engine',
#        'naturally aspirated 12v', 'naturally aspirated 12v dohc efi',
#        'nef tci- crde diesel engi', 'nef tci-crde engine',
#        'nu 2.0 mpi petrol engine', 'nu 2.0 petrol',
#        'om 654 diesel engine', 'petrol engine', 'petroll engine',
#        'quadrajet diesel engine', 'quadrajet engine', 'quattro engine',
#        'revotorq engine', 'revotorq, 1.5l turbocharged engine',
#        'revotron 1.2l turbocharged engine', 'revotron engine',
#        'rx270 xdi diesel engine', 'rx270 xvt diesel engine',
#        's-tec ii engine', 'sd4 diesel  engine', 'sd4 diesel engine',
#        'sdrive20d diesel engine', 'si4 petrol engine',
#        'smartech diesel engine', 'smartech engine',
#        'smartech petrol engine', 'smartstream g1.0 t - gdi',
#        'smartstream g1.0 t-gdi', 'smartstream g1.2', 'smartstream g1.4',
#        'smartstream g1.4 t-gdi', 'smartstream g1.5',
#        'smartstream g1.5 t-gdi', 'sohc d-4d diesel engine', 'sohc i-vtec',
#        'sohc i-vtec bs6 petrol engine', 'sohc irde2 engine',
#        'sz crde diesel engine', 'sz crde, 4 stroke, turbo',
#        't-jet petrol engine', 'tcdi diesel engine',
#        'tcic common rail diesel engine', 'td4 diesel engine',
#        'tdci diesel engine', 'tdci engine', 'tdi diesel engine',
#        'tdi engine', 'tdi quattro diesel engine', 'tdi quattro engine',
#        'tfsi engine', 'tfsi petrol engine', 'ti vct petrol engine',
#        'ti-vct petrol engine', 'tsi petrol engine', 'turbo diesel engine',
#        'turbo petrol engine', 'turbocharged diesel engin',
#        'turbocharged intercooled', 'turbocharged petrol engin',
#        'twin turbo diesel engine', 'twin turbocharger v8 engi',
#        'twinpower turbo 4 cylinder engine',
#        'twinpower turbo 4 cylinder petrol engine',
#        'twinpower turbo 4-cylinder diesel engine',
#        'twinpower turbo 4-cylinder engine',
#        'twinpower turbo 4-cylinder petrol engine',
#        'twinpower turbo 6-cylinder engine',
#        'twinpower turbo inline 4 cylinder engine',
#        'twinpower turbo inline 6 cylinder engine',
#        'u2 crdi  diesel engine', 'u2 crdi diesel',
#        'u2 crdi diesel  engine', 'u2 crdi diesel engine',
#        'u2 crdi engine', 'u2 crdi vgt engine', 'u2 diesel engine',
#        'u2 vgt crdi diesel engine', 'u2 vgt diesel engine',
#        'v type diesel engine', 'v type engine', 'v type petrol engine',
#        'v-shaped petrol engine', 'v-type diesel engine', 'v-type engine',
#        'v-type petrol engine', 'v-type supercharged engin',
#        'v12 petrol engine', 'v4 petrol engine', 'v4 twin turbo engine',
#        'v6 diesel engine', 'v6 petrol engine', 'v6 tfsi petrol engine',
#        'v8 diesel engine', 'v8 petrol engine', 'varicor diesel engine',
#        'vcdi diesel engine', 'vgs turbo diesel engine',
#        'vgt crdi diesel engine', 'vgt diesel engine', 'vtt dicor engine',
#        'vtt varicor diesel engine', 'vtvt engine', 'vtvt petrol engine',
#        'vvt petrol engine', 'xdrive20d diesel engine',
#        'xdrive20d inline diesel engine', 'xdrive30d diesel engine',
#        'xh2 petrol engine', 'xh5 in-line petrol engine', 'xsde engine'],
#       dtype=object), 'Gear Box': array(['4 speed', '5 speed', '6 speed', '7 speed', '8 speed', '9 speed',
#        'cvt', 'direct drive'], dtype=object), 'Drive Type': array(['2wd', '4wd', '4x2', 'awd', 'fwd', 'rwd'], dtype=object), 'Steering Type': array(['manual', 'power'], dtype=object), 'Front Brake Type': array(['caliper', 'disc', 'disc & drum', 'drum', 'ventilated disc'],
#       dtype=object), 'Rear Brake Type': array(['caliper', 'disc', 'disc & drum', 'drum', 'ventilated disc'],
#       dtype=object), 'Tyre Type': array(['runflat', 'tubeless', 'tubeless radial'], dtype=object), 'owner_type': array(['fifth', 'first', 'fourth', 'second', 'third', 'unregistered car'],
#       dtype=object), 'Fuel Suppy System': array(['Common Rail Injection', 'Diesel Direct Injection',
#        'Direct Injection', 'Distributor-Type Fuel Injection',
#        'Electronic Fuel Injection', 'Gasoline Direct Injection',
#        'Gasoline Port Injection', 'Indirect Injection',
#        'Intake Port Injection', 'Multi-Point Fuel Injection',
#        'Three-Phase AC Induction Motors', 'Turbo Intercooled Diesel',
#        'Variable Valve Timing Injection'], dtype=object)}

# %%
# 현재 데이터 세트 확인
pre_c_df
# Out:
#        myear body transmission fuel        km  ip oem model variant  \
# 1       2015    2            1    0   45864.0   0  22   150    1381
# 3       2013    2            1    0  115893.0   0  22   167    1546
# 7       2017    2            1    0   58000.0   0  12    85     111
# 8       2021    2            1    0   54097.0   0  22   167    1114
# 10      2018    2            1    0   98083.0   0  22   150    2144
# ...      ...  ...          ...  ...       ...  ..  ..   ...     ...
# 37806   2018    9            1    1   66000.0   0  33   241     349
# 37808   2018    9            1    1   49882.0   0  33   241     354
# 37809   2011    8            1    1   82843.0   0  33   238    1042
# 37811   2014    2            1    1   62000.0   0  33   236    1503
# 37812   2018    8            1    1   54000.0   0  33   246      62
#
#        discountValue  ... Compression Ratio Alloy Wheel Size  \
# 1                  0  ...              11.0             16.0
# 3                  0  ...              10.8             13.0
# 7                  0  ...              10.8             16.0
# 8                  0  ...              10.8             16.0
# 10                 0  ...              11.0             16.0
# ...              ...  ...               ...              ...
# 37806              0  ...              10.8             16.0
# 37808              0  ...              10.8             16.0
# 37809              0  ...              10.8             15.0
# 37811              0  ...              10.8             16.0
# 37812              0  ...              16.0             14.0
#
#       Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 1                        190.0                58.20        6000.0
# 3                        190.0                58.20        6200.0
# 7                        190.0                65.39        6000.0
# 8                        190.0                58.33        5500.0
# 10                       190.0                58.33        6000.0
# ...                        ...                  ...           ...
# 37806                    209.0               108.50        3750.0
# 37808                    209.0               108.50        3750.0
# 37809                    190.0                88.80        4000.0
# 37811                    190.0                69.00        4000.0
# 37812                    190.0                69.00        4000.0
#
#        Max Torque Delivered  Max Torque At  Bore  Stroke    target
# 1                      78.0         3500.0  73.0    82.5  365000.0
# 3                      77.0         3500.0  73.0    82.5  240000.0
# 7                      98.0         4000.0  73.0    82.5  465000.0
# 8                      78.0         3500.0  73.0    82.5  560000.0
# 10                     78.0         3500.0  73.0    82.5  425000.0
# ...                     ...            ...   ...     ...       ...
# 37806                 260.0         2125.0  76.0    82.5  760000.0
# 37808                 260.0         2125.0  76.0    82.5  881000.0
# 37809                 200.0         2375.0  73.0    82.5  245000.0
# 37811                 140.0         2400.0  73.0    82.5  225000.0
# 37812                 140.0         2400.0  75.0    82.5  530000.0
#
# [28675 rows x 49 columns]

# %%
# 현재 데이터 세트의 정보 출력
pre_c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28675 entries, 1 to 37812
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   myear                     28675 non-null  int64
#  1   body                      28675 non-null  object
#  2   transmission              28675 non-null  object
#  3   fuel                      28675 non-null  object
#  4   km                        28675 non-null  float64
#  5   ip                        28675 non-null  int64
#  6   oem                       28675 non-null  object
#  7   model                     28675 non-null  object
#  8   variant                   28675 non-null  object
#  9   discountValue             28675 non-null  int64
#  10  utype                     28675 non-null  object
#  11  carType                   28675 non-null  object
#  12  Engine Type               28675 non-null  object
#  13  No of Cylinder            28675 non-null  float64
#  14  Valves per Cylinder       28675 non-null  float64
#  15  Turbo Charger             28675 non-null  bool
#  16  Super Charger             28675 non-null  bool
#  17  Length                    28675 non-null  float64
#  18  Width                     28675 non-null  float64
#  19  Height                    28675 non-null  float64
#  20  Wheel Base                28675 non-null  float64
#  21  Front Tread               28675 non-null  float64
#  22  Rear Tread                28675 non-null  float64
#  23  Kerb Weight               28675 non-null  float64
#  24  Gross Weight              28675 non-null  float64
#  25  Gear Box                  28675 non-null  object
#  26  Drive Type                28675 non-null  object
#  27  Seats                     28675 non-null  float64
#  28  Steering Type             28675 non-null  object
#  29  Turning Radius            28675 non-null  float64
#  30  Front Brake Type          28675 non-null  object
#  31  Rear Brake Type           28675 non-null  object
#  32  Top Speed                 28675 non-null  float64
#  33  Acceleration              28675 non-null  float64
#  34  Tyre Type                 28675 non-null  object
#  35  Doors                     28675 non-null  float64
#  36  Cargo Volume              28675 non-null  float64
#  37  owner_type                28675 non-null  object
#  38  Fuel Suppy System         28675 non-null  object
#  39  Compression Ratio         28675 non-null  float64
#  40  Alloy Wheel Size          28675 non-null  float64
#  41  Ground Clearance Unladen  28675 non-null  float64
#  42  Max Power Delivered       28675 non-null  float64
#  43  Max Power At              28675 non-null  float64
#  44  Max Torque Delivered      28675 non-null  float64
#  45  Max Torque At             28675 non-null  float64
#  46  Bore                      28675 non-null  float64
#  47  Stroke                    28675 non-null  float64
#  48  target                    28675 non-null  float64
# dtypes: bool(2), float64(27), int64(3), object(17)
# memory usage: 10.6+ MB

# %%
# 레이블 인코딩 한 컬럼들의 데이터 타입을 int로 변경
for column in object_columns:
    pre_c_df[column] = pre_c_df[column].astype(np.int64)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2630121914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)

# %%
# 현재 데이터 세트의 정보 출력
pre_c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28675 entries, 1 to 37812
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   myear                     28675 non-null  int64
#  1   body                      28675 non-null  int64
#  2   transmission              28675 non-null  int64
#  3   fuel                      28675 non-null  int64
#  4   km                        28675 non-null  float64
#  5   ip                        28675 non-null  int64
#  6   oem                       28675 non-null  int64
#  7   model                     28675 non-null  int64
#  8   variant                   28675 non-null  int64
#  9   discountValue             28675 non-null  int64
#  10  utype                     28675 non-null  int64
#  11  carType                   28675 non-null  int64
#  12  Engine Type               28675 non-null  int64
#  13  No of Cylinder            28675 non-null  float64
#  14  Valves per Cylinder       28675 non-null  float64
#  15  Turbo Charger             28675 non-null  bool
#  16  Super Charger             28675 non-null  bool
#  17  Length                    28675 non-null  float64
#  18  Width                     28675 non-null  float64
#  19  Height                    28675 non-null  float64
#  20  Wheel Base                28675 non-null  float64
#  21  Front Tread               28675 non-null  float64
#  22  Rear Tread                28675 non-null  float64
#  23  Kerb Weight               28675 non-null  float64
#  24  Gross Weight              28675 non-null  float64
#  25  Gear Box                  28675 non-null  int64
#  26  Drive Type                28675 non-null  int64
#  27  Seats                     28675 non-null  float64
#  28  Steering Type             28675 non-null  int64
#  29  Turning Radius            28675 non-null  float64
#  30  Front Brake Type          28675 non-null  int64
#  31  Rear Brake Type           28675 non-null  int64
#  32  Top Speed                 28675 non-null  float64
#  33  Acceleration              28675 non-null  float64
#  34  Tyre Type                 28675 non-null  int64
#  35  Doors                     28675 non-null  float64
#  36  Cargo Volume              28675 non-null  float64
#  37  owner_type                28675 non-null  int64
#  38  Fuel Suppy System         28675 non-null  int64
#  39  Compression Ratio         28675 non-null  float64
#  40  Alloy Wheel Size          28675 non-null  float64
#  41  Ground Clearance Unladen  28675 non-null  float64
#  42  Max Power Delivered       28675 non-null  float64
#  43  Max Power At              28675 non-null  float64
#  44  Max Torque Delivered      28675 non-null  float64
#  45  Max Torque At             28675 non-null  float64
#  46  Bore                      28675 non-null  float64
#  47  Stroke                    28675 non-null  float64
#  48  target                    28675 non-null  float64
# dtypes: bool(2), float64(27), int64(20)
# memory usage: 10.6 MB

# %%
# 일부 float타입 컬럼들과 bool타입 컬럼의 데이터 타입을 int타입으로 변경
# StandardScaler를 통한 이상치 제거 과정의 편의를 위한 전처리
columns = ['km', 'Turbo Charger', 'Super Charger', 'No of Cylinder', 'Valves per Cylinder', 'Seats', 'Doors', 'target']

for column in columns:
    pre_c_df[column] = pre_c_df[column].astype(np.int64)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)
# C:\Users\User\AppData\Local\Temp\ipykernel_10172\2048862895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_c_df[column] = pre_c_df[column].astype(np.int64)

# %%
# 현재 데이터 세트의 정보 출력
pre_c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28675 entries, 1 to 37812
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   myear                     28675 non-null  int64
#  1   body                      28675 non-null  int64
#  2   transmission              28675 non-null  int64
#  3   fuel                      28675 non-null  int64
#  4   km                        28675 non-null  int64
#  5   ip                        28675 non-null  int64
#  6   oem                       28675 non-null  int64
#  7   model                     28675 non-null  int64
#  8   variant                   28675 non-null  int64
#  9   discountValue             28675 non-null  int64
#  10  utype                     28675 non-null  int64
#  11  carType                   28675 non-null  int64
#  12  Engine Type               28675 non-null  int64
#  13  No of Cylinder            28675 non-null  int64
#  14  Valves per Cylinder       28675 non-null  int64
#  15  Turbo Charger             28675 non-null  int64
#  16  Super Charger             28675 non-null  int64
#  17  Length                    28675 non-null  float64
#  18  Width                     28675 non-null  float64
#  19  Height                    28675 non-null  float64
#  20  Wheel Base                28675 non-null  float64
#  21  Front Tread               28675 non-null  float64
#  22  Rear Tread                28675 non-null  float64
#  23  Kerb Weight               28675 non-null  float64
#  24  Gross Weight              28675 non-null  float64
#  25  Gear Box                  28675 non-null  int64
#  26  Drive Type                28675 non-null  int64
#  27  Seats                     28675 non-null  int64
#  28  Steering Type             28675 non-null  int64
#  29  Turning Radius            28675 non-null  float64
#  30  Front Brake Type          28675 non-null  int64
#  31  Rear Brake Type           28675 non-null  int64
#  32  Top Speed                 28675 non-null  float64
#  33  Acceleration              28675 non-null  float64
#  34  Tyre Type                 28675 non-null  int64
#  35  Doors                     28675 non-null  int64
#  36  Cargo Volume              28675 non-null  float64
#  37  owner_type                28675 non-null  int64
#  38  Fuel Suppy System         28675 non-null  int64
#  39  Compression Ratio         28675 non-null  float64
#  40  Alloy Wheel Size          28675 non-null  float64
#  41  Ground Clearance Unladen  28675 non-null  float64
#  42  Max Power Delivered       28675 non-null  float64
#  43  Max Power At              28675 non-null  float64
#  44  Max Torque Delivered      28675 non-null  float64
#  45  Max Torque At             28675 non-null  float64
#  46  Bore                      28675 non-null  float64
#  47  Stroke                    28675 non-null  float64
#  48  target                    28675 non-null  int64
# dtypes: float64(21), int64(28)
# memory usage: 10.9 MB

# %% [markdown]
# #### 이후 과정
# - StandardScaler로 이상치 제거
# - discountValue의 이상치(1) 제거

# %%
# 데이터 세트 내 컬럼들 중 문자열 데이터가 담긴 컬럼들만 가져오기
columns = pre_c_df.columns
float_columns = []

for column in columns:
    if pre_c_df[column].dtype == 'float64':
        float_columns.append(column)

float_columns
# Out:
# ['Length',
#  'Width',
#  'Height',
#  'Wheel Base',
#  'Front Tread',
#  'Rear Tread',
#  'Kerb Weight',
#  'Gross Weight',
#  'Turning Radius',
#  'Top Speed',
#  'Acceleration',
#  'Cargo Volume',
#  'Compression Ratio',
#  'Alloy Wheel Size',
#  'Ground Clearance Unladen',
#  'Max Power Delivered',
#  'Max Power At',
#  'Max Torque Delivered',
#  'Max Torque At',
#  'Bore',
#  'Stroke']

# %%
from sklearn.preprocessing import StandardScaler
# float형 컬럼들만 StandardScaler 적용한 새로운 데이터 세트 생성

std = StandardScaler()
result = std.fit_transform(pre_c_df.loc[:, float_columns])
std_pre_c_df = pd.DataFrame(result, columns=pre_c_df.loc[:, float_columns].columns)
std_pre_c_df
# Out:
#          Length     Width    Height  Wheel Base  Front Tread  Rear Tread  \
# 0     -1.296759 -1.000288 -0.118733   -0.797016    -0.881680   -0.932005
# 1     -1.309335 -1.977734  1.114623   -0.959576    -2.746442   -2.486378
# 2     -0.881774 -0.531115 -0.471120   -0.797016    -0.001512    0.143102
# 3     -1.158431 -0.843897  0.894381   -0.731992     0.087997    0.143102
# 4     -1.057828 -1.000288 -0.118733   -0.797016    -0.881680   -0.932005
# ...         ...       ...       ...         ...          ...         ...
# 28670 -0.305825  0.649640  0.295322   -0.322341     0.908492    0.622367
# 28671 -0.305825  0.649640  0.295322   -0.322341     0.908492    0.622367
# 28672  0.747985 -0.194873 -0.206830   -0.179288     0.087997    0.143102
# 28673 -1.070404 -0.492017 -0.779459   -0.959576     0.087997    0.143102
# 28674 -0.310855 -0.398182 -0.321356   -0.634456    -1.180042   -0.802474
#
#        Kerb Weight  Gross Weight  Turning Radius  Top Speed  ...  \
# 0        -0.799343     -1.092352       -0.889938  -1.074380  ...
# 1        -0.625416     -1.092352       -1.099082  -0.114470  ...
# 2        -0.215720     -0.143054       -0.680795  -0.354447  ...
# 3        -0.837994     -1.125087       -0.889938  -0.114470  ...
# 4        -0.760693     -1.092352       -0.889938  -1.074380  ...
# ...            ...           ...             ...        ...  ...
# 28670     0.708027     -0.143054       -0.053364  -0.873279  ...
# 28671     0.708027     -0.143054       -0.053364  -0.873279  ...
# 28672     0.302196     -0.110320       -0.053364  -0.114470  ...
# 28673    -0.161610     -0.143054       -0.471651  -0.834403  ...
# 28674    -0.007008     -0.143054        0.155779  -0.114470  ...
#
#        Cargo Volume  Compression Ratio  Alloy Wheel Size  \
# 0         -1.071388          -0.150018          0.278625
# 1         -0.117184          -0.214715         -2.221503
# 2         -0.897142          -0.214715          0.278625
# 3         -0.191861          -0.214715          0.278625
# 4         -1.071388          -0.150018          0.278625
# ...             ...                ...               ...
# 28670     -0.117184          -0.214715          0.278625
# 28671     -0.117184          -0.214715          0.278625
# 28672      0.795532          -0.214715         -0.554751
# 28673     -1.195849          -0.214715          0.278625
# 28674      0.455338           1.467408         -1.388127
#
#        Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                      0.091954            -1.066772      0.899596
# 1                      0.091954            -1.066772      1.087416
# 2                      0.091954            -0.892598      0.899596
# 3                      0.091954            -1.063622      0.430047
# 4                      0.091954            -1.063622      0.899596
# ...                         ...                  ...           ...
# 28670                  2.676641             0.151720     -1.213378
# 28671                  2.676641             0.151720     -1.213378
# 28672                  0.091954            -0.325502     -0.978603
# 28673                  0.091954            -0.805147     -0.978603
# 28674                  0.091954            -0.805147     -0.978603
#
#        Max Torque Delivered  Max Torque At      Bore    Stroke
# 0                 -1.053832       0.354167  0.028037 -0.026909
# 1                 -1.063573       0.354167  0.028037 -0.026909
# 2                 -0.859007       0.837608  0.028037 -0.026909
# 3                 -1.053832       0.354167  0.028037 -0.026909
# 4                 -1.053832       0.354167  0.028037 -0.026909
# ...                     ...            ...       ...       ...
# 28670              0.719076      -0.975297  0.436483 -0.026909
# 28671              0.719076      -0.975297  0.436483 -0.026909
# 28672              0.134601      -0.733577  0.028037 -0.026909
# 28673             -0.449874      -0.709405  0.028037 -0.026909
# 28674             -0.449874      -0.709405  0.300334 -0.026909
#
# [28675 rows x 21 columns]

# %%
condition = True

# 반복문으로 각 컬럼에서 -1.96 ~ 1.96 사이의 데이터만 가져오는 조건식 생성
for column in std_pre_c_df.columns:
    condition &= std_pre_c_df[column].between(-1.96, 1.96)

# 위 조건에 맞지 않는 데이터 삭제
std_pre_c_df = std_pre_c_df[condition]
std_pre_c_df
# Out:
#          Length     Width    Height  Wheel Base  Front Tread  Rear Tread  \
# 0     -1.296759 -1.000288 -0.118733   -0.797016    -0.881680   -0.932005
# 2     -0.881774 -0.531115 -0.471120   -0.797016    -0.001512    0.143102
# 4     -1.057828 -1.000288 -0.118733   -0.797016    -0.881680   -0.932005
# 5     -1.057828 -1.000288 -0.118733   -0.797016    -0.881680   -0.932005
# 6      0.453723 -0.257430  0.982477    1.251239     0.013406    0.104243
# ...         ...       ...       ...         ...          ...         ...
# 28665 -0.929560 -0.632769 -0.338975   -0.959576    -1.180042   -0.802474
# 28666  1.213272  1.298663  1.167481    1.257741     0.087997    0.143102
# 28672  0.747985 -0.194873 -0.206830   -0.179288     0.087997    0.143102
# 28673 -1.070404 -0.492017 -0.779459   -0.959576     0.087997    0.143102
# 28674 -0.310855 -0.398182 -0.321356   -0.634456    -1.180042   -0.802474
#
#        Kerb Weight  Gross Weight  Turning Radius  Top Speed  ...  \
# 0        -0.799343     -1.092352       -0.889938  -1.074380  ...
# 2        -0.215720     -0.143054       -0.680795  -0.354447  ...
# 4        -0.760693     -1.092352       -0.889938  -1.074380  ...
# 5        -0.780018     -1.092352       -0.889938  -1.074380  ...
# 6         0.514774     -0.143054        0.155779  -0.402443  ...
# ...            ...           ...             ...        ...  ...
# 28665    -0.316212     -0.143054       -0.471651  -1.074380  ...
# 28666    -0.215720     -0.143054        0.155779  -0.114470  ...
# 28672     0.302196     -0.110320       -0.053364  -0.114470  ...
# 28673    -0.161610     -0.143054       -0.471651  -0.834403  ...
# 28674    -0.007008     -0.143054        0.155779  -0.114470  ...
#
#        Cargo Volume  Compression Ratio  Alloy Wheel Size  \
# 0         -1.071388          -0.150018          0.278625
# 2         -0.897142          -0.214715          0.278625
# 4         -1.071388          -0.150018          0.278625
# 5         -1.071388          -0.150018          0.278625
# 6         -1.901130          -0.150018          0.278625
# ...             ...                ...               ...
# 28665     -1.013306           1.467408          0.278625
# 28666      0.505122           1.629150          1.112001
# 28672      0.795532          -0.214715         -0.554751
# 28673     -1.195849          -0.214715          0.278625
# 28674      0.455338           1.467408         -1.388127
#
#        Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                      0.091954            -1.066772      0.899596
# 2                      0.091954            -0.892598      0.899596
# 4                      0.091954            -1.063622      0.899596
# 5                      0.091954            -1.063622      0.899596
# 6                      0.091954            -0.527534      0.899596
# ...                         ...                  ...           ...
# 28665                  0.091954            -0.805147     -0.978603
# 28666                  0.091954             0.868765     -1.213378
# 28672                  0.091954            -0.325502     -0.978603
# 28673                  0.091954            -0.805147     -0.978603
# 28674                  0.091954            -0.805147     -0.978603
#
#        Max Torque Delivered  Max Torque At      Bore    Stroke
# 0                 -1.053832       0.354167  0.028037 -0.026909
# 2                 -0.859007       0.837608  0.028037 -0.026909
# 4                 -1.053832       0.354167  0.028037 -0.026909
# 5                 -1.053832       0.354167  0.028037 -0.026909
# 6                 -0.722629       0.837608  0.028037 -0.026909
# ...                     ...            ...       ...       ...
# 28665             -0.449874      -0.709405  0.300334 -0.026909
# 28666              1.595788      -0.975297  0.028037 -0.026909
# 28672              0.134601      -0.733577  0.028037 -0.026909
# 28673             -0.449874      -0.709405  0.028037 -0.026909
# 28674             -0.449874      -0.709405  0.300334 -0.026909
#
# [17830 rows x 21 columns]

# %%
# 이상치가 없는 인덱스만 유지하고 인덱스 초기화
pre_c_df = pre_c_df.iloc[std_pre_c_df.index].reset_index(drop=True)
pre_c_df
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  \
# 0       2015     2             1     0  45864   0   22    150     1381
# 1       2017     2             1     0  58000   0   12     85      111
# 2       2018     2             1     0  98083   0   22    150     2144
# 3       2019     2             1     0  80000   0   22    150     2141
# 4       2017     6             1     0  39000   0   22    155     2140
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...
# 17825   2018     2             1     1  63000   0   33    244       58
# 17826   2019     9             1     1  96029   0   33    233     2281
# 17827   2011     8             1     1  82843   0   33    238     1042
# 17828   2014     2             1     1  62000   0   33    236     1503
# 17829   2018     8             1     1  54000   0   33    246       62
#
#        discountValue  ...  Compression Ratio  Alloy Wheel Size  \
# 0                  0  ...               11.0              16.0
# 1                  0  ...               10.8              16.0
# 2                  0  ...               11.0              16.0
# 3                  0  ...               11.0              16.0
# 4                  0  ...               11.0              16.0
# ...              ...  ...                ...               ...
# 17825              0  ...               16.0              16.0
# 17826              0  ...               16.5              17.0
# 17827              0  ...               10.8              15.0
# 17828              0  ...               10.8              16.0
# 17829              0  ...               16.0              14.0
#
#        Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                         190.0                58.20        6000.0
# 1                         190.0                65.39        6000.0
# 2                         190.0                58.33        6000.0
# 3                         190.0                58.33        6000.0
# 4                         190.0                80.46        6000.0
# ...                         ...                  ...           ...
# 17825                     190.0                69.00        4000.0
# 17826                     190.0               138.10        3750.0
# 17827                     190.0                88.80        4000.0
# 17828                     190.0                69.00        4000.0
# 17829                     190.0                69.00        4000.0
#
#        Max Torque Delivered  Max Torque At  Bore  Stroke   target
# 0                      78.0         3500.0  73.0    82.5   365000
# 1                      98.0         4000.0  73.0    82.5   465000
# 2                      78.0         3500.0  73.0    82.5   425000
# 3                      78.0         3500.0  73.0    82.5   380000
# 4                     112.0         4000.0  73.0    82.5   795000
# ...                     ...            ...   ...     ...      ...
# 17825                 140.0         2400.0  75.0    82.5   460000
# 17826                 350.0         2125.0  73.0    82.5  1293000
# 17827                 200.0         2375.0  73.0    82.5   245000
# 17828                 140.0         2400.0  73.0    82.5   225000
# 17829                 140.0         2400.0  75.0    82.5   530000
#
# [17830 rows x 49 columns]

# %%
# discountValue의 클래스 값들 출력
pre_c_df.discountValue.unique()
# Out:
# array([    0, 24000, 30000,  5000, 65000, 10000,  3000, 36000,  7000,
#        57000, 37000, 32000, 21000,  4000, 50000, 14000, 15000],
#       dtype=int64)

# %%
# target에 discountValue 적용 후, discountValue 제거
pre_c_df.loc[:, 'target'] = pre_c_df.target - pre_c_df.discountValue
pre_c_df = pre_c_df.drop(labels=['discountValue'], axis=1)
pre_c_df
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0       2015     2             1     0  45864   0   22    150     1381      0
# 1       2017     2             1     0  58000   0   12     85      111      0
# 2       2018     2             1     0  98083   0   22    150     2144      0
# 3       2019     2             1     0  80000   0   22    150     2141      1
# 4       2017     6             1     0  39000   0   22    155     2140      0
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 17825   2018     2             1     1  63000   0   33    244       58      0
# 17826   2019     9             1     1  96029   0   33    233     2281      0
# 17827   2011     8             1     1  82843   0   33    238     1042      0
# 17828   2014     2             1     1  62000   0   33    236     1503      0
# 17829   2018     8             1     1  54000   0   33    246       62      0
#
#        ...  Compression Ratio  Alloy Wheel Size  Ground Clearance Unladen  \
# 0      ...               11.0              16.0                     190.0
# 1      ...               10.8              16.0                     190.0
# 2      ...               11.0              16.0                     190.0
# 3      ...               11.0              16.0                     190.0
# 4      ...               11.0              16.0                     190.0
# ...    ...                ...               ...                       ...
# 17825  ...               16.0              16.0                     190.0
# 17826  ...               16.5              17.0                     190.0
# 17827  ...               10.8              15.0                     190.0
# 17828  ...               10.8              16.0                     190.0
# 17829  ...               16.0              14.0                     190.0
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 0                    58.20        6000.0                  78.0         3500.0
# 1                    65.39        6000.0                  98.0         4000.0
# 2                    58.33        6000.0                  78.0         3500.0
# 3                    58.33        6000.0                  78.0         3500.0
# 4                    80.46        6000.0                 112.0         4000.0
# ...                    ...           ...                   ...            ...
# 17825                69.00        4000.0                 140.0         2400.0
# 17826               138.10        3750.0                 350.0         2125.0
# 17827                88.80        4000.0                 200.0         2375.0
# 17828                69.00        4000.0                 140.0         2400.0
# 17829                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke   target
# 0      73.0    82.5   365000
# 1      73.0    82.5   465000
# 2      73.0    82.5   425000
# 3      73.0    82.5   380000
# 4      73.0    82.5   795000
# ...     ...     ...      ...
# 17825  75.0    82.5   460000
# 17826  73.0    82.5  1293000
# 17827  73.0    82.5   245000
# 17828  73.0    82.5   225000
# 17829  75.0    82.5   530000
#
# [17830 rows x 48 columns]

# %%
# 현재 target 값이 0 이하인 데이터가 있는지 확인
# 모델 학습 과정에서 발생할 수 있는 이슈를 사전에 방지하기 위함
pre_c_df[pre_c_df.target <= 0]
# Out:
# Empty DataFrame
# Columns: [myear, body, transmission, fuel, km, ip, oem, model, variant, utype, carType, Engine Type, No of Cylinder, Valves per Cylinder, Turbo Charger, Super Charger, Length, Width, Height, Wheel Base, Front Tread, Rear Tread, Kerb Weight, Gross Weight, Gear Box, Drive Type, Seats, Steering Type, Turning Radius, Front Brake Type, Rear Brake Type, Top Speed, Acceleration, Tyre Type, Doors, Cargo Volume, owner_type, Fuel Suppy System, Compression Ratio, Alloy Wheel Size, Ground Clearance Unladen, Max Power Delivered, Max Power At, Max Torque Delivered, Max Torque At, Bore, Stroke, target]
# Index: []
#
# [0 rows x 48 columns]

# %%
# 현재 target의 데이터 분포 출력
pre_c_df.target.hist()
# Out:
# <Axes: >

# %%
# 현재 target의 수치 데이터 출력
pre_c_df.target.describe().T
# Out:
# count    1.783000e+04
# mean     6.214049e+05
# std      4.129387e+06
# min      5.000000e+04
# 25%      3.629362e+05
# 50%      5.200000e+05
# 75%      7.250000e+05
# max      5.500006e+08
# Name: target, dtype: float64

# %%
# target 값이 200만 이상인 데이터 삭제 후 인덱스 초기화
pre_c_df = pre_c_df[pre_c_df.target < 2000000].reset_index(drop=True)
pre_c_df
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0       2015     2             1     0  45864   0   22    150     1381      0
# 1       2017     2             1     0  58000   0   12     85      111      0
# 2       2018     2             1     0  98083   0   22    150     2144      0
# 3       2019     2             1     0  80000   0   22    150     2141      1
# 4       2017     6             1     0  39000   0   22    155     2140      0
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 17754   2018     2             1     1  63000   0   33    244       58      0
# 17755   2019     9             1     1  96029   0   33    233     2281      0
# 17756   2011     8             1     1  82843   0   33    238     1042      0
# 17757   2014     2             1     1  62000   0   33    236     1503      0
# 17758   2018     8             1     1  54000   0   33    246       62      0
#
#        ...  Compression Ratio  Alloy Wheel Size  Ground Clearance Unladen  \
# 0      ...               11.0              16.0                     190.0
# 1      ...               10.8              16.0                     190.0
# 2      ...               11.0              16.0                     190.0
# 3      ...               11.0              16.0                     190.0
# 4      ...               11.0              16.0                     190.0
# ...    ...                ...               ...                       ...
# 17754  ...               16.0              16.0                     190.0
# 17755  ...               16.5              17.0                     190.0
# 17756  ...               10.8              15.0                     190.0
# 17757  ...               10.8              16.0                     190.0
# 17758  ...               16.0              14.0                     190.0
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 0                    58.20        6000.0                  78.0         3500.0
# 1                    65.39        6000.0                  98.0         4000.0
# 2                    58.33        6000.0                  78.0         3500.0
# 3                    58.33        6000.0                  78.0         3500.0
# 4                    80.46        6000.0                 112.0         4000.0
# ...                    ...           ...                   ...            ...
# 17754                69.00        4000.0                 140.0         2400.0
# 17755               138.10        3750.0                 350.0         2125.0
# 17756                88.80        4000.0                 200.0         2375.0
# 17757                69.00        4000.0                 140.0         2400.0
# 17758                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke   target
# 0      73.0    82.5   365000
# 1      73.0    82.5   465000
# 2      73.0    82.5   425000
# 3      73.0    82.5   380000
# 4      73.0    82.5   795000
# ...     ...     ...      ...
# 17754  75.0    82.5   460000
# 17755  73.0    82.5  1293000
# 17756  73.0    82.5   245000
# 17757  73.0    82.5   225000
# 17758  75.0    82.5   530000
#
# [17759 rows x 48 columns]

# %%
# 현재 target의 수치 데이터 출력
pre_c_df.target.describe().T
# Out:
# count    1.775900e+04
# mean     5.826898e+05
# std      3.203822e+05
# min      5.000000e+04
# 25%      3.603195e+05
# 50%      5.200000e+05
# 75%      7.200000e+05
# max      1.999000e+06
# Name: target, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 폰트를 맑은 고딕으로 설정하고 한글 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 현재 target의 데이터 분포를 히스토그램으로 시각화
ax = sns.displot(pre_c_df.target, bins=15, kde=True)
plt.title('로그 변환 이전의 target 데이터 분포')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# target에 log를 취했을 때의 데이터 분포 시각화
# 현재 target의 데이터 분포를 히스토그램으로 시각화
sns.displot(np.log1p(pre_c_df.target), bins=15, kde=True)
plt.title('로그 변환 이후의 target 데이터 분포')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# log 변환 전후의 왜도 출력
print(pre_c_df.target.skew())
print(np.log1p(pre_c_df.target).skew())
# Out:
# 1.3181226096533245
# -0.3504468788591889

# %%
# target의 값을 로그를 취한 이후의 수치로 대체
pre_c_df.target = np.log1p(pre_c_df.target)
pre_c_df
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0       2015     2             1     0  45864   0   22    150     1381      0
# 1       2017     2             1     0  58000   0   12     85      111      0
# 2       2018     2             1     0  98083   0   22    150     2144      0
# 3       2019     2             1     0  80000   0   22    150     2141      1
# 4       2017     6             1     0  39000   0   22    155     2140      0
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 17754   2018     2             1     1  63000   0   33    244       58      0
# 17755   2019     9             1     1  96029   0   33    233     2281      0
# 17756   2011     8             1     1  82843   0   33    238     1042      0
# 17757   2014     2             1     1  62000   0   33    236     1503      0
# 17758   2018     8             1     1  54000   0   33    246       62      0
#
#        ...  Compression Ratio  Alloy Wheel Size  Ground Clearance Unladen  \
# 0      ...               11.0              16.0                     190.0
# 1      ...               10.8              16.0                     190.0
# 2      ...               11.0              16.0                     190.0
# 3      ...               11.0              16.0                     190.0
# 4      ...               11.0              16.0                     190.0
# ...    ...                ...               ...                       ...
# 17754  ...               16.0              16.0                     190.0
# 17755  ...               16.5              17.0                     190.0
# 17756  ...               10.8              15.0                     190.0
# 17757  ...               10.8              16.0                     190.0
# 17758  ...               16.0              14.0                     190.0
#
#        Max Power Delivered  Max Power At  Max Torque Delivered  Max Torque At  \
# 0                    58.20        6000.0                  78.0         3500.0
# 1                    65.39        6000.0                  98.0         4000.0
# 2                    58.33        6000.0                  78.0         3500.0
# 3                    58.33        6000.0                  78.0         3500.0
# 4                    80.46        6000.0                 112.0         4000.0
# ...                    ...           ...                   ...            ...
# 17754                69.00        4000.0                 140.0         2400.0
# 17755               138.10        3750.0                 350.0         2125.0
# 17756                88.80        4000.0                 200.0         2375.0
# 17757                69.00        4000.0                 140.0         2400.0
# 17758                69.00        4000.0                 140.0         2400.0
#
#        Bore  Stroke     target
# 0      73.0    82.5  12.807655
# 1      73.0    82.5  13.049795
# 2      73.0    82.5  12.959847
# 3      73.0    82.5  12.847929
# 4      73.0    82.5  13.586099
# ...     ...     ...        ...
# 17754  75.0    82.5  13.038984
# 17755  73.0    82.5  14.072476
# 17756  73.0    82.5  12.409018
# 17757  73.0    82.5  12.323860
# 17758  75.0    82.5  13.180634
#
# [17759 rows x 48 columns]

# %% [markdown]
# #### 중간 분석
# - log를 취한 이후, skew()로 출력한 왜도가 보다 0에 가까워진 것을 확인
# - 히스토그램 시각화 결과 역시, log를 취했을 때 데이터 분포 형태가 표준 정규 분포에 더 가까운 형태를 보임
# - 따라서 모델 학습은 로그를 취한 값을 적용 후 진행
# - 학습 후 예측하기 전, expm1() 함수를 취해 log 취하기 전 값으로 원복

# %%
# 각 feature 별 target과의 상관관계 출력
pre_c_df.corr()['target'].sort_values(ascending=False)[1:]
# Out:
# myear                       0.741956
# Width                       0.618547
# Max Power Delivered         0.523028
# Alloy Wheel Size            0.487393
# Wheel Base                  0.483912
# body                        0.432280
# Turning Radius              0.419528
# Length                      0.392115
# Gear Box                    0.366724
# Height                      0.357097
# Max Torque Delivered        0.349992
# Cargo Volume                0.333756
# Top Speed                   0.277526
# Super Charger               0.247421
# Turbo Charger               0.247421
# Rear Tread                  0.231008
# Front Tread                 0.220910
# Valves per Cylinder         0.204468
# No of Cylinder              0.181408
# Kerb Weight                 0.155873
# Compression Ratio           0.073072
# ip                          0.070492
# Steering Type               0.056802
# Seats                       0.030047
# Ground Clearance Unladen    0.010709
# Doors                      -0.004812
# Max Power At               -0.019154
# Gross Weight               -0.021497
# oem                        -0.031346
# Tyre Type                  -0.035021
# model                      -0.044125
# variant                    -0.054976
# fuel                       -0.059171
# Engine Type                -0.059917
# Drive Type                 -0.064363
# Max Torque At              -0.074415
# Bore                       -0.107755
# Fuel Suppy System          -0.135360
# utype                      -0.157507
# carType                    -0.166536
# Front Brake Type           -0.180727
# Rear Brake Type            -0.261964
# owner_type                 -0.271465
# Acceleration               -0.305820
# transmission               -0.307764
# km                         -0.339765
# Stroke                           NaN
# Name: target, dtype: float64

# %%
# 각 feature들 간 상관관계 시각화
sns.heatmap(pre_c_df.iloc[:, :-1].corr())
# Out:
# <Axes: >

# %%
pre_c_df.iloc[:, :-1].corr()
# Out:
#                              myear      body  transmission      fuel  \
# myear                     1.000000  0.100230     -0.158445  0.051812
# body                      0.100230  1.000000     -0.139436 -0.267938
# transmission             -0.158445 -0.139436      1.000000 -0.101722
# fuel                      0.051812 -0.267938     -0.101722  1.000000
# km                       -0.440841  0.082278      0.106145 -0.351519
# ip                        0.038945  0.029660     -0.051668  0.014703
# oem                      -0.007308  0.001356     -0.052328 -0.068135
# model                    -0.025123 -0.001435     -0.046362 -0.069342
# variant                  -0.026120 -0.000040      0.079096  0.046539
# utype                    -0.077420 -0.009538      0.078650 -0.118273
# carType                  -0.166672  0.069435      0.043499 -0.128538
# Engine Type              -0.077302 -0.078205      0.005714  0.124221
# No of Cylinder           -0.111559  0.276083     -0.018505 -0.091378
# Valves per Cylinder       0.143882  0.062229     -0.091714  0.105401
# Turbo Charger             0.073361  0.416270     -0.036409 -0.758921
# Super Charger             0.073361  0.416270     -0.036409 -0.758921
# Length                   -0.042442  0.721323     -0.163549 -0.208719
# Width                     0.277319  0.571388     -0.119956 -0.259961
# Height                    0.291455  0.344489     -0.003831 -0.185334
# Wheel Base                0.110229  0.545119     -0.141036 -0.237031
# Front Tread               0.080410  0.211555     -0.025255 -0.136388
# Rear Tread                0.118936  0.215541     -0.028663 -0.146511
# Kerb Weight              -0.102847  0.377035     -0.082211 -0.413549
# Gross Weight             -0.201459  0.307963     -0.021229 -0.279353
# Gear Box                  0.186897  0.225297     -0.393130 -0.051171
# Drive Type                0.041281 -0.132359      0.040598 -0.016679
# Seats                     0.055868  0.027099      0.046620 -0.074614
# Steering Type             0.000517  0.039576     -0.016319 -0.025775
# Turning Radius            0.076761  0.610447     -0.128205 -0.277709
# Front Brake Type         -0.216791  0.152618      0.076646 -0.098752
# Rear Brake Type          -0.014542 -0.278437      0.160992  0.132537
# Top Speed                -0.070963  0.407660     -0.136075 -0.095632
# Acceleration             -0.007085 -0.339463      0.138041  0.051378
# Tyre Type                -0.103289  0.261230     -0.056568 -0.099846
# Doors                     0.195853 -0.565820      0.085284  0.027659
# Cargo Volume             -0.018178  0.727250     -0.163746 -0.133263
# owner_type               -0.299196 -0.036228      0.018543 -0.040388
# Fuel Suppy System         0.090946 -0.363592      0.035653  0.695012
# Compression Ratio         0.008726  0.134805      0.030507 -0.386961
# Alloy Wheel Size          0.441790  0.203493     -0.120287 -0.074055
# Ground Clearance Unladen -0.055535  0.029378     -0.006494 -0.009660
# Max Power Delivered       0.068823  0.643167     -0.265912 -0.076424
# Max Power At              0.061749 -0.222558     -0.085318  0.903683
# Max Torque Delivered      0.009656  0.540150     -0.092136 -0.740695
# Max Torque At             0.028825 -0.252674     -0.059494  0.880123
# Bore                     -0.167389  0.041067     -0.064036  0.105588
# Stroke                         NaN       NaN           NaN       NaN
#
#                                 km        ip       oem     model   variant  \
# myear                    -0.440841  0.038945 -0.007308 -0.025123 -0.026120
# body                      0.082278  0.029660  0.001356 -0.001435 -0.000040
# transmission              0.106145 -0.051668 -0.052328 -0.046362  0.079096
# fuel                     -0.351519  0.014703 -0.068135 -0.069342  0.046539
# km                        1.000000 -0.041895  0.054742  0.062015 -0.031945
# ip                       -0.041895  1.000000 -0.002637 -0.004416 -0.005341
# oem                       0.054742 -0.002637  1.000000  0.994267  0.009945
# model                     0.062015 -0.004416  0.994267  1.000000  0.014386
# variant                  -0.031945 -0.005341  0.009945  0.014386  1.000000
# utype                     0.114988 -0.024092  0.060386  0.058983 -0.037028
# carType                   0.117515  0.031875 -0.012135 -0.010450 -0.021512
# Engine Type               0.011501 -0.016675 -0.108394 -0.100724 -0.242012
# No of Cylinder            0.088460  0.010827 -0.254322 -0.248129  0.020923
# Valves per Cylinder      -0.084753  0.010226  0.086712  0.087736  0.048787
# Turbo Charger             0.233948  0.004081  0.116612  0.115232 -0.055686
# Super Charger             0.233948  0.004081  0.116612  0.115232 -0.055686
# Length                    0.149051  0.032361  0.081931  0.076045 -0.052965
# Width                    -0.014591  0.040752  0.033470  0.015454 -0.032089
# Height                   -0.082950  0.024118 -0.089336 -0.113876  0.006768
# Wheel Base                0.081495  0.044436  0.009393 -0.009843 -0.073678
# Front Tread               0.046918  0.020297 -0.025543 -0.041449 -0.005104
# Rear Tread                0.029804  0.019759  0.045644  0.035208 -0.080810
# Kerb Weight               0.195480  0.017949  0.001971  0.013194 -0.156758
# Gross Weight              0.177804  0.007248 -0.041262 -0.023128 -0.189741
# Gear Box                 -0.061056  0.043344 -0.010859 -0.021973 -0.056152
# Drive Type                0.001463 -0.007496 -0.019652 -0.018074  0.022746
# Seats                     0.016191 -0.003921 -0.023117 -0.030475  0.092146
# Steering Type             0.005852  0.002742  0.032204  0.029709  0.004567
# Turning Radius            0.104563  0.034918  0.004909  0.004067 -0.119048
# Front Brake Type          0.110956  0.004612  0.092704  0.080138  0.223271
# Rear Brake Type          -0.021294 -0.032494  0.000117  0.000377  0.031215
# Top Speed                 0.108409  0.023019 -0.082990 -0.079432 -0.148302
# Acceleration             -0.043427 -0.023449  0.138766  0.130039  0.075432
# Tyre Type                 0.078845  0.003887  0.237741  0.213245  0.123888
# Doors                    -0.151624  0.005580 -0.087425 -0.098988 -0.037526
# Cargo Volume              0.112483  0.026193  0.120233  0.111672 -0.076389
# owner_type                0.175063 -0.007211  0.018817  0.025223 -0.008298
# Fuel Suppy System        -0.289907 -0.010558  0.078257  0.078353  0.063530
# Compression Ratio         0.141632 -0.018256 -0.083217 -0.078059 -0.172564
# Alloy Wheel Size         -0.159535  0.025433 -0.076826 -0.091248 -0.070367
# Ground Clearance Unladen  0.033119  0.005209  0.033887  0.031933 -0.002748
# Max Power Delivered       0.020882  0.042178 -0.115058 -0.116832 -0.134353
# Max Power At             -0.326992  0.014752 -0.137270 -0.142156  0.071691
# Max Torque Delivered      0.255651  0.014976  0.063447  0.066331 -0.131032
# Max Torque At            -0.309305  0.009124 -0.188714 -0.192706  0.043158
# Bore                      0.062554 -0.001116  0.049893  0.063702 -0.269591
# Stroke                         NaN       NaN       NaN       NaN       NaN
#
#                              utype  ...  Fuel Suppy System  Compression Ratio  \
# myear                    -0.077420  ...           0.090946           0.008726
# body                     -0.009538  ...          -0.363592           0.134805
# transmission              0.078650  ...           0.035653           0.030507
# fuel                     -0.118273  ...           0.695012          -0.386961
# km                        0.114988  ...          -0.289907           0.141632
# ip                       -0.024092  ...          -0.010558          -0.018256
# oem                       0.060386  ...           0.078257          -0.083217
# model                     0.058983  ...           0.078353          -0.078059
# variant                  -0.037028  ...           0.063530          -0.172564
# utype                     1.000000  ...          -0.067191           0.049490
# carType                   0.179688  ...          -0.115561           0.046626
# Engine Type              -0.008550  ...           0.181276           0.069516
# No of Cylinder           -0.066203  ...          -0.149444           0.070113
# Valves per Cylinder      -0.117634  ...           0.015284          -0.195431
# Turbo Charger             0.082135  ...          -0.656786           0.386362
# Super Charger             0.082135  ...          -0.656786           0.386362
# Length                   -0.026871  ...          -0.354985           0.114760
# Width                    -0.048648  ...          -0.309372           0.077791
# Height                    0.010888  ...          -0.112376           0.043799
# Wheel Base               -0.007533  ...          -0.338977           0.120826
# Front Tread               0.016943  ...          -0.149828           0.033016
# Rear Tread                0.023879  ...          -0.102759           0.015660
# Kerb Weight               0.069588  ...          -0.462953           0.157371
# Gross Weight              0.101540  ...          -0.345568           0.123713
# Gear Box                 -0.041644  ...          -0.152276           0.076293
# Drive Type                0.008775  ...          -0.017725           0.116541
# Seats                     0.062026  ...          -0.024728          -0.029861
# Steering Type            -0.033313  ...          -0.010262           0.007181
# Turning Radius           -0.013395  ...          -0.359931           0.144709
# Front Brake Type          0.081641  ...          -0.074915          -0.031316
# Rear Brake Type           0.002624  ...           0.185122          -0.139539
# Top Speed                -0.074424  ...          -0.297341           0.163872
# Acceleration              0.075252  ...           0.220724          -0.191330
# Tyre Type                 0.045480  ...          -0.185191           0.011814
# Doors                     0.020194  ...           0.162026          -0.132507
# Cargo Volume             -0.038921  ...          -0.319752           0.098061
# owner_type                0.131209  ...          -0.042482           0.024994
# Fuel Suppy System        -0.067191  ...           1.000000          -0.250787
# Compression Ratio         0.049490  ...          -0.250787           1.000000
# Alloy Wheel Size         -0.049769  ...          -0.044507           0.094709
# Ground Clearance Unladen -0.062792  ...           0.013436          -0.036967
# Max Power Delivered      -0.065664  ...          -0.338108           0.158315
# Max Power At             -0.127346  ...           0.641172          -0.407019
# Max Torque Delivered      0.053502  ...          -0.689583           0.367607
# Max Torque At            -0.109379  ...           0.633361          -0.321230
# Bore                      0.031649  ...           0.043139           0.363290
# Stroke                         NaN  ...                NaN                NaN
#
#                           Alloy Wheel Size  Ground Clearance Unladen  \
# myear                             0.441790                 -0.055535
# body                              0.203493                  0.029378
# transmission                     -0.120287                 -0.006494
# fuel                             -0.074055                 -0.009660
# km                               -0.159535                  0.033119
# ip                                0.025433                  0.005209
# oem                              -0.076826                  0.033887
# model                            -0.091248                  0.031933
# variant                          -0.070367                 -0.002748
# utype                            -0.049769                 -0.062792
# carType                          -0.043057                 -0.009037
# Engine Type                       0.010658                 -0.001397
# No of Cylinder                    0.047312                  0.106223
# Valves per Cylinder              -0.007064                 -0.015546
# Turbo Charger                     0.208270                  0.013150
# Super Charger                     0.208270                  0.013150
# Length                            0.131769                  0.018608
# Width                             0.379655                  0.067101
# Height                            0.351336                 -0.008280
# Wheel Base                        0.280949                 -0.000765
# Front Tread                       0.126635                  0.023826
# Rear Tread                        0.120267                  0.017315
# Kerb Weight                       0.105864                  0.033223
# Gross Weight                     -0.013375                 -0.038767
# Gear Box                          0.236314                  0.008228
# Drive Type                        0.027519                 -0.003474
# Seats                             0.004688                 -0.202930
# Steering Type                    -0.016486                  0.054965
# Turning Radius                    0.200659                  0.067991
# Front Brake Type                 -0.111352                  0.006353
# Rear Brake Type                  -0.219386                 -0.022964
# Top Speed                         0.090131                  0.035952
# Acceleration                     -0.069660                 -0.016765
# Tyre Type                        -0.163763                  0.045488
# Doors                             0.179543                 -0.044029
# Cargo Volume                      0.085545                  0.054306
# owner_type                       -0.125267                  0.007566
# Fuel Suppy System                -0.044507                  0.013436
# Compression Ratio                 0.094709                 -0.036967
# Alloy Wheel Size                  1.000000                 -0.005313
# Ground Clearance Unladen         -0.005313                  1.000000
# Max Power Delivered               0.273672                  0.058828
# Max Power At                     -0.107889                  0.024879
# Max Torque Delivered              0.228127                  0.029738
# Max Torque At                    -0.060741                 -0.011076
# Bore                             -0.090414                 -0.019452
# Stroke                                 NaN                       NaN
#
#                           Max Power Delivered  Max Power At  \
# myear                                0.068823      0.061749
# body                                 0.643167     -0.222558
# transmission                        -0.265912     -0.085318
# fuel                                -0.076424      0.903683
# km                                   0.020882     -0.326992
# ip                                   0.042178      0.014752
# oem                                 -0.115058     -0.137270
# model                               -0.116832     -0.142156
# variant                             -0.134353      0.071691
# utype                               -0.065664     -0.127346
# carType                              0.051710     -0.128333
# Engine Type                          0.033512      0.158151
# No of Cylinder                       0.328705     -0.044279
# Valves per Cylinder                  0.173690      0.165075
# Turbo Charger                        0.316331     -0.802910
# Super Charger                        0.316331     -0.802910
# Length                               0.746112     -0.149526
# Width                                0.618289     -0.246379
# Height                               0.194201     -0.178142
# Wheel Base                           0.665360     -0.188044
# Front Tread                          0.222186     -0.113331
# Rear Tread                           0.214025     -0.138648
# Kerb Weight                          0.501495     -0.452057
# Gross Weight                         0.316600     -0.324378
# Gear Box                             0.402590     -0.061450
# Drive Type                          -0.183900      0.019994
# Seats                                0.009838     -0.050003
# Steering Type                        0.051897      0.001166
# Turning Radius                       0.608475     -0.231912
# Front Brake Type                    -0.131800     -0.072313
# Rear Brake Type                     -0.559679      0.166245
# Top Speed                            0.552578     -0.065153
# Acceleration                        -0.559732      0.028993
# Tyre Type                            0.092556     -0.090730
# Doors                               -0.344524     -0.024559
# Cargo Volume                         0.594093     -0.087115
# owner_type                          -0.005247     -0.047709
# Fuel Suppy System                   -0.338108      0.641172
# Compression Ratio                    0.158315     -0.407019
# Alloy Wheel Size                     0.273672     -0.107889
# Ground Clearance Unladen             0.058828      0.024879
# Max Power Delivered                  1.000000     -0.043685
# Max Power At                        -0.043685      1.000000
# Max Torque Delivered                 0.644350     -0.736955
# Max Torque At                       -0.090429      0.920273
# Bore                                 0.219617      0.094089
# Stroke                                    NaN           NaN
#
#                           Max Torque Delivered  Max Torque At      Bore  \
# myear                                 0.009656       0.028825 -0.167389
# body                                  0.540150      -0.252674  0.041067
# transmission                         -0.092136      -0.059494 -0.064036
# fuel                                 -0.740695       0.880123  0.105588
# km                                    0.255651      -0.309305  0.062554
# ip                                    0.014976       0.009124 -0.001116
# oem                                   0.063447      -0.188714  0.049893
# model                                 0.066331      -0.192706  0.063702
# variant                              -0.131032       0.043158 -0.269591
# utype                                 0.053502      -0.109379  0.031649
# carType                               0.123089      -0.122947  0.031667
# Engine Type                          -0.075144       0.148738  0.211833
# No of Cylinder                        0.261320       0.010259 -0.162013
# Valves per Cylinder                   0.028051       0.070620  0.022534
# Turbo Charger                         0.799766      -0.843285 -0.074583
# Super Charger                         0.799766      -0.843285 -0.074583
# Length                                0.572438      -0.196439  0.133989
# Width                                 0.589243      -0.310730 -0.100249
# Height                                0.241968      -0.188120 -0.169510
# Wheel Base                            0.555177      -0.221683  0.058366
# Front Tread                           0.235923      -0.105563 -0.087626
# Rear Tread                            0.253056      -0.140588 -0.063971
# Kerb Weight                           0.612011      -0.438684  0.096284
# Gross Weight                          0.406962      -0.265621  0.107652
# Gear Box                              0.289500      -0.085745  0.062452
# Drive Type                           -0.111734       0.029901  0.002014
# Seats                                 0.027060      -0.055851 -0.007848
# Steering Type                         0.040603      -0.023755  0.008133
# Turning Radius                        0.543960      -0.268261  0.061555
# Front Brake Type                     -0.056516      -0.091436 -0.045209
# Rear Brake Type                      -0.472154       0.191917 -0.153608
# Top Speed                             0.372924      -0.085861  0.144431
# Acceleration                         -0.341845       0.052926 -0.164153
# Tyre Type                             0.104612      -0.128269  0.019247
# Doors                                -0.187101      -0.015051 -0.242519
# Cargo Volume                          0.424988      -0.112429  0.107114
# owner_type                            0.031118      -0.034641  0.081490
# Fuel Suppy System                    -0.689583       0.633361  0.043139
# Compression Ratio                     0.367607      -0.321230  0.363290
# Alloy Wheel Size                      0.228127      -0.060741 -0.090414
# Ground Clearance Unladen              0.029738      -0.011076 -0.019452
# Max Power Delivered                   0.644350      -0.090429  0.219617
# Max Power At                         -0.736955       0.920273  0.094089
# Max Torque Delivered                  1.000000      -0.754744  0.049634
# Max Torque At                        -0.754744       1.000000  0.109055
# Bore                                  0.049634       0.109055  1.000000
# Stroke                                     NaN            NaN       NaN
#
#                           Stroke
# myear                        NaN
# body                         NaN
# transmission                 NaN
# fuel                         NaN
# km                           NaN
# ip                           NaN
# oem                          NaN
# model                        NaN
# variant                      NaN
# utype                        NaN
# carType                      NaN
# Engine Type                  NaN
# No of Cylinder               NaN
# Valves per Cylinder          NaN
# Turbo Charger                NaN
# Super Charger                NaN
# Length                       NaN
# Width                        NaN
# Height                       NaN
# Wheel Base                   NaN
# Front Tread                  NaN
# Rear Tread                   NaN
# Kerb Weight                  NaN
# Gross Weight                 NaN
# Gear Box                     NaN
# Drive Type                   NaN
# Seats                        NaN
# Steering Type                NaN
# Turning Radius               NaN
# Front Brake Type             NaN
# Rear Brake Type              NaN
# Top Speed                    NaN
# Acceleration                 NaN
# Tyre Type                    NaN
# Doors                        NaN
# Cargo Volume                 NaN
# owner_type                   NaN
# Fuel Suppy System            NaN
# Compression Ratio            NaN
# Alloy Wheel Size             NaN
# Ground Clearance Unladen     NaN
# Max Power Delivered          NaN
# Max Power At                 NaN
# Max Torque Delivered         NaN
# Max Torque At                NaN
# Bore                         NaN
# Stroke                       NaN
#
# [47 rows x 47 columns]

# %%
# 현재 Stroke의 값 분포 출력
pre_c_df.Stroke.unique()
# Out:
# array([82.5])

# %%
# Stroke 컬럼 제거
# 현재 한 가지 값만 가지고 있기 때문에 머신 러닝에 도움이 되지 않음
pre_c_df = pre_c_df.drop(labels=['Stroke'], axis=1)
pre_c_df
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0       2015     2             1     0  45864   0   22    150     1381      0
# 1       2017     2             1     0  58000   0   12     85      111      0
# 2       2018     2             1     0  98083   0   22    150     2144      0
# 3       2019     2             1     0  80000   0   22    150     2141      1
# 4       2017     6             1     0  39000   0   22    155     2140      0
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 17754   2018     2             1     1  63000   0   33    244       58      0
# 17755   2019     9             1     1  96029   0   33    233     2281      0
# 17756   2011     8             1     1  82843   0   33    238     1042      0
# 17757   2014     2             1     1  62000   0   33    236     1503      0
# 17758   2018     8             1     1  54000   0   33    246       62      0
#
#        ...  Fuel Suppy System  Compression Ratio  Alloy Wheel Size  \
# 0      ...                  6               11.0              16.0
# 1      ...                  9               10.8              16.0
# 2      ...                  6               11.0              16.0
# 3      ...                  6               11.0              16.0
# 4      ...                  9               11.0              16.0
# ...    ...                ...                ...               ...
# 17754  ...                  0               16.0              16.0
# 17755  ...                  0               16.5              17.0
# 17756  ...                  0               10.8              15.0
# 17757  ...                  0               10.8              16.0
# 17758  ...                  0               16.0              14.0
#
#        Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                         190.0                58.20        6000.0
# 1                         190.0                65.39        6000.0
# 2                         190.0                58.33        6000.0
# 3                         190.0                58.33        6000.0
# 4                         190.0                80.46        6000.0
# ...                         ...                  ...           ...
# 17754                     190.0                69.00        4000.0
# 17755                     190.0               138.10        3750.0
# 17756                     190.0                88.80        4000.0
# 17757                     190.0                69.00        4000.0
# 17758                     190.0                69.00        4000.0
#
#        Max Torque Delivered  Max Torque At  Bore     target
# 0                      78.0         3500.0  73.0  12.807655
# 1                      98.0         4000.0  73.0  13.049795
# 2                      78.0         3500.0  73.0  12.959847
# 3                      78.0         3500.0  73.0  12.847929
# 4                     112.0         4000.0  73.0  13.586099
# ...                     ...            ...   ...        ...
# 17754                 140.0         2400.0  75.0  13.038984
# 17755                 350.0         2125.0  73.0  14.072476
# 17756                 200.0         2375.0  73.0  12.409018
# 17757                 140.0         2400.0  73.0  12.323860
# 17758                 140.0         2400.0  75.0  13.180634
#
# [17759 rows x 47 columns]

# %% [markdown]
# ### 1st Cycle - 차원 축소 없이 선형 회귀
# - PCA 차원 축소 후 결과와 비교 분석

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = pre_c_df.iloc[:, :-1], pre_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score

# 선형 회귀 모델의 평가 지표(R2 점수 포함)를 출력해주는 함수
def get_evaluation(y_test, prediction):
    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    MSLE = mean_squared_log_error(y_test, prediction)
    RMSLE = np.sqrt(mean_squared_log_error(y_test, prediction))
    R2 = r2_score(y_test, prediction)
    print('MSE: {:.4f}, RMSE: {:.4f}, MSLE: {:.4f}, RMSLE: {:.4f}, R2: {:.4f}'\
          .format(MSE, RMSE, MSLE, RMSLE, R2))

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0442, RMSE: 0.2101, MSLE: 0.0002, RMSLE: 0.0152, R2: 0.8537

# %% [markdown]
# #### 과적합 발생 여부 확인
# - 같은 모델로 train 데이터와 test 데이터를 각각 예측한 다음 평가
# - 시각화 결과를 포함하여 과적합 발생 여부 검증

# %%
import matplotlib.pyplot as plt

# 모델 훈련 후 train 데이터 예측하고 평가
l_r.fit(X_train, y_train)
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('Train 데이터를 통한 중고차 가격 회귀 예측')
plt.show()
# Out:
# MSE: 0.0452, RMSE: 0.2125, MSLE: 0.0002, RMSLE: 0.0154, R2: 0.8560

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
l_r.fit(X_train, y_train)
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('Test 데이터를 통한 중고차 가격 회귀 예측')
plt.show()
# Out:
# MSE: 0.0442, RMSE: 0.2101, MSLE: 0.0002, RMSLE: 0.0152, R2: 0.8537

# %% [markdown]
# #### 1st Cycle - 차원 축소 없이 선형 회귀한 결과
# - train 데이터와 test 데이터의 R2와 오차가 큰 차이를 보이지 않음
# - 따라서 현재 모델에는 과적합이 발생하지 않은 것으로 추정

# %% [markdown]
# ### 1st Cycle - 차원 축소
# - 차원 축소 이전에도 만족스러운 결과를 보였지만,
#   학습에 사용된 feature의 개수가 많기 때문에 모델의 계산 효율에 악영향을 줄 수 있음
# - 따라서 표현력 손실을 감수하더라도 차원 축소를 통해 계산 효율을 향상
# - 현재 target이 연속형이기 때문에 차원 축소는 PCA 방식으로만 진행

# %%
from sklearn.decomposition import PCA

# 1 ~ 15차원까지 늘려보면서 각 차원의 데이터 보존률 출력
# fit하기 적합한 차원 수를 알아보기 위함
for i in range(15):
    pca = PCA(n_components=(i + 1))

    pca_train = pca.fit_transform(X_train)
    pca_test = pca.transform(X_test)
    
    # 차원 축소 후 데이터 보존률 확인
    print(f'{i + 1}차원')
    print(pca.explained_variance_ratio_.sum())
    print('=' * 30)
# Out:
# 1차원
# 0.9982300749508576
# ==============================
# 2차원
# 0.9994762779157293
# ==============================
# 3차원
# 0.99984566711732
# ==============================
# 4차원
# 0.9999145672695126
# ==============================
# 5차원
# 0.9999685889866424
# ==============================
# 6차원
# 0.9999805199241657
# ==============================
# 7차원
# 0.999985210842029
# ==============================
# 8차원
# 0.9999895619955204
# ==============================
# 9차원
# 0.9999932257703706
# ==============================
# 10차원
# 0.9999956029825384
# ==============================
# 11차원
# 0.9999972391051548
# ==============================
# 12차원
# 0.9999984670150772
# ==============================
# 13차원
# 0.9999991030529473
# ==============================
# 14차원
# 0.9999996025564408
# ==============================
# 15차원
# 0.999999872916776
# ==============================

# %%
# 차원 축소 이전, 훈련 데이터와 테스트 데이터를 각각 병합하여 새로운 데이터 세트 생성
train_df = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)
test_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)

# %%
# 훈련용, 테스트용 데이터 세트 확인
display(train_df)
# Out:
#        myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0       2018     9             0     4  41320   0   30    210     1688      0
# 1       2022     9             1     1  15000   0   16    108     1429      1
# 2       2020     2             0     4   3990   0   30    214     1099      0
# 3       2017     2             1     4  86543   0   12     85      103      0
# 4       2017     9             0     4  24083   0   30    210     1688      0
# ...      ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 14202   2017     2             1     4  60000   0   30    214       40      1
# 14203   2018     2             1     1  70618   0   12     88      276      0
# 14204   2017     2             1     4  50000   0   12     88     1578      0
# 14205   2018     9             1     1  73893   0   15    105      620      0
# 14206   2016     2             1     4  52000   0   27    199     2266      1
#
#        ...  Fuel Suppy System  Compression Ratio  Alloy Wheel Size  \
# 0      ...                  9               10.8              16.0
# 1      ...                  0               10.8              17.0
# 2      ...                  9               10.8              16.0
# 3      ...                  9               10.8              14.0
# 4      ...                  9               10.8              16.0
# ...    ...                ...                ...               ...
# 14202  ...                  9               10.8              16.0
# 14203  ...                  0               10.8              16.0
# 14204  ...                  9               10.8              16.0
# 14205  ...                  0               10.8              16.0
# 14206  ...                  4                9.8              16.0
#
#        Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                         190.0               104.50        5600.0
# 1                         190.0               113.43        4000.0
# 2                         190.0                67.00        5500.0
# 3                         190.0                81.86        6000.0
# 4                         190.0               104.50        5600.0
# ...                         ...                  ...           ...
# 14202                     190.0                67.00        5500.0
# 14203                     190.0                88.73        4000.0
# 14204                     190.0                81.83        6000.0
# 14205                     190.0               170.00        3750.0
# 14206                     190.0                67.04        5000.0
#
#        Max Torque Delivered  Max Torque At  Bore     target
# 0                    142.00         4000.0  73.0  13.790194
# 1                    250.00         2125.0  73.0  14.346139
# 2                     91.00         4250.0  73.0  13.171536
# 3                    113.75         4000.0  73.0  13.221305
# 4                    142.00         4000.0  73.0  13.696728
# ...                     ...            ...   ...        ...
# 14202                 91.00         4250.0  73.0  12.429220
# 14203                219.70         2125.0  73.0  13.060490
# 14204                114.70         4000.0  73.0  13.199326
# 14205                350.00         2125.0  73.0  14.115616
# 14206                104.00         4000.0  78.0  12.429220
#
# [14207 rows x 47 columns]

# %%
display(test_df)
# Out:
#       myear  body  transmission  fuel     km  ip  oem  model  variant  utype  \
# 0      2017     2             0     4  42961   0   12     85      109      0
# 1      2019     8             1     4  53128   0   22    152     1187      0
# 2      2011     2             1     4  80000   0   10     65     1670      1
# 3      2021     9             1     1  36836   0   12     95     1944      0
# 4      2021     6             1     0  60000   0   22    155     1119      1
# ...     ...   ...           ...   ...    ...  ..  ...    ...      ...    ...
# 3547   2017     8             1     4  75048   0   11     73     1447      0
# 3548   2020     8             0     4  30015   0   11     74     2311      0
# 3549   2012     2             1     4  76500   0   11     72     1807      1
# 3550   2020     2             0     4  13599   0   22    162      996      0
# 3551   2014     6             1     1  70000   0   11     77     2045      0
#
#       ...  Fuel Suppy System  Compression Ratio  Alloy Wheel Size  \
# 0     ...                  9               10.8              16.0
# 1     ...                  9               10.8              15.0
# 2     ...                  4               10.8              14.0
# 3     ...                  0               10.8              16.0
# 4     ...                  9               10.5              16.0
# ...   ...                ...                ...               ...
# 3547  ...                  0               10.3              15.0
# 3548  ...                  9               10.8              17.0
# 3549  ...                  0               10.8              16.0
# 3550  ...                  9               10.8              16.0
# 3551  ...                  0               10.3              15.0
#
#       Ground Clearance Unladen  Max Power Delivered  Max Power At  \
# 0                        190.0                81.86        6000.0
# 1                        190.0               103.25        6000.0
# 2                        190.0                70.00        6250.0
# 3                        190.0                98.60        4000.0
# 4                        190.0                91.19        6000.0
# ...                        ...                  ...           ...
# 3547                     190.0               117.30        6600.0
# 3548                     190.0               139.46        6500.0
# 3549                     190.0                86.80        6000.0
# 3550                     190.0                81.80        6000.0
# 3551                     190.0                98.60        3600.0
#
#       Max Torque Delivered  Max Torque At  Bore     target
# 0                   113.75         4000.0  73.0  13.210376
# 1                   138.00         4400.0  74.0  13.458837
# 2                   102.00         4000.0  73.0  12.429220
# 3                   240.26         2125.0  73.0  14.038655
# 4                   122.00         4400.0  74.0  13.764218
# ...                    ...            ...   ...        ...
# 3547                145.00         4600.0  73.0  13.251637
# 3548                174.00         4300.0  73.0  14.465229
# 3549                109.00         4500.0  73.0  12.206078
# 3550                113.00         4200.0  73.0  13.384729
# 3551                200.00         1750.0  73.0  13.407544
#
# [3552 rows x 47 columns]

# %% [markdown]
# #### 1st Cycle - 2차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 2차원으로 설정
pca = PCA(n_components=2)

pca_train = pca.fit_transform(X_train)
pca_test = pca.transform(X_test)

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)
# Out:
# (14207, 2) (3552, 2)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)
# Out:
#                pca1         pca2     target
# 0     -19831.075573   410.952367  13.790194
# 1     -46119.652219 -2368.879921  14.346139
# 2     -57160.073989    87.853604  13.171536
# 3      25385.436009  1197.258815  13.221305
# 4     -37066.818102   203.467795  13.696728
# ...             ...          ...        ...
# 14202  -1153.563662   722.385293  12.429220
# 14203   9494.909603 -1744.913202  13.060490
# 14204 -11155.516971   804.773909  13.199326
# 14205  12772.101513 -1886.811992  14.115616
# 14206  -9147.882397   184.259272  12.429220
#
# [14207 rows x 3 columns]

# %%
display(pca_test_df)
# Out:
#               pca1         pca2     target
# 0    -18193.388376   672.888677  13.210376
# 1     -8030.324482  1102.606404  13.458837
# 2     18839.905587  1349.358986  12.429220
# 3    -24285.948245 -2069.407769  14.038655
# 4     -1158.676544  1169.516912  13.764218
# ...            ...          ...        ...
# 3547  13881.148518  1930.482372  13.251637
# 3548 -31145.282238  1113.927819  14.465229
# 3549  15337.576463  1519.906048  12.206078
# 3550 -47555.722473   513.340924  13.384729
# 3551   8882.656957 -2231.743626  13.407544
#
# [3552 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(2차원) - Train 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.2670, RMSE: 0.5167, MSLE: 0.0014, RMSLE: 0.0372, R2: 0.1487

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(2차원) - Test 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.2611, RMSE: 0.5109, MSLE: 0.0013, RMSLE: 0.0367, R2: 0.1349

# %% [markdown]
# #### 1st Cycle - 2차원으로 차원 축소 후 선형 회귀 결과
# - PCA 방식으로 차원 축소 후 2차원으로 축소한 결과, R2가 매우 크게 감소함
# - 따라서 차원을 5차원으로 설정한 뒤 다시 학습

# %% [markdown]
# #### 1st Cycle - 5차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 5차원으로 설정
pca = PCA(n_components=5)

pca_train = pca.fit_transform(train_df.iloc[:, :-1])
pca_test = pca.transform(test_df.iloc[:, :-1])

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)
# Out:
# (14207, 5) (3552, 5)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)
# Out:
#                pca1         pca2         pca3        pca4        pca5  \
# 0     -19831.075573   410.952367  -443.151408  222.656517 -367.957418
# 1     -46119.652219 -2368.879921  -293.476676  153.663430 -197.383126
# 2     -57160.073989    87.853604   148.080177 -478.045304 -246.842477
# 3      25385.436009  1197.258815  1114.636331 -225.865625  298.888887
# 4     -37066.818102   203.467795  -439.945104  230.482677 -380.272168
# ...             ...          ...          ...         ...         ...
# 14202  -1153.563662   722.385293  1192.948096 -549.823687 -138.932676
# 14203   9494.909603 -1744.913202   858.235546 -122.525169    2.510084
# 14204 -11155.516971   804.773909  -343.809491   26.200484   86.074586
# 14205  12772.101513 -1886.811992   515.622505  167.244170 -376.422901
# 14206  -9147.882397   184.259272 -1040.796156 -542.417064 -456.510082
#
#           target
# 0      13.790194
# 1      14.346139
# 2      13.171536
# 3      13.221305
# 4      13.696728
# ...          ...
# 14202  12.429220
# 14203  13.060490
# 14204  13.199326
# 14205  14.115616
# 14206  12.429220
#
# [14207 rows x 6 columns]

# %%
display(pca_test_df)
# Out:
#               pca1         pca2         pca3        pca4        pca5  \
# 0    -18193.388376   672.888677  1116.760506 -206.019752  267.476280
# 1     -8030.324482  1102.606404    74.504365  355.868168 -369.678418
# 2     18839.905587  1349.358986  -443.259932  -67.924516  352.379280
# 3    -24285.948245 -2069.407769  -809.351108 -149.251611  -39.883733
# 4     -1158.676544  1169.516912   149.889412  303.932403 -371.746595
# ...            ...          ...          ...         ...         ...
# 3547  13881.148518  1930.482372  -175.002778  470.612727 -106.130560
# 3548 -31145.282238  1113.927819 -1038.195034  776.222801 -192.953303
# 3549  15337.576463  1519.906048  -565.232494 -534.553497   13.413820
# 3550 -47555.722473   513.340924   239.683807 -220.015690  121.140490
# 3551   8882.656957 -2231.743626  -931.192800  122.065672 -228.487722
#
#          target
# 0     13.210376
# 1     13.458837
# 2     12.429220
# 3     14.038655
# 4     13.764218
# ...         ...
# 3547  13.251637
# 3548  14.465229
# 3549  12.206078
# 3550  13.384729
# 3551  13.407544
#
# [3552 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(5차원) - Train 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.2074, RMSE: 0.4554, MSLE: 0.0011, RMSLE: 0.0330, R2: 0.3387

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(5차원) - Test 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.1928, RMSE: 0.4391, MSLE: 0.0010, RMSLE: 0.0317, R2: 0.3610

# %% [markdown]
# #### 1st Cycle - 5차원으로 차원 축소 후 선형 회귀 결과
# - 5차원으로 축소한 결과, 2차원일 때보다는 R2가 개선되었지만 여전히 우수하지 않은 결과를 보임
# - 따라서 차원을 8차원으로 설정한 뒤 다시 학습

# %% [markdown]
# #### 1st Cycle - 8차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 8차원으로 설정
pca = PCA(n_components=8)

pca_train = pca.fit_transform(train_df.iloc[:, :-1])
pca_test = pca.transform(test_df.iloc[:, :-1])

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)
# Out:
# (14207, 8) (3552, 8)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)
# Out:
#                pca1         pca2         pca3        pca4        pca5  \
# 0     -19831.075573   410.952367  -443.151408  222.656517 -367.957418
# 1     -46119.652219 -2368.879921  -293.476676  153.663430 -197.383126
# 2     -57160.073989    87.853604   148.080177 -478.045304 -246.842477
# 3      25385.436009  1197.258815  1114.636331 -225.865625  298.888887
# 4     -37066.818102   203.467795  -439.945104  230.482677 -380.272168
# ...             ...          ...          ...         ...         ...
# 14202  -1153.563662   722.385293  1192.948096 -549.823687 -138.932676
# 14203   9494.909603 -1744.913202   858.235546 -122.525169    2.510084
# 14204 -11155.516971   804.773909  -343.809491   26.200484   86.074586
# 14205  12772.101513 -1886.811992   515.622505  167.244170 -376.422901
# 14206  -9147.882397   184.259272 -1040.796156 -542.417064 -456.510082
#
#              pca6        pca7        pca8     target
# 0       71.752672  -10.065380   75.039405  13.790194
# 1      -89.496363 -105.463677  118.718497  14.346139
# 2       75.080125  -35.950488 -116.267840  13.171536
# 3      107.805342  -31.459529   26.970810  13.221305
# 4       73.030404  -11.630039   67.408816  13.696728
# ...           ...         ...         ...        ...
# 14202   47.762945  -63.665501  -76.667771  12.429220
# 14203  234.412782  153.607732   41.586208  13.060490
# 14204   98.589174   23.922111   12.766579  13.199326
# 14205  158.229828   -3.727181  255.936226  14.115616
# 14206   61.764703  -18.323705  -24.354915  12.429220
#
# [14207 rows x 9 columns]

# %%
display(pca_test_df)
# Out:
#               pca1         pca2         pca3        pca4        pca5  \
# 0    -18193.388376   672.888677  1116.760506 -206.019752  267.476280
# 1     -8030.324482  1102.606404    74.504365  355.868168 -369.678418
# 2     18839.905587  1349.358986  -443.259932  -67.924516  352.379280
# 3    -24285.948245 -2069.407769  -809.351108 -149.251611  -39.883733
# 4     -1158.676544  1169.516912   149.889412  303.932403 -371.746595
# ...            ...          ...          ...         ...         ...
# 3547  13881.148518  1930.482372  -175.002778  470.612727 -106.130560
# 3548 -31145.282238  1113.927819 -1038.195034  776.222801 -192.953303
# 3549  15337.576463  1519.906048  -565.232494 -534.553497   13.413820
# 3550 -47555.722473   513.340924   239.683807 -220.015690  121.140490
# 3551   8882.656957 -2231.743626  -931.192800  122.065672 -228.487722
#
#             pca6        pca7        pca8     target
# 0     111.194419  -35.263063    7.586462  13.210376
# 1    -149.458318  -23.889056    1.464276  13.458837
# 2     152.615215   15.259938  -62.174210  12.429220
# 3     -10.191547  141.252512  -65.843814  14.038655
# 4     211.319007   50.544702  114.472301  13.764218
# ...          ...         ...         ...        ...
# 3547   -3.634450  -72.471677  -18.900531  13.251637
# 3548  155.068524  -95.152272   95.875497  14.465229
# 3549   87.609817  -32.433391   -4.069201  12.206078
# 3550 -258.910179  137.792790    5.765854  13.384729
# 3551   27.217048   85.881563   64.955124  13.407544
#
# [3552 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(8차원) - Train 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.1635, RMSE: 0.4044, MSLE: 0.0009, RMSLE: 0.0293, R2: 0.4785

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(8차원) - Test 데이터 예측 결과')
plt.show()
# Out:
# MSE: 0.1515, RMSE: 0.3892, MSLE: 0.0008, RMSLE: 0.0281, R2: 0.4981

# %% [markdown]
# #### 1st Cycle - PCA 방식으로 차원 축소 후 sklearn 선형 회귀 모델 학습 결과
# - 차원 수를 8로 늘렸지만, R2는 0.5 미만으로
#   여전히 차원 축소 이전에 비해 심각하게 감소한 경향을 보임
# - Pytorch로 차원 축소 이후 데이터 세트 학습 후,
#   위 과정에서 사용한 sklearn과의 결과 비교

# %% [markdown]
# ### 1st Cycle - Pytorch를 이용한 선형 회귀
# - 데이터 세트는 위 과정으로 만들어진 pca_train_df와 pca_test_df 사용

# %%
from torch.nn import Module, Linear

# LinearRegressionModel 클래스 선언
class LinearRegressionModel(Module):
    # 클래스 실행 시, 매개변수 n을 전달받음
    def __init__(self, n):
        # 부모 클래스(torch.nn.Module) 실행
        super().__init__()
        # linear 재정의 - 전달받은 n 만큼 차원 설정
        self.linear = Linear(n, 1)

    # LinearRegressionModel.forward 사용 시
    def forward(self, x):
        # 위에서 재정의한 linear에 전달받은 x값 넣어서 실행
        return self.linear(x)

# %%
import torch
from torch.optim import SGD
from torch.nn.functional import mse_loss
from sklearn.model_selection import train_test_split
import numpy as np

# torch의 시드값 고정
torch.manual_seed(124)

# 데이터 세트 분할 후 Tensor 타입으로 변경
# y(정답) 데이터 세트들은 ndarray 타입이기 때문에 view를 사용해서 차원 변환
X_train = torch.FloatTensor(pca_train_df.iloc[:, :-1].values)
y_train = torch.FloatTensor(pca_train_df.target.values).view(-1, 1)
X_test = torch.FloatTensor(pca_test_df.iloc[:, :-1].values)
y_test = torch.FloatTensor(pca_test_df.target.values).view(-1, 1)

# 위 셀에서 정의한 클래스 객체 선언(8차원)
l_r = LinearRegressionModel(8)

optimizer = SGD(l_r.parameters(), lr=6e-10)

# 반복 횟수
epochs = 100000

for epoch in range(1, epochs + 1):
    H = l_r(X_train)
    loss = mse_loss(y_train, H)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10000 == 0:
        print(f'Epoch: {epoch}/{epochs}')
        for i, w in enumerate(list(l_r.parameters())[0][0]):
            print(f'W{i + 1}: {np.round(w.item(), 4)}, ', end='')
        print(f'b: {np.round(list(l_r.parameters())[1].item(), 4)}')
        print(f'loss: {np.round(loss.item(), 4)}')
        print('=' * 60)
# Out:
# Epoch: 10000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0003, W4: -0.0047, W5: 0.0031, W6: -0.2144, W7: -0.1234, W8: -0.0217, b: -0.0107
# loss: 1123.3542
# ============================================================
# Epoch: 20000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: -0.0008, W5: 0.001, W6: -0.1725, W7: -0.1132, W8: -0.0199, b: -0.0105
# loss: 807.6827
# ============================================================
# Epoch: 30000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0003, W5: 0.0002, W6: -0.1388, W7: -0.1038, W8: -0.0182, b: -0.0103
# loss: 602.0433
# ============================================================
# Epoch: 40000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0006, W5: -0.0001, W6: -0.1117, W7: -0.0952, W8: -0.0166, b: -0.0102
# loss: 466.279
# ============================================================
# Epoch: 50000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0899, W7: -0.0873, W8: -0.0152, b: -0.01
# loss: 375.998
# ============================================================
# Epoch: 60000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0723, W7: -0.08, W8: -0.0138, b: -0.0099
# loss: 315.5073
# ============================================================
# Epoch: 70000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0582, W7: -0.0734, W8: -0.0126, b: -0.0097
# loss: 274.61
# ============================================================
# Epoch: 80000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0469, W7: -0.0673, W8: -0.0115, b: -0.0095
# loss: 246.6624
# ============================================================
# Epoch: 90000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0378, W7: -0.0616, W8: -0.0104, b: -0.0094
# loss: 227.3253
# ============================================================
# Epoch: 100000/100000
# W1: -0.0, W2: -0.0001, W3: 0.0, W4: 0.0007, W5: -0.0002, W6: -0.0304, W7: -0.0565, W8: -0.0095, b: -0.0092
# loss: 213.7532
# ============================================================

# %%
import numpy as np
import torch
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score

# PyTorch 모델의 평가 지표(R2 점수 포함)를 출력해주는 함수
def get_evaluation_pytorch(y_test, prediction):
    # 만약 전달받은 인자가 Pytorch의 tensor 타입이면
    # 아래의 sklearn 메소드에서도 사용가능하도록 detach() 함수 사용
    y_test = y_test.detach().numpy() if torch.is_tensor(y_test) else y_test
    prediction = prediction.detach().numpy() if torch.is_tensor(prediction) else prediction

    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    # MSLE = mean_squared_log_error(y_test, prediction)
    # RMSLE = np.sqrt(mean_squared_log_error(y_test, prediction))
    R2 = r2_score(y_test, prediction)
    
    print('MSE: {:.4f}, RMSE: {:.4f}, R2: {:.4f}'\
          .format(MSE, RMSE, R2))

# %%
prediction = l_r(X_test)
    
# 예측값과 실제 값 사이의 평가 지표 계산
get_evaluation_pytorch(y_test, prediction)
# Out:
# MSE: 208.2689, RMSE: 14.4315, R2: -689.1631

# %% [markdown]
# #### 이슈 발생
# - Pytorch 모델 훈련 결과의 R2 Score에서 비정상적인 수치 발견
# - 또한 MSLE 출력을 시도할 경우 에러 발생

# %% [markdown]
# #### 1st Cycle - 학습 결과
# - 차원 축소 시, 차원 축소 이전에 비해 R2가 심각하게 감소하는 현상 발생
# - 피드백 결과, 이는 차원 축소 이전 target과의 연관성이 낮은 feature들을 제거하지 않아서 생긴 문제라는 것을 인식함
# - 따라서 다음 사이클에서는 target과의 연관성이 낮았던 feature들을 제거한 다음 학습

# %% [markdown]
# ### 2nd Cycle - 데이터 전처리
# - target과의 연관성이 0.3 이하인 컬럼들을 전부 제거한 다음, 차원 축소 유무에 따른 학습 결과 비교

# %%
# 각 feature 별 target과의 상관관계 출력
pre_c_df.corr()['target'].sort_values(ascending=False)[1:]
# Out:
# myear                       0.741956
# Width                       0.618547
# Max Power Delivered         0.523028
# Alloy Wheel Size            0.487393
# Wheel Base                  0.483912
# body                        0.432280
# Turning Radius              0.419528
# Length                      0.392115
# Gear Box                    0.366724
# Height                      0.357097
# Max Torque Delivered        0.349992
# Cargo Volume                0.333756
# Top Speed                   0.277526
# Super Charger               0.247421
# Turbo Charger               0.247421
# Rear Tread                  0.231008
# Front Tread                 0.220910
# Valves per Cylinder         0.204468
# No of Cylinder              0.181408
# Kerb Weight                 0.155873
# Compression Ratio           0.073072
# ip                          0.070492
# Steering Type               0.056802
# Seats                       0.030047
# Ground Clearance Unladen    0.010709
# Doors                      -0.004812
# Max Power At               -0.019154
# Gross Weight               -0.021497
# oem                        -0.031346
# Tyre Type                  -0.035021
# model                      -0.044125
# variant                    -0.054976
# fuel                       -0.059171
# Engine Type                -0.059917
# Drive Type                 -0.064363
# Max Torque At              -0.074415
# Bore                       -0.107755
# Fuel Suppy System          -0.135360
# utype                      -0.157507
# carType                    -0.166536
# Front Brake Type           -0.180727
# Rear Brake Type            -0.261964
# owner_type                 -0.271465
# Acceleration               -0.305820
# transmission               -0.307764
# km                         -0.339765
# Name: target, dtype: float64

# %%
# target과의 상관관계를 변수에 할당(pandas.Series 타입)
target_corr = pre_c_df.corr()['target'].sort_values(ascending=False)[1:]

# 상관관계 0.이하인 컬럼만 담을 빈 리스트 선언
low_columns = []

# Series에는 딕셔너리와 유사하기 때문에 keys로 각 컬럼명 불러오는 것이 가능
for column in target_corr.keys():
    if (target_corr[column] <= 0.5) & (target_corr[column] >= -0.5):
        low_columns.append(column)

# 상관관계 0.3 이하인 feature만 담긴 리스트 출력
low_columns
# Out:
# ['Alloy Wheel Size',
#  'Wheel Base',
#  'body',
#  'Turning Radius',
#  'Length',
#  'Gear Box',
#  'Height',
#  'Max Torque Delivered',
#  'Cargo Volume',
#  'Top Speed',
#  'Super Charger',
#  'Turbo Charger',
#  'Rear Tread',
#  'Front Tread',
#  'Valves per Cylinder',
#  'No of Cylinder',
#  'Kerb Weight',
#  'Compression Ratio',
#  'ip',
#  'Steering Type',
#  'Seats',
#  'Ground Clearance Unladen',
#  'Doors',
#  'Max Power At',
#  'Gross Weight',
#  'oem',
#  'Tyre Type',
#  'model',
#  'variant',
#  'fuel',
#  'Engine Type',
#  'Drive Type',
#  'Max Torque At',
#  'Bore',
#  'Fuel Suppy System',
#  'utype',
#  'carType',
#  'Front Brake Type',
#  'Rear Brake Type',
#  'owner_type',
#  'Acceleration',
#  'transmission',
#  'km']

# %%
# low_columns 내 feature들 삭제
pre_c_df = pre_c_df.drop(labels=low_columns, axis=1)
pre_c_df
# Out:
#        myear   Width  Max Power Delivered     target
# 0       2015  1600.0                58.20  12.807655
# 1       2017  1660.0                65.39  13.049795
# 2       2018  1600.0                58.33  12.959847
# 3       2019  1600.0                58.33  12.847929
# 4       2017  1695.0                80.46  13.586099
# ...      ...     ...                  ...        ...
# 17754   2018  1647.0                69.00  13.038984
# 17755   2019  1894.0               138.10  14.072476
# 17756   2011  1703.0                88.80  12.409018
# 17757   2014  1665.0                69.00  12.323860
# 17758   2018  1677.0                69.00  13.180634
#
# [17759 rows x 4 columns]

# %%
# 현재 각 feature 별 target과의 상관관계 출력
pre_c_df.corr()['target'].sort_values(ascending=False)[1:]
# Out:
# myear                  0.741956
# Width                  0.618547
# Max Power Delivered    0.523028
# Name: target, dtype: float64

# %% [markdown]
# ### 2nd Cycle - 차원 축소 없이 선형 회귀
# - PCA 차원 축소 후 결과와 비교 분석

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = pre_c_df.iloc[:, :-1], pre_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 0.0584, RMSE: 0.2416, MSLE: 0.0003, RMSLE: 0.0174, R2: 0.8066

# %% [markdown]
# #### 과적합 발생 여부 확인

# %%
import matplotlib.pyplot as plt

# 모델 훈련 후 train 데이터 예측하고 평가
l_r.fit(X_train, y_train)
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('Train 데이터를 통한 중고차 가격 회귀 예측')
plt.show()
# Out:
# MSE: 0.0618, RMSE: 0.2485, MSLE: 0.0003, RMSLE: 0.0179, R2: 0.8030

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
l_r.fit(X_train, y_train)
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('Test 데이터를 통한 중고차 가격 회귀 예측')
plt.show()
# Out:
# MSE: 0.0584, RMSE: 0.2416, MSLE: 0.0003, RMSLE: 0.0174, R2: 0.8066

# %% [markdown]
# #### 2nd Cycle - 차원 축소 없이 선형 회귀한 결과
# - 이전 사이클과 마찬가지로, train 데이터와 test 데이터의 R2와 오차가 큰 차이를 보이지 않음
# - 따라서 현재 모델에는 과적합이 발생하지 않은 것으로 추정되며,
#   R2는 약 0.82 정도로 우수한 성능을 보임

# %%
차원 축소 이전에 남는 feature가 3개라 차원 축소 생략
# Out:
#   Cell In[88], line 1
#     차원 축소 이전에 남는 feature가 3개라 차원 축소 생략
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2nd Cycle - 차원 축소
# - 상관관계가 낮은 feature를 제거하지 않았던 이전 사이클과의 결과 비교가 목적

# %%
from sklearn.decomposition import PCA

# 1 ~ 15차원까지 늘려보면서 각 차원의 데이터 보존률 출력
# fit하기 적합한 차원 수를 알아보기 위함
for i in range(15):
    pca = PCA(n_components=(i + 1))

    pca_train = pca.fit_transform(X_train)
    pca_test = pca.transform(X_test)
    
    # 차원 축소 후 데이터 보존률 확인
    print(f'{i + 1}차원')
    print(pca.explained_variance_ratio_.sum())
    print('=' * 30)

# %%
# 차원 축소 이전, 훈련 데이터와 테스트 데이터를 각각 병합하여 새로운 데이터 세트 생성
train_df = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)
test_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)

# %%
# 훈련용, 테스트용 데이터 세트 확인
display(train_df)

# %%
display(test_df)

# %% [markdown]
# #### 2차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 2차원으로 설정
pca = PCA(n_components=2)

pca_train = pca.fit_transform(X_train)
pca_test = pca.transform(X_test)

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)

# %%
display(pca_test_df)

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(2차원) - Train 데이터 예측 결과')
plt.show()

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(2차원) - Test 데이터 예측 결과')
plt.show()

# %% [markdown]
# #### 2nd Cycle - 2차원으로 차원 축소 후 선형 회귀 결과
# - 이전 사이클에서 2차원으로 축소했을 때에 비해 크게 향상된 결과를 보임
# - 차원 수를 늘려나가다 보면, 차원 축소 후에도 우수한 R2 Score를 얻을 수 있을 것으로 기대

# %% [markdown]
# #### 2nd Cycle - 5차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 5차원으로 설정
pca = PCA(n_components=5)

pca_train = pca.fit_transform(train_df.iloc[:, :-1])
pca_test = pca.transform(test_df.iloc[:, :-1])

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)

# %%
display(pca_test_df)

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(5차원) - Train 데이터 예측 결과')
plt.show()

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(5차원) - Test 데이터 예측 결과')
plt.show()

# %% [markdown]
# #### 2nd Cycle - 5차원으로 차원 축소 후 선형 회귀 결과
# - 2차원일 때에 비해 R2 Score가 개선되었지만 성능 면에서는 여전히 부족함
# - 따라서 이전 사이클과 마찬가지로 8차원으로도 차원 축소 후 평가

# %% [markdown]
# #### 1st Cycle - 8차원으로 차원 축소

# %%
from sklearn.decomposition import PCA

# 차원 축소 후 목표 차원을 8차원으로 설정
pca = PCA(n_components=8)

pca_train = pca.fit_transform(train_df.iloc[:, :-1])
pca_test = pca.transform(test_df.iloc[:, :-1])

# 차원 축소 여부 확인
print(pca_train.shape, pca_test.shape)

# %%
# 차원 축소된 데이터 세트 생성
pca_columns = [f'pca{i + 1}' for i in range(pca_train.shape[1])]
pca_train_df = pd.DataFrame(pca_train, columns=pca_columns)
pca_train_df.loc[:, 'target'] = train_df.target

pca_columns = [f'pca{i + 1}' for i in range(pca_test.shape[1])]
pca_test_df = pd.DataFrame(pca_test, columns=pca_columns)
pca_test_df.loc[:, 'target'] = test_df.target

# %%
# 차원 축소된 데이터 세트 확인
display(pca_train_df)

# %%
display(pca_test_df)

# %%
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할
X_train, y_train = pca_train_df.iloc[:, :-1], pca_train_df.iloc[:, -1]
X_test, y_test = pca_test_df.iloc[:, :-1], pca_test_df.iloc[:, -1]

l_r = LinearRegression()
l_r.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt

# 모델로 train 데이터 예측 후 평가
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

# train 데이터 분포 시각화
fig, ax = plt.subplots()

# 실제값과 예측값에 따른 분포를 산점도로 시각화
ax.scatter(y_train, prediction, edgecolors='red', c='orange', alpha=0.2)

# y = x 그래프를 점선으로 시각화
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--')
plt.title('PCA 차원 축소(8차원) - Train 데이터 예측 결과')
plt.show()

# %%
import matplotlib.pyplot as plt

# 같은 모델로 test 데이터 예측 결과 시각화
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

fig, ax = plt.subplots()
ax.scatter(y_test, prediction, edgecolors='red', c='orange', alpha=0.2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.title('PCA 차원 축소(8차원) - Test 데이터 예측 결과')
plt.show()

# %% [markdown]
# #### 2nd Cycle - PCA 방식으로 차원 축소 후 sklearn 선형 회귀 모델 학습 결과
# - 여전히 기대했던 것보다 낮은 R2 Score를 기록함
# - 따라서 다음 사이클에서는 제거할 컬럼의 상관관계 기준을 상향 조정
