# %% [markdown]
# ### 데이터 세트: 콘크리트 강도 예측
#
# #### Features
# - Cement: 시멘트 함유량
# - Blast Furnace Slag: 용광로 내에서의 광재(광석 제련 후 남는 재)의 양
# - Fly Ash: 먼지 발생량
# - Water: 콘크리트를 만드는데 들어가는 물의 양
# - Superplasticizer: 시멘트가 마른 뒤의 강성
# - Coarse Aggregate: 시멘트 입자의 거친 정도
# - Fine Aggregate: 시멘트의 고운 정도
# - Age: 재보강이 필요해질 때까지 걸리는 시간
#
# #### Target
# - Strength: 콘크리트의 강도 (단위 /kN)

# %%
import pandas as pd
import numpy as np

# 데이터 세트 가져오기
c_df = pd.read_csv('./datasets/concrete_data.csv')

c_df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# 1               1055.0           676.0   28     61.89
# 2                932.0           594.0  270     40.27
# 3                932.0           594.0  365     41.05
# 4                978.4           825.5  360     44.30
# ...                ...             ...  ...       ...
# 1025             870.1           768.3   28     44.28
# 1026             817.9           813.4   28     31.18
# 1027             892.4           780.0   28     23.70
# 1028             989.6           788.9   28     32.77
# 1029             864.5           761.5   28     32.40
#
# [1030 rows x 9 columns]

# %%
# 데이터 세트 정보 확인
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %% [markdown]
# ### 이후 진행 순서
# 1. 우선 원본 데이터 세트 그대로 선형 회귀 모델에 fit
# 2. 만족스럽지 않은 결과가 나왔을 때는 전처리 다시 해보기
# 3. 위 과정을 반복해서 R2가 0.6 ~ 0.7 이상 나왔을 때 Polynomial이랑 OLS, VIF 보고 다음 사이클 전처리 방향 잡기

# %%
# 원본 데이터 세트의 분포 출력
c_df.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'Cement'}>,
#         <Axes: title={'center': 'Blast Furnace Slag'}>,
#         <Axes: title={'center': 'Fly Ash'}>],
#        [<Axes: title={'center': 'Water'}>,
#         <Axes: title={'center': 'Superplasticizer'}>,
#         <Axes: title={'center': 'Coarse Aggregate'}>],
#        [<Axes: title={'center': 'Fine Aggregate'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Strength'}>]], dtype=object)

# %% [markdown]
# - 타겟 데이터 분포의 첨도가 높지 않으니, 추가적인 전처리가 필요할 때 로그를 취할 필요는 없을 것으로 보임

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Cement                0.497832
# Superplasticizer      0.366079
# Age                   0.328873
# Blast Furnace Slag    0.134829
# Fly Ash              -0.105755
# Coarse Aggregate     -0.164935
# Fine Aggregate       -0.167241
# Water                -0.289633
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag   Fly Ash     Water  \
# Cement              1.000000           -0.275216 -0.397467 -0.081587
# Blast Furnace Slag -0.275216            1.000000 -0.323580  0.107252
# Fly Ash            -0.397467           -0.323580  1.000000 -0.256984
# Water              -0.081587            0.107252 -0.256984  1.000000
# Superplasticizer    0.092386            0.043270  0.377503 -0.657533
# Coarse Aggregate   -0.109349           -0.283999 -0.009961 -0.182294
# Fine Aggregate     -0.222718           -0.281603  0.079108 -0.450661
# Age                 0.081946           -0.044246 -0.154371  0.277618
#
#                     Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# Cement                      0.092386         -0.109349       -0.222718
# Blast Furnace Slag          0.043270         -0.283999       -0.281603
# Fly Ash                     0.377503         -0.009961        0.079108
# Water                      -0.657533         -0.182294       -0.450661
# Superplasticizer            1.000000         -0.265999        0.222691
# Coarse Aggregate           -0.265999          1.000000       -0.178481
# Fine Aggregate              0.222691         -0.178481        1.000000
# Age                        -0.192700         -0.003016       -0.156095
#
#                          Age
# Cement              0.081946
# Blast Furnace Slag -0.044246
# Fly Ash            -0.154371
# Water               0.277618
# Superplasticizer   -0.192700
# Coarse Aggregate   -0.003016
# Fine Aggregate     -0.156095
# Age                 1.000000

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = c_df.iloc[:, :-1], c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score

# 선형 회귀 모델의 평가 지표(R2 점수 포함)를 출력해주는 함수
def get_evaluation(y_test, prediction):
    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    MSLE = mean_squared_log_error(y_test, prediction)
    RMSLE = np.sqrt(mean_squared_log_error(y_test, prediction))
    R2 = r2_score(y_test, prediction)
    print('MSE: {:.4f}, RMSE: {:.4f}, MSLE: {:.4f}, RMSLE: {:.4f}, R2: {:.4f}'\
          .format(MSE, RMSE, MSLE, RMSLE, R2))

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 123.5110, RMSE: 11.1136, MSLE: 0.1213, RMSLE: 0.3482, R2: 0.4897

# %% [markdown]
# #### 1st Cycle - 선형 회귀 모델 학습 결과
# - R2 점수가 0.5에 못 미침
# - 데이터 전처리 후 재학습 진행

# %% [markdown]
# ### 2nd Cycle - 데이터 전처리

# %%
# 중복 검사
c_df.duplicated().sum()
# Out:
# 25

# %%
# 중복 제거한 새로운 데이터 세트 생성
pre_c_df = c_df.drop_duplicates().reset_index(drop=True)
pre_c_df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1000   276.4               116.0     90.3  179.6               8.9
# 1001   322.2                 0.0    115.6  196.0              10.4
# 1002   148.5               139.4    108.6  192.7               6.1
# 1003   159.1               186.7      0.0  175.6              11.3
# 1004   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# 1               1055.0           676.0   28     61.89
# 2                932.0           594.0  270     40.27
# 3                932.0           594.0  365     41.05
# 4                978.4           825.5  360     44.30
# ...                ...             ...  ...       ...
# 1000             870.1           768.3   28     44.28
# 1001             817.9           813.4   28     31.18
# 1002             892.4           780.0   28     23.70
# 1003             989.6           788.9   28     32.77
# 1004             864.5           761.5   28     32.40
#
# [1005 rows x 9 columns]

# %%
# 결측치 검사
pre_c_df.isna().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
# 원본 데이터 세트의 분포 출력
pre_c_df.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'Cement'}>,
#         <Axes: title={'center': 'Blast Furnace Slag'}>,
#         <Axes: title={'center': 'Fly Ash'}>],
#        [<Axes: title={'center': 'Water'}>,
#         <Axes: title={'center': 'Superplasticizer'}>,
#         <Axes: title={'center': 'Coarse Aggregate'}>],
#        [<Axes: title={'center': 'Fine Aggregate'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Strength'}>]], dtype=object)

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
pre_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Cement                0.488283
# Superplasticizer      0.344209
# Age                   0.337367
# Blast Furnace Slag    0.103374
# Fly Ash              -0.080648
# Coarse Aggregate     -0.144717
# Fine Aggregate       -0.186448
# Water                -0.269624
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(pre_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
pre_c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag   Fly Ash     Water  \
# Cement              1.000000           -0.303324 -0.385610 -0.056625
# Blast Furnace Slag -0.303324            1.000000 -0.312352  0.130262
# Fly Ash            -0.385610           -0.312352  1.000000 -0.283314
# Water              -0.056625            0.130262 -0.283314  1.000000
# Superplasticizer    0.060906            0.019800  0.414213 -0.646946
# Coarse Aggregate   -0.086205           -0.277559 -0.026468 -0.212480
# Fine Aggregate     -0.245375           -0.289685  0.090262 -0.444915
# Age                 0.086348           -0.042759 -0.158940  0.279284
#
#                     Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# Cement                      0.060906         -0.086205       -0.245375
# Blast Furnace Slag          0.019800         -0.277559       -0.289685
# Fly Ash                     0.414213         -0.026468        0.090262
# Water                      -0.646946         -0.212480       -0.444915
# Superplasticizer            1.000000         -0.241721        0.207993
# Coarse Aggregate           -0.241721          1.000000       -0.162187
# Fine Aggregate              0.207993         -0.162187        1.000000
# Age                        -0.194076         -0.005264       -0.156572
#
#                          Age
# Cement              0.086348
# Blast Furnace Slag -0.042759
# Fly Ash            -0.158940
# Water               0.279284
# Superplasticizer   -0.194076
# Coarse Aggregate   -0.005264
# Fine Aggregate     -0.156572
# Age                 1.000000

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = pre_c_df.iloc[:, :-1], pre_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 116.2002, RMSE: 10.7796, MSLE: 0.1056, RMSLE: 0.3250, R2: 0.5443

# %% [markdown]
# #### 2nd Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2 점수가 향상된 것을 확인
# - 데이터 표준화 후 이상치를 제거했을 때 생기는 변화와 비교해보기

# %% [markdown]
# ### 3nd Cycle - 데이터 전처리
# - StandardScaler()로 수치형 데이터 표준화
# - 표준화 이후 수치가 -1.96 ~ 1.96이 아닌 데이터들 제거

# %%
from sklearn.preprocessing import StandardScaler

# 표준화 된 수치가 담긴 데이터 세트를 새로 생성
std = StandardScaler()
result = std.fit_transform(pre_c_df)
std_pre_c_df = pd.DataFrame(result, columns=pre_c_df.columns)
std_pre_c_df
# Out:
#         Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0     2.506116           -0.836471 -0.865375 -0.941235         -0.597131
# 1     2.506116           -0.836471 -0.865375 -0.941235         -0.597131
# 2     0.516516            0.818045 -0.865375  2.153185         -1.019640
# 3     0.516516            0.818045 -0.865375  2.153185         -1.019640
# 4    -0.767375            0.700778 -0.865375  0.465320         -1.019640
# ...        ...                 ...       ...       ...               ...
# 1000 -0.021395            0.510363  0.541693 -0.116056          0.484495
# 1001  0.417755           -0.836471  0.935921  0.652861          0.738001
# 1002 -1.247756            0.782052  0.826846  0.498140          0.011284
# 1003 -1.146118            1.331235 -0.865375 -0.303597          0.890104
# 1004 -0.170016            0.330398  0.354707  0.868532          0.433794
#
#       Coarse Aggregate  Fine Aggregate       Age  Strength
# 0             0.846302       -1.204081 -0.280312  2.748689
# 1             1.039748       -1.204081 -0.280312  1.636671
# 2            -0.546508       -2.225246  3.518569  0.308393
# 3            -0.546508       -2.225246  5.009865  0.356314
# 4             0.051885        0.657677  4.931375  0.555986
# ...                ...             ...       ...       ...
# 1000         -1.344795       -0.054648 -0.280312  0.554757
# 1001         -2.017987        0.506993 -0.280312 -0.250074
# 1002         -1.057205        0.091055 -0.280312 -0.709626
# 1003          0.196324        0.201889 -0.280312 -0.152388
# 1004         -1.417015       -0.139330 -0.280312 -0.175120
#
# [1005 rows x 9 columns]

# %%
condition = True

# 반복문으로 각 컬럼에서 -1.96 ~ 1.96 사이의 데이터만 가져오는 조건식 생성
for column in std_pre_c_df.columns:
    condition &= std_pre_c_df[column].between(-1.96, 1.96)

# 위 조건에 맞지 않는 데이터 삭제
std_pre_c_df = std_pre_c_df[condition]
std_pre_c_df
# Out:
#         Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 10   -0.767375            0.700778 -0.865375  0.465320         -1.019640
# 11   -0.767375            0.700778 -0.865375  0.465320         -1.019640
# 16   -1.333093            1.594797 -0.865375  0.465320         -1.019640
# 21   -1.333093            1.594797 -0.865375  0.465320         -1.019640
# 22   -1.333093            1.594797 -0.865375  0.465320         -1.019640
# ...        ...                 ...       ...       ...               ...
# 997  -0.135497            0.452310  0.482481  0.629418         -0.022517
# 1000 -0.021395            0.510363  0.541693 -0.116056          0.484495
# 1002 -1.247756            0.782052  0.826846  0.498140          0.011284
# 1003 -1.146118            1.331235 -0.865375 -0.303597          0.890104
# 1004 -0.170016            0.330398  0.354707  0.868532          0.433794
#
#       Coarse Aggregate  Fine Aggregate       Age  Strength
# 10            0.051885        0.657677  0.692955  0.173230
# 11            0.051885        0.657677 -0.280312 -0.444216
# 16            0.936577        0.426047  0.692955  0.252485
# 21            0.936577        0.426047 -0.280312 -0.430700
# 22            0.936577        0.426047 -0.672758 -1.670508
# ...                ...             ...       ...       ...
# 997          -1.828410        0.220568 -0.280312  0.386418
# 1000         -1.344795       -0.054648 -0.280312  0.554757
# 1002         -1.057205        0.091055 -0.280312 -0.709626
# 1003          0.196324        0.201889 -0.280312 -0.152388
# 1004         -1.417015       -0.139330 -0.280312 -0.175120
#
# [720 rows x 9 columns]

# %%
# pre_c_df에서 이상치가 없는 인덱스만 유지하고, 인덱스 초기화
pre_c_df = pre_c_df.iloc[std_pre_c_df.index].reset_index(drop=True)
pre_c_df
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0     198.6               132.4      0.0  192.0               0.0
# 1     198.6               132.4      0.0  192.0               0.0
# 2     139.6               209.4      0.0  192.0               0.0
# 3     139.6               209.4      0.0  192.0               0.0
# 4     139.6               209.4      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 715   264.5               111.0     86.5  195.5               5.9
# 716   276.4               116.0     90.3  179.6               8.9
# 717   148.5               139.4    108.6  192.7               6.1
# 718   159.1               186.7      0.0  175.6              11.3
# 719   260.9               100.5     78.3  200.6               8.6
#
#      Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               978.4           825.5   90     38.07
# 1               978.4           825.5   28     28.02
# 2              1047.0           806.9   90     39.36
# 3              1047.0           806.9   28     28.24
# 4              1047.0           806.9    3      8.06
# ..                ...             ...  ...       ...
# 715             832.6           790.4   28     41.54
# 716             870.1           768.3   28     44.28
# 717             892.4           780.0   28     23.70
# 718             989.6           788.9   28     32.77
# 719             864.5           761.5   28     32.40
#
# [720 rows x 9 columns]

# %%
# 원본 데이터 세트의 분포 출력
pre_c_df.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'Cement'}>,
#         <Axes: title={'center': 'Blast Furnace Slag'}>,
#         <Axes: title={'center': 'Fly Ash'}>],
#        [<Axes: title={'center': 'Water'}>,
#         <Axes: title={'center': 'Superplasticizer'}>,
#         <Axes: title={'center': 'Coarse Aggregate'}>],
#        [<Axes: title={'center': 'Fine Aggregate'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Strength'}>]], dtype=object)

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
pre_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Age                   0.567925
# Superplasticizer      0.441279
# Cement                0.326046
# Fly Ash               0.124221
# Blast Furnace Slag    0.093006
# Fine Aggregate       -0.104157
# Coarse Aggregate     -0.191517
# Water                -0.389538
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(pre_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
pre_c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag   Fly Ash     Water  \
# Cement              1.000000           -0.296936 -0.378685 -0.051506
# Blast Furnace Slag -0.296936            1.000000 -0.324692  0.179947
# Fly Ash            -0.378685           -0.324692  1.000000 -0.417051
# Water              -0.051506            0.179947 -0.417051  1.000000
# Superplasticizer   -0.009158           -0.006695  0.569877 -0.669075
# Coarse Aggregate   -0.160193           -0.379349  0.053390 -0.241992
# Fine Aggregate     -0.151530           -0.293065  0.024300 -0.298933
# Age                -0.092379           -0.077498  0.122548 -0.046674
#
#                     Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# Cement                     -0.009158         -0.160193       -0.151530
# Blast Furnace Slag         -0.006695         -0.379349       -0.293065
# Fly Ash                     0.569877          0.053390        0.024300
# Water                      -0.669075         -0.241992       -0.298933
# Superplasticizer            1.000000         -0.186904        0.091230
# Coarse Aggregate           -0.186904          1.000000       -0.119828
# Fine Aggregate              0.091230         -0.119828        1.000000
# Age                         0.049983          0.052986        0.086554
#
#                          Age
# Cement             -0.092379
# Blast Furnace Slag -0.077498
# Fly Ash             0.122548
# Water              -0.046674
# Superplasticizer    0.049983
# Coarse Aggregate    0.052986
# Fine Aggregate      0.086554
# Age                 1.000000

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = pre_c_df.iloc[:, :-1], pre_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 49.6105, RMSE: 7.0435, MSLE: 0.0594, RMSLE: 0.2438, R2: 0.7435

# %% [markdown]
# #### 3rd Cycle - 선형 회귀 모델 학습 결과
# - R2 Score가 만족스러운 수준까지 향상됨
# - Polynomial, OLS, VIF 등을 활용해서 더욱 나은 성능의 모델을 구현해보기

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.0000000e+00, 1.9860000e+02, 1.3240000e+02, ..., 6.8145025e+05,
#         7.4295000e+04, 8.1000000e+03],
#        [1.0000000e+00, 1.9860000e+02, 1.3240000e+02, ..., 6.8145025e+05,
#         2.3114000e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.3960000e+02, 2.0940000e+02, ..., 6.5108761e+05,
#         7.2621000e+04, 8.1000000e+03],
#        ...,
#        [1.0000000e+00, 1.4850000e+02, 1.3940000e+02, ..., 6.0840000e+05,
#         2.1840000e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.5910000e+02, 1.8670000e+02, ..., 6.2236321e+05,
#         2.2089200e+04, 7.8400000e+02],
#        [1.0000000e+00, 2.6090000e+02, 1.0050000e+02, ..., 5.7988225e+05,
#         2.1322000e+04, 7.8400000e+02]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 25.7876, RMSE: 5.0781, MSLE: 0.0294, RMSLE: 0.1714, R2: 0.8667

# %% [markdown]
# #### 3rd Cycle - 다항 회귀 모델 학습 결과
# - 회귀선의 차수가 2일 때 R2가 0.8667까지 향상됨
# - 선형 회귀 모델보다 높은 R2를 보임에 따라, 현재 데이터가 비선형이라고 할 수 있음
# - 아래에서 트리 회귀 모델 학습 결과와 비교 분석하면서 가장 높은 성능을 보인 모델 찾아보기

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = pre_c_df.iloc[:, :-1], pre_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 32.3654, RMSE: 5.6891, MSLE: 0.0472, RMSLE: 0.2172, R2: 0.8327
# RandomForestRegressor
# MSE: 19.6409, RMSE: 4.4318, MSLE: 0.0265, RMSLE: 0.1626, R2: 0.8985
# GradientBoostingRegressor
# MSE: 20.8236, RMSE: 4.5633, MSLE: 0.0277, RMSLE: 0.1663, R2: 0.8923
# XGBRegressor
# MSE: 17.0724, RMSE: 4.1319, MSLE: 0.0216, RMSLE: 0.1471, R2: 0.9117
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000111 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 658
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 8
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 15.3919, RMSE: 3.9232, MSLE: 0.0191, RMSLE: 0.1380, R2: 0.9204

# %% [markdown]
# #### 3rd Cycle - 각종 회귀 모델 학습 결과
# - 전반적으로 R2가 0.8 이상으로, 우수한 결과를 보여줌
# - 단, 과적합 발생 가능성도 존재하니 VIF와 pairplot으로 다중 공선성 발생 여부 확인

# %% [markdown]
# ### VIF Score 출력

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# feature 별 VIF Score를 출력해주는 함수
def get_vif(features):
    vif = pd.DataFrame()
    vif['vif_score'] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]
    vif['feature'] = features.columns
    return vif

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
#     vif_score             feature
# 0   18.189222              Cement
# 1    3.313920  Blast Furnace Slag
# 2    6.222276             Fly Ash
# 3  131.798549               Water
# 4    7.501128    Superplasticizer
# 5  116.571303    Coarse Aggregate
# 6  124.096826      Fine Aggregate
# 7    2.289399                 Age

# %% [markdown]
# #### 중간 분석
# - Water와 Coarse Aggregate, Fine Aggregate에서 VIF Score가 매우 높은 수치를 보임
# - 또한 Cement 역시 10 이상의 높은 수치를 보여줌

# %%
# 다중공선성 존재 여부를 확인하기 위해 pairplot 시각화
sns.pairplot(features)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 3rd Cycle - VIF Score 출력 결과
# - 4개의 feature에서 높은 다중 공선성이 확인됨
# - 아래의 OLS 평가와 종합해서 제거할 feature 선정

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.960
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2128.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        15:40:03   Log-Likelihood:                         -2428.3
# No. Observations:                 720   AIC:                                      4873.
# Df Residuals:                     712   BIC:                                      4909.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Cement                 0.1055      0.004     25.582      0.000       0.097       0.114
# Blast Furnace Slag     0.0883      0.005     17.846      0.000       0.079       0.098
# Fly Ash                0.0652      0.007      8.783      0.000       0.051       0.080
# Water                 -0.1533      0.017     -9.125      0.000      -0.186      -0.120
# Superplasticizer       0.4343      0.096      4.537      0.000       0.246       0.622
# Coarse Aggregate       0.0076      0.003      2.623      0.009       0.002       0.013
# Fine Aggregate         0.0041      0.004      1.107      0.269      -0.003       0.011
# Age                    0.3021      0.009     32.442      0.000       0.284       0.320
# ==============================================================================
# Omnibus:                        3.171   Durbin-Watson:                   1.299
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                3.387
# Skew:                           0.061   Prob(JB):                        0.184
# Kurtosis:                       3.313   Cond. No.                         477.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 3rd Cycle - OLS 출력 결과
# - Fine Aggregate가 target에 미치는 영향이 적은 것으로 확인됨에 따라 다음 사이클에서는 제거

# %% [markdown]
# ### 4th Cycle
# - corr(), VIF, OLS를 종합했을 때 삭제할 feature들
# > - Fly Ash: Superplasticizer와의 상관관계가 높지만, target과의 상관관계는 낮음
# > - Fine Aggregate: target에 미치는 영향력이 낮음
#
# - 이번 사이클 결과 보고 추후 전처리 방향 판단

# %% [markdown]
# ### 4th Cycle - 데이터 전처리

# %%
# 이전 사이클 때 사용한 데이터 세트에서 FLy Ash와 Fine Aggregate를 제거한 새로운 데이터 세트 생성
fourth_c_df = pre_c_df.drop(labels=['Fly Ash', 'Fine Aggregate'], axis=1)
fourth_c_df
# Out:
#      Cement  Blast Furnace Slag  Water  Superplasticizer  Coarse Aggregate  \
# 0     198.6               132.4  192.0               0.0             978.4
# 1     198.6               132.4  192.0               0.0             978.4
# 2     139.6               209.4  192.0               0.0            1047.0
# 3     139.6               209.4  192.0               0.0            1047.0
# 4     139.6               209.4  192.0               0.0            1047.0
# ..      ...                 ...    ...               ...               ...
# 715   264.5               111.0  195.5               5.9             832.6
# 716   276.4               116.0  179.6               8.9             870.1
# 717   148.5               139.4  192.7               6.1             892.4
# 718   159.1               186.7  175.6              11.3             989.6
# 719   260.9               100.5  200.6               8.6             864.5
#
#      Age  Strength
# 0     90     38.07
# 1     28     28.02
# 2     90     39.36
# 3     28     28.24
# 4      3      8.06
# ..   ...       ...
# 715   28     41.54
# 716   28     44.28
# 717   28     23.70
# 718   28     32.77
# 719   28     32.40
#
# [720 rows x 7 columns]

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
fourth_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Age                   0.567925
# Superplasticizer      0.441279
# Cement                0.326046
# Blast Furnace Slag    0.093006
# Coarse Aggregate     -0.191517
# Water                -0.389538
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(fourth_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
fourth_c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag     Water  Superplasticizer  \
# Cement              1.000000           -0.296936 -0.051506         -0.009158
# Blast Furnace Slag -0.296936            1.000000  0.179947         -0.006695
# Water              -0.051506            0.179947  1.000000         -0.669075
# Superplasticizer   -0.009158           -0.006695 -0.669075          1.000000
# Coarse Aggregate   -0.160193           -0.379349 -0.241992         -0.186904
# Age                -0.092379           -0.077498 -0.046674          0.049983
#
#                     Coarse Aggregate       Age
# Cement                     -0.160193 -0.092379
# Blast Furnace Slag         -0.379349 -0.077498
# Water                      -0.241992 -0.046674
# Superplasticizer           -0.186904  0.049983
# Coarse Aggregate            1.000000  0.052986
# Age                         0.052986  1.000000

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = fourth_c_df.iloc[:, :-1], fourth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 54.8989, RMSE: 7.4094, MSLE: 0.0624, RMSLE: 0.2499, R2: 0.7162

# %% [markdown]
# #### 4th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2 Score가 약간 감소함
# - 모델의 성능이 떨어졌거나, 비선형의 성격이 강해진 것이 원인으로 추정됨

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.0000000e+00, 1.9860000e+02, 1.3240000e+02, ..., 9.5726656e+05,
#         8.8056000e+04, 8.1000000e+03],
#        [1.0000000e+00, 1.9860000e+02, 1.3240000e+02, ..., 9.5726656e+05,
#         2.7395200e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.3960000e+02, 2.0940000e+02, ..., 1.0962090e+06,
#         9.4230000e+04, 8.1000000e+03],
#        ...,
#        [1.0000000e+00, 1.4850000e+02, 1.3940000e+02, ..., 7.9637776e+05,
#         2.4987200e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.5910000e+02, 1.8670000e+02, ..., 9.7930816e+05,
#         2.7708800e+04, 7.8400000e+02],
#        [1.0000000e+00, 2.6090000e+02, 1.0050000e+02, ..., 7.4736025e+05,
#         2.4206000e+04, 7.8400000e+02]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 28.8762, RMSE: 5.3737, MSLE: 0.0403, RMSLE: 0.2007, R2: 0.8507

# %% [markdown]
# #### 4th Cycle - 다항 회귀 모델 학습 결과
# - 이전 사이클과 마찬가지로, 회귀선의 차수가 2일 때 가장 높은 R2를 보임
# - 단, 이전 사이클에 비해 R2가 약간 감소함에 따라 모델의 예측 성능이 감소한 것으로 추정

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = fourth_c_df.iloc[:, :-1], fourth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 28.9042, RMSE: 5.3763, MSLE: 0.0367, RMSLE: 0.1916, R2: 0.8506
# RandomForestRegressor
# MSE: 18.8250, RMSE: 4.3388, MSLE: 0.0242, RMSLE: 0.1554, R2: 0.9027
# GradientBoostingRegressor
# MSE: 18.8043, RMSE: 4.3364, MSLE: 0.0245, RMSLE: 0.1566, R2: 0.9028
# XGBRegressor
# MSE: 14.0006, RMSE: 3.7417, MSLE: 0.0188, RMSLE: 0.1371, R2: 0.9276
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 468
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 6
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 16.4221, RMSE: 4.0524, MSLE: 0.0213, RMSLE: 0.1461, R2: 0.9151

# %% [markdown]
# #### 4th Cycle - 각종 회귀 모델 학습 결과
# - 이전 사이클과는 다르게, XGB 회귀 모델의 R2가 가장 높게 측정됨
# - VIF와 pairplot으로 다중공선성 여부 확인해보기

# %% [markdown]
# ### VIF Score 출력

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
#    vif_score             feature
# 0  10.808224              Cement
# 1   2.060830  Blast Furnace Slag
# 2  91.060257               Water
# 3   2.868769    Superplasticizer
# 4  84.965223    Coarse Aggregate
# 5   2.276336                 Age

# %% [markdown]
# #### 중간 분석
# - Water와 Coarse Aggregate, Cement가 여전히 높은 VIF Score를 보임

# %%
# 다중공선성 존재 여부를 확인하기 위해 pairplot 시각화
sns.pairplot(features)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 4th Cycle - VIF Score 출력 결과
# - 3개의 feature에서 높은 다중 공선성이 확인됨
# - 아래의 OLS 평가와 종합해서 제거할 feature 선정

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              2554.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        16:09:25   Log-Likelihood:                         -2465.5
# No. Observations:                 720   AIC:                                      4943.
# Df Residuals:                     714   BIC:                                      4970.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Cement                 0.0824      0.003     24.659      0.000       0.076       0.089
# Blast Furnace Slag     0.0623      0.004     15.189      0.000       0.054       0.070
# Water                 -0.1071      0.015     -7.293      0.000      -0.136      -0.078
# Superplasticizer       1.0366      0.062     16.652      0.000       0.914       1.159
# Coarse Aggregate       0.0106      0.003      4.083      0.000       0.006       0.016
# Age                    0.3053      0.010     31.266      0.000       0.286       0.324
# ==============================================================================
# Omnibus:                        2.035   Durbin-Watson:                   1.200
# Prob(Omnibus):                  0.361   Jarque-Bera (JB):                1.864
# Skew:                           0.110   Prob(JB):                        0.394
# Kurtosis:                       3.118   Cond. No.                         234.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 4th Cycle - OLS 출력 결과
# - 타겟에 영향이 적은 feature는 찾지 못함
# - 따라서 위의 corr()과 VIF만 참고하여 다음 사이클에서 제거할 feature 선정

# %% [markdown]
# ### 5th Cycle - 데이터 전처리
# - 이전 사이클에서 사용한 데이터 세트를 기반으로 일부 feature 제거 후 테스트
# > - Blast Furnace Slag: 타겟과의 상관관계 낮음
# > - Water: VIF Score가 높고, Superplasticizer와 음의 상관관계 높음

# %%
# 이전 사이클의 데이터 세트에서 일부 feature를 제거한 새로운 데이터 세트 생성
fifth_c_df = fourth_c_df.drop(labels=['Blast Furnace Slag', 'Water'], axis=1)
fifth_c_df
# Out:
#      Cement  Superplasticizer  Coarse Aggregate  Age  Strength
# 0     198.6               0.0             978.4   90     38.07
# 1     198.6               0.0             978.4   28     28.02
# 2     139.6               0.0            1047.0   90     39.36
# 3     139.6               0.0            1047.0   28     28.24
# 4     139.6               0.0            1047.0    3      8.06
# ..      ...               ...               ...  ...       ...
# 715   264.5               5.9             832.6   28     41.54
# 716   276.4               8.9             870.1   28     44.28
# 717   148.5               6.1             892.4   28     23.70
# 718   159.1              11.3             989.6   28     32.77
# 719   260.9               8.6             864.5   28     32.40
#
# [720 rows x 5 columns]

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
fifth_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Age                 0.567925
# Superplasticizer    0.441279
# Cement              0.326046
# Coarse Aggregate   -0.191517
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(fifth_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
fifth_c_df.iloc[:, :-1].corr()
# Out:
#                     Cement  Superplasticizer  Coarse Aggregate       Age
# Cement            1.000000         -0.009158         -0.160193 -0.092379
# Superplasticizer -0.009158          1.000000         -0.186904  0.049983
# Coarse Aggregate -0.160193         -0.186904          1.000000  0.052986
# Age              -0.092379          0.049983          0.052986  1.000000

# %% [markdown]
# #### 5th Cycle - 상관관계 시각화 결과
# - 이전 사이클까지 존재했던 일부 feature 사이의 높은 상관관계가 해소됨
# - 이에 따라 우수한 학습 결과를 얻을 수 있을 것으로 기대

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = fifth_c_df.iloc[:, :-1], fifth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 71.7580, RMSE: 8.4710, MSLE: 0.0832, RMSLE: 0.2884, R2: 0.6290

# %% [markdown]
# #### 5th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2 Score가 더욱 감소함
# - 이는 타겟과의 상관관계가 높았던 Water를 제거해서 발생한 현상으로 추정

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.0000000e+00, 1.9860000e+02, 0.0000000e+00, ..., 9.5726656e+05,
#         8.8056000e+04, 8.1000000e+03],
#        [1.0000000e+00, 1.9860000e+02, 0.0000000e+00, ..., 9.5726656e+05,
#         2.7395200e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.3960000e+02, 0.0000000e+00, ..., 1.0962090e+06,
#         9.4230000e+04, 8.1000000e+03],
#        ...,
#        [1.0000000e+00, 1.4850000e+02, 6.1000000e+00, ..., 7.9637776e+05,
#         2.4987200e+04, 7.8400000e+02],
#        [1.0000000e+00, 1.5910000e+02, 1.1300000e+01, ..., 9.7930816e+05,
#         2.7708800e+04, 7.8400000e+02],
#        [1.0000000e+00, 2.6090000e+02, 8.6000000e+00, ..., 7.4736025e+05,
#         2.4206000e+04, 7.8400000e+02]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 53.0961, RMSE: 7.2867, MSLE: 0.0602, RMSLE: 0.2454, R2: 0.7255

# %% [markdown]
# #### 5th Cycle - 다항 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2가 눈에 띄게 감소함

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = fifth_c_df.iloc[:, :-1], fifth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 24.7918, RMSE: 4.9791, MSLE: 0.0387, RMSLE: 0.1967, R2: 0.8718
# RandomForestRegressor
# MSE: 28.0523, RMSE: 5.2964, MSLE: 0.0341, RMSLE: 0.1847, R2: 0.8550
# GradientBoostingRegressor
# MSE: 32.7540, RMSE: 5.7231, MSLE: 0.0365, RMSLE: 0.1911, R2: 0.8307
# XGBRegressor
# MSE: 18.8234, RMSE: 4.3386, MSLE: 0.0260, RMSLE: 0.1613, R2: 0.9027
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 312
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 4
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 28.3351, RMSE: 5.3231, MSLE: 0.0344, RMSLE: 0.1855, R2: 0.8535

# %% [markdown]
# #### 5th Cycle - 각종 회귀 모델 학습 결과
# - 이전 사이클과 마찬가지로, XGB 회귀 모델의 R2가 가장 높게 측정됨
# - 또한, 위의 모델 전부 R2가 0.85 이상의 우수한 수치를 보임
# - VIF와 pairplot으로 다중공선성이 남아있는지 확인해보기

# %% [markdown]
# ### VIF Score 출력

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
#    vif_score           feature
# 0   9.261013            Cement
# 1   2.435195  Superplasticizer
# 2  11.784120  Coarse Aggregate
# 3   2.256292               Age

# %%
# 다중공선성 존재 여부를 확인하기 위해 pairplot 시각화
sns.pairplot(features)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 5th Cycle - VIF Score 출력 결과
# - Coarse Aggrgate에서 높은 다중 공선성이 확인됨

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.941
# Model:                            OLS   Adj. R-squared (uncentered):              0.941
# Method:                 Least Squares   F-statistic:                              2859.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        16:24:30   Log-Likelihood:                         -2566.3
# No. Observations:                 720   AIC:                                      5141.
# Df Residuals:                     716   BIC:                                      5159.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Cement               0.0664      0.004     18.672      0.000       0.059       0.073
# Superplasticizer     1.2537      0.066     19.030      0.000       1.124       1.383
# Coarse Aggregate    -0.0018      0.001     -1.637      0.102      -0.004       0.000
# Age                  0.2922      0.011     26.161      0.000       0.270       0.314
# ==============================================================================
# Omnibus:                        9.097   Durbin-Watson:                   1.189
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.328
# Skew:                           0.274   Prob(JB):                      0.00943
# Kurtosis:                       2.900   Cond. No.                         211.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 5th Cycle - OLS 출력 결과
# - 위의 VIF Score에서 이상이 발생했던 Coarse Aggregate가 타겟에 주는 영향이 적은 것으로 나타남
# - 따라서 다음 사이클에서는 해당 feature를 삭제

# %% [markdown]
# ### 6th Cycle - 데이터 전처리
# - Coarse Aggregate 제거
# - 만약 전반적으로 R2 Score가 떨어졌다면, Blast Furnace Slag를 제거하지 않고도 진행해볼 것

# %%
# 이전 사이클의 데이터 세트에서 일부 feature를 제거한 새로운 데이터 세트 생성
sixth_c_df = fifth_c_df.drop(labels=['Coarse Aggregate'], axis=1)
sixth_c_df
# Out:
#      Cement  Superplasticizer  Age  Strength
# 0     198.6               0.0   90     38.07
# 1     198.6               0.0   28     28.02
# 2     139.6               0.0   90     39.36
# 3     139.6               0.0   28     28.24
# 4     139.6               0.0    3      8.06
# ..      ...               ...  ...       ...
# 715   264.5               5.9   28     41.54
# 716   276.4               8.9   28     44.28
# 717   148.5               6.1   28     23.70
# 718   159.1              11.3   28     32.77
# 719   260.9               8.6   28     32.40
#
# [720 rows x 4 columns]

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
sixth_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Age                 0.567925
# Superplasticizer    0.441279
# Cement              0.326046
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(sixth_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
sixth_c_df.iloc[:, :-1].corr()
# Out:
#                     Cement  Superplasticizer       Age
# Cement            1.000000         -0.009158 -0.092379
# Superplasticizer -0.009158          1.000000  0.049983
# Age              -0.092379          0.049983  1.000000

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = sixth_c_df.iloc[:, :-1], sixth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 71.2265, RMSE: 8.4396, MSLE: 0.0810, RMSLE: 0.2846, R2: 0.6317

# %% [markdown]
# #### 6th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2 Score가 약간 상승함
# - 이는 다중 공선성이 발생한 Coarse Aggregate를 제거하면서 발생한 현상으로 추정

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.0000e+00, 1.9860e+02, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         8.1000e+03],
#        [1.0000e+00, 1.9860e+02, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         7.8400e+02],
#        [1.0000e+00, 1.3960e+02, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         8.1000e+03],
#        ...,
#        [1.0000e+00, 1.4850e+02, 6.1000e+00, ..., 3.7210e+01, 1.7080e+02,
#         7.8400e+02],
#        [1.0000e+00, 1.5910e+02, 1.1300e+01, ..., 1.2769e+02, 3.1640e+02,
#         7.8400e+02],
#        [1.0000e+00, 2.6090e+02, 8.6000e+00, ..., 7.3960e+01, 2.4080e+02,
#         7.8400e+02]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 47.5822, RMSE: 6.8980, MSLE: 0.0559, RMSLE: 0.2365, R2: 0.7540

# %% [markdown]
# #### 6th Cycle - 다항 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2가 약간 증가했으며, 여전히 회귀선의 차수가 2일 때 가장 높은 R2를 기록함

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = sixth_c_df.iloc[:, :-1], sixth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 56.3935, RMSE: 7.5096, MSLE: 0.0696, RMSLE: 0.2638, R2: 0.7084
# RandomForestRegressor
# MSE: 39.2231, RMSE: 6.2628, MSLE: 0.0466, RMSLE: 0.2159, R2: 0.7972
# GradientBoostingRegressor
# MSE: 33.8191, RMSE: 5.8154, MSLE: 0.0387, RMSLE: 0.1966, R2: 0.8252
# XGBRegressor
# MSE: 31.2125, RMSE: 5.5868, MSLE: 0.0395, RMSLE: 0.1988, R2: 0.8386
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 188
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 3
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 31.7834, RMSE: 5.6377, MSLE: 0.0393, RMSLE: 0.1982, R2: 0.8357

# %% [markdown]
# #### 6th Cycle - 각종 회귀 모델 학습 결과
# - 이전 사이클과 마찬가지로, XGB 회귀 모델의 R2가 가장 높게 측정됨
# - 전반적으로 R2가 이전 사이클에 비해 크게 감소함

# %% [markdown]
# ### VIF Score 출력

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
#    vif_score           feature
# 0   2.740050            Cement
# 1   2.254662  Superplasticizer
# 2   1.958221               Age

# %%
# 다중공선성 존재 여부를 확인하기 위해 pairplot 시각화
sns.pairplot(features)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### 5th Cycle - VIF Score 출력 결과
# - 기존에 존재했던 다중 공선성이 전부 해소됨

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.941
# Model:                            OLS   Adj. R-squared (uncentered):              0.941
# Method:                 Least Squares   F-statistic:                              3803.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        16:33:20   Log-Likelihood:                         -2567.6
# No. Observations:                 720   AIC:                                      5141.
# Df Residuals:                     717   BIC:                                      5155.
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Cement               0.0615      0.002     31.765      0.000       0.058       0.065
# Superplasticizer     1.2243      0.063     19.291      0.000       1.100       1.349
# Age                  0.2855      0.010     27.410      0.000       0.265       0.306
# ==============================================================================
# Omnibus:                       10.945   Durbin-Watson:                   1.195
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.261
# Skew:                           0.305   Prob(JB):                      0.00359
# Kurtosis:                       2.939   Cond. No.                         54.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 6th Cycle - OLS 출력 결과
# - 전반적으로 이전 사이클과 거의 동일한 양상을 보임

# %% [markdown]
# ### 7th Cycle
# - 만약 4 → 5 사이클로 넘어갈 때 Blast Furnace Slag를 제거하지 않았다면 R2가 지금보다 개선되었을까?
# - 4번째 사이클에서 사용한 데이터 세트에서 Water와 Coarse Aggregate를 제거하고 이전 사이클과 결과 비교
# > - 이전 사이클의 데이터에서 Blast Furnace Slag가 다시 추가되는 것

# %% [markdown]
# ### 7th Cycle - 데이터 전처리

# %%
# 4번째 사이클에서의 데이터 세트에서 일부 feature 제거
seventh_c_df = fourth_c_df.drop(labels=['Water', 'Coarse Aggregate'], axis=1)
seventh_c_df
# Out:
#      Cement  Blast Furnace Slag  Superplasticizer  Age  Strength
# 0     198.6               132.4               0.0   90     38.07
# 1     198.6               132.4               0.0   28     28.02
# 2     139.6               209.4               0.0   90     39.36
# 3     139.6               209.4               0.0   28     28.24
# 4     139.6               209.4               0.0    3      8.06
# ..      ...                 ...               ...  ...       ...
# 715   264.5               111.0               5.9   28     41.54
# 716   276.4               116.0               8.9   28     44.28
# 717   148.5               139.4               6.1   28     23.70
# 718   159.1               186.7              11.3   28     32.77
# 719   260.9               100.5               8.6   28     32.40
#
# [720 rows x 5 columns]

# %%
# 원본 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
seventh_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# Age                   0.567925
# Superplasticizer      0.441279
# Cement                0.326046
# Blast Furnace Slag    0.093006
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(seventh_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
seventh_c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag  Superplasticizer       Age
# Cement              1.000000           -0.296936         -0.009158 -0.092379
# Blast Furnace Slag -0.296936            1.000000         -0.006695 -0.077498
# Superplasticizer   -0.009158           -0.006695          1.000000  0.049983
# Age                -0.092379           -0.077498          0.049983  1.000000

# %% [markdown]
# #### 7th Cycle - 상관관계 시각화 결과
# - Cement와 Blast Furnace Slag 사이에 상대적으로 높은 음의 상관관계가 발생
# - 아래의 학습 결과로 Blast Furnace Slag 추가에 따른 변화가 어떤지 알아볼 것

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = seventh_c_df.iloc[:, :-1], seventh_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 56.8339, RMSE: 7.5388, MSLE: 0.0648, RMSLE: 0.2545, R2: 0.7062

# %% [markdown]
# #### 7th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2 Score가 상승함

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.0000e+00, 1.9860e+02, 1.3240e+02, ..., 0.0000e+00, 0.0000e+00,
#         8.1000e+03],
#        [1.0000e+00, 1.9860e+02, 1.3240e+02, ..., 0.0000e+00, 0.0000e+00,
#         7.8400e+02],
#        [1.0000e+00, 1.3960e+02, 2.0940e+02, ..., 0.0000e+00, 0.0000e+00,
#         8.1000e+03],
#        ...,
#        [1.0000e+00, 1.4850e+02, 1.3940e+02, ..., 3.7210e+01, 1.7080e+02,
#         7.8400e+02],
#        [1.0000e+00, 1.5910e+02, 1.8670e+02, ..., 1.2769e+02, 3.1640e+02,
#         7.8400e+02],
#        [1.0000e+00, 2.6090e+02, 1.0050e+02, ..., 7.3960e+01, 2.4080e+02,
#         7.8400e+02]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 35.5562, RMSE: 5.9629, MSLE: 0.0463, RMSLE: 0.2152, R2: 0.8162

# %% [markdown]
# #### 7th Cycle - 다항 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2가 약간 증가함
# - 여전히 회귀선의 차수가 2일 때 가장 높은 R2를 기록함

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = seventh_c_df.iloc[:, :-1], seventh_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 30.0916, RMSE: 5.4856, MSLE: 0.0422, RMSLE: 0.2055, R2: 0.8444
# RandomForestRegressor
# MSE: 23.0375, RMSE: 4.7997, MSLE: 0.0289, RMSLE: 0.1701, R2: 0.8809
# GradientBoostingRegressor
# MSE: 23.6710, RMSE: 4.8653, MSLE: 0.0285, RMSLE: 0.1689, R2: 0.8776
# XGBRegressor
# MSE: 17.3552, RMSE: 4.1660, MSLE: 0.0241, RMSLE: 0.1552, R2: 0.9103
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 251
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 4
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 20.7313, RMSE: 4.5532, MSLE: 0.0266, RMSLE: 0.1631, R2: 0.8928

# %% [markdown]
# #### 7th Cycle - 각종 회귀 모델 학습 결과
# - 전반적으로 R2가 이전 사이클에 비해 상승함
# - 가장 높은 R2를 보이는 XGB 회귀 모델의 경우, 0.91이라는 매우 우수한 수치가 관측됨

# %% [markdown]
# ### VIF Score 출력

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
#    vif_score             feature
# 0   2.876193              Cement
# 1   1.411223  Blast Furnace Slag
# 2   2.308734    Superplasticizer
# 3   1.969577                 Age

# %% [markdown]
# #### 7th Cycle - VIF Score 출력 결과
# - 이전 사이클과 마찬가지로, 다중 공선성이 발생한 feature가 존재하지 않음

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.950
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              3366.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        16:51:30   Log-Likelihood:                         -2510.8
# No. Observations:                 720   AIC:                                      5030.
# Df Residuals:                     716   BIC:                                      5048.
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Cement                 0.0571      0.002     31.120      0.000       0.053       0.061
# Blast Furnace Slag     0.0400      0.004     11.067      0.000       0.033       0.047
# Superplasticizer       1.1237      0.059     18.922      0.000       1.007       1.240
# Age                    0.2774      0.010     28.715      0.000       0.258       0.296
# ==============================================================================
# Omnibus:                       12.950   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.399
# Skew:                           0.333   Prob(JB):                      0.00123
# Kurtosis:                       2.956   Cond. No.                         56.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 7th Cycle - OLS 출력 결과
# - 이전 사이클에 비해 R2 Score가 약간 상승함

# %% [markdown]
# ### 7th Cycle - 결론
# - 현재의 데이터 세트가 다중 공선성이 발생하지 않은 데이터 세트 중 가장 높은 R2 Score를 기록함에 따라
#   가장 전처리가 잘 되어있으며, 필요한 feature들만 모여있는 데이터 세트라고 할 수 있음
# - 6번째와 7번째 사이클을 비교했을 때, 타겟과의 상관관계가 낮다고 무작정 제거하는 것이 아니라,
#   해당 feature의 다중 공선성 발생 여부도 고려하여 제거할 feature를 선별하는 것이 좋다는 것을 알 수 있었음

# %% [markdown]
# ### 8th Cycle
# - 7번째 사이클에서 얻은 가중치(coef)를 기반으로 Feature Engineering을 거친다면, 더 나은 결과를 얻을 수 있을까?
#
# > - 각 feature 별 가중치를 해당 feature에 곱하기
# >> - 가중치가 양수: feature 값 * (가중치 + 1)
# >> - 가중치가 음수: feature 값 * (-가중치)
# > - 곱셈을 마친 값끼리 전부 합하고, 이렇게 얻은 값을 새로운 컬럼으로 만들어 넣기
# > - 타겟과 해당 feature 만으로 단변량 회귀 분석

# %%
# 이전 사이클의 데이터 세트 복사
eighth_c_df = seventh_c_df.copy()
eighth_c_df
# Out:
#      Cement  Blast Furnace Slag  Superplasticizer  Age  Strength
# 0     198.6               132.4               0.0   90     38.07
# 1     198.6               132.4               0.0   28     28.02
# 2     139.6               209.4               0.0   90     39.36
# 3     139.6               209.4               0.0   28     28.24
# 4     139.6               209.4               0.0    3      8.06
# ..      ...                 ...               ...  ...       ...
# 715   264.5               111.0               5.9   28     41.54
# 716   276.4               116.0               8.9   28     44.28
# 717   148.5               139.4               6.1   28     23.70
# 718   159.1               186.7              11.3   28     32.77
# 719   260.9               100.5               8.6   28     32.40
#
# [720 rows x 5 columns]

# %%
# 각 feature 내 값에 해당 feature의 가중치를 곱해서 할당
eighth_c_df['Cement'] = eighth_c_df['Cement'] * 1.0571
eighth_c_df['Blast Furnace Slag'] = eighth_c_df['Blast Furnace Slag'] * 1.04
eighth_c_df['Superplasticizer'] = eighth_c_df['Superplasticizer'] * 2.1237
eighth_c_df['Age'] = eighth_c_df['Age'] * 1.2774

eighth_c_df
# Out:
#         Cement  Blast Furnace Slag  Superplasticizer       Age  Strength
# 0    209.94006             137.696           0.00000  114.9660     38.07
# 1    209.94006             137.696           0.00000   35.7672     28.02
# 2    147.57116             217.776           0.00000  114.9660     39.36
# 3    147.57116             217.776           0.00000   35.7672     28.24
# 4    147.57116             217.776           0.00000    3.8322      8.06
# ..         ...                 ...               ...       ...       ...
# 715  279.60295             115.440          12.52983   35.7672     41.54
# 716  292.18244             120.640          18.90093   35.7672     44.28
# 717  156.97935             144.976          12.95457   35.7672     23.70
# 718  168.18461             194.168          23.99781   35.7672     32.77
# 719  275.79739             104.520          18.26382   35.7672     32.40
#
# [720 rows x 5 columns]

# %%
# 현재 feature 값을 모두 합한 값을 담은 새로운 컬럼 생성
eighth_c_df['FE'] = eighth_c_df['Cement'] + eighth_c_df['Blast Furnace Slag'] + \
                                                        eighth_c_df['Superplasticizer'] + eighth_c_df['Age']

eighth_c_df
# Out:
#         Cement  Blast Furnace Slag  Superplasticizer       Age  Strength  \
# 0    209.94006             137.696           0.00000  114.9660     38.07
# 1    209.94006             137.696           0.00000   35.7672     28.02
# 2    147.57116             217.776           0.00000  114.9660     39.36
# 3    147.57116             217.776           0.00000   35.7672     28.24
# 4    147.57116             217.776           0.00000    3.8322      8.06
# ..         ...                 ...               ...       ...       ...
# 715  279.60295             115.440          12.52983   35.7672     41.54
# 716  292.18244             120.640          18.90093   35.7672     44.28
# 717  156.97935             144.976          12.95457   35.7672     23.70
# 718  168.18461             194.168          23.99781   35.7672     32.77
# 719  275.79739             104.520          18.26382   35.7672     32.40
#
#             FE
# 0    462.60206
# 1    383.40326
# 2    480.31316
# 3    401.11436
# 4    369.17936
# ..         ...
# 715  443.33998
# 716  467.49057
# 717  350.67712
# 718  422.11762
# 719  434.34841
#
# [720 rows x 6 columns]

# %%
# 컬럼 순서 재배치
columns = ['Cement', 'Blast Furnace Slag', 'Superplasticizer', 'Age', 'FE', 'Strength']

eighth_c_df = eighth_c_df.loc[:, columns]
eighth_c_df
# Out:
#         Cement  Blast Furnace Slag  Superplasticizer       Age         FE  \
# 0    209.94006             137.696           0.00000  114.9660  462.60206
# 1    209.94006             137.696           0.00000   35.7672  383.40326
# 2    147.57116             217.776           0.00000  114.9660  480.31316
# 3    147.57116             217.776           0.00000   35.7672  401.11436
# 4    147.57116             217.776           0.00000    3.8322  369.17936
# ..         ...                 ...               ...       ...        ...
# 715  279.60295             115.440          12.52983   35.7672  443.33998
# 716  292.18244             120.640          18.90093   35.7672  467.49057
# 717  156.97935             144.976          12.95457   35.7672  350.67712
# 718  168.18461             194.168          23.99781   35.7672  422.11762
# 719  275.79739             104.520          18.26382   35.7672  434.34841
#
#      Strength
# 0       38.07
# 1       28.02
# 2       39.36
# 3       28.24
# 4        8.06
# ..        ...
# 715     41.54
# 716     44.28
# 717     23.70
# 718     32.77
# 719     32.40
#
# [720 rows x 6 columns]

# %%
# 데이터 세트에서 feature와 타겟 데이터와의 상관관계 출력
eighth_c_df.corr()['Strength'].sort_values(ascending=False)[1:]
# Out:
# FE                    0.603919
# Age                   0.567925
# Superplasticizer      0.441279
# Cement                0.326046
# Blast Furnace Slag    0.093006
# Name: Strength, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# feature들 간 상관관계 출력
sns.heatmap(eighth_c_df.iloc[:, :-1].corr(), cmap='Oranges')
plt.show()

# %%
# feature 간 상관관계를 데이터 세트 형태로 출력
eighth_c_df.iloc[:, :-1].corr()
# Out:
#                       Cement  Blast Furnace Slag  Superplasticizer       Age  \
# Cement              1.000000           -0.296936         -0.009158 -0.092379
# Blast Furnace Slag -0.296936            1.000000         -0.006695 -0.077498
# Superplasticizer   -0.009158           -0.006695          1.000000  0.049983
# Age                -0.092379           -0.077498          0.049983  1.000000
# FE                  0.614933            0.481796          0.103080  0.220930
#
#                           FE
# Cement              0.614933
# Blast Furnace Slag  0.481796
# Superplasticizer    0.103080
# Age                 0.220930
# FE                  1.000000

# %% [markdown]
# #### 8th Cycle - 상관관계 시각화 결과
# - 기존 feature와 피쳐 엔지니어링 용도로 새로 생성한 컬럼 사이에 높은 상관관계가 관측됨
# - 또한, 새로운 컬럼은 타겟과 가장 높은 연관성을 보임

# %% [markdown]
# #### 의문점
# - 만약 기존 feature들을 제거하지 않고 학습을 진행하면 어떤 결과가 나올까?

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = eighth_c_df.iloc[:, :-1], eighth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 56.8339, RMSE: 7.5388, MSLE: 0.0648, RMSLE: 0.2545, R2: 0.7062

# %% [markdown]
# #### 8th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클과 동일한 R2를 기록함

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=2).fit_transform(features)
poly_features
# Out:
# array([[1.00000000e+00, 2.09940060e+02, 1.37696000e+02, ...,
#         1.32171812e+04, 5.31835084e+04, 2.14000666e+05],
#        [1.00000000e+00, 2.09940060e+02, 1.37696000e+02, ...,
#         1.27929260e+03, 1.37132611e+04, 1.46998060e+05],
#        [1.00000000e+00, 1.47571160e+02, 2.17776000e+02, ...,
#         1.32171812e+04, 5.52196828e+04, 2.30700732e+05],
#        ...,
#        [1.00000000e+00, 1.56979350e+02, 1.44976000e+02, ...,
#         1.27929260e+03, 1.25427387e+04, 1.22974442e+05],
#        [1.00000000e+00, 1.68184610e+02, 1.94168000e+02, ...,
#         1.27929260e+03, 1.50979653e+04, 1.78183285e+05],
#        [1.00000000e+00, 2.75797390e+02, 1.04520000e+02, ...,
#         1.27929260e+03, 1.55354265e+04, 1.88658541e+05]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 35.5514, RMSE: 5.9625, MSLE: 0.0463, RMSLE: 0.2152, R2: 0.8162

# %% [markdown]
# #### 8th Cycle - 다항 회귀 모델 학습 결과
# - 마찬가지로 이전 사이클과 동일한 R2가 기록됨

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = eighth_c_df.iloc[:, :-1], eighth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 38.6249, RMSE: 6.2149, MSLE: 0.0506, RMSLE: 0.2249, R2: 0.8003
# RandomForestRegressor
# MSE: 26.4382, RMSE: 5.1418, MSLE: 0.0328, RMSLE: 0.1810, R2: 0.8633
# GradientBoostingRegressor
# MSE: 23.2391, RMSE: 4.8207, MSLE: 0.0261, RMSLE: 0.1615, R2: 0.8799
# XGBRegressor
# MSE: 22.7571, RMSE: 4.7704, MSLE: 0.0304, RMSLE: 0.1742, R2: 0.8823
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000088 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 444
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 5
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 20.3829, RMSE: 4.5147, MSLE: 0.0277, RMSLE: 0.1664, R2: 0.8946

# %% [markdown]
# #### 8th Cycle - 각종 회귀 모델 학습 결과
# - 전반적으로 이전 사이클에 비해 R2가 감소함
# - LightGBM 모델이 가장 높은 R2를 기록함

# %% [markdown]
# ### VIF Score 출력

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# feature 별 VIF Score를 출력해주는 함수
def get_vif(features):
    vif = pd.DataFrame()
    vif['vif_score'] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]
    vif['feature'] = features.columns
    return vif

# %%
# feature 별 VIF Score 출력
get_vif(features)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#    vif_score             feature
# 0        inf              Cement
# 1        inf  Blast Furnace Slag
# 2        inf    Superplasticizer
# 3        inf                 Age
# 4        inf                  FE

# %% [markdown]
# #### 8th Cycle - VIF Score 출력 결과
# - 피쳐 엔지니어링 컬럼이 추가됨에 따라 모든 컬럼의 VIF Score가 무한대로 측정됨

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.950
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              3366.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        17:31:48   Log-Likelihood:                         -2510.8
# No. Observations:                 720   AIC:                                      5030.
# Df Residuals:                     716   BIC:                                      5048.
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Cement                -0.1137      0.006    -17.610      0.000      -0.126      -0.101
# Blast Furnace Slag    -0.1293      0.006    -19.987      0.000      -0.142      -0.117
# Superplasticizer       0.3614      0.023     15.742      0.000       0.316       0.406
# Age                    0.0494      0.009      5.544      0.000       0.032       0.067
# FE                     0.1677      0.005     32.064      0.000       0.157       0.178
# ==============================================================================
# Omnibus:                       12.950   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.399
# Skew:                           0.333   Prob(JB):                      0.00123
# Kurtosis:                       2.956   Cond. No.                     1.43e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 8.81e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### 8th Cycle - OLS 출력 결과
# - 이전 사이클과 R2는 동일하게 나타났으며, 전반적인 평가 지표 역시 거의 비슷한 양상을 보임

# %% [markdown]
# ### 9th Cycle - 데이터 전처리
# - 이전 사이클에서 기존 feature들을 모두 제거하고 FE만으로 단변량 회귀 분석

# %%
# FE와 타겟만 남은 데이터 세트 새로 생성
ninth_c_df = eighth_c_df.iloc[:, -2:]
ninth_c_df
# Out:
#             FE  Strength
# 0    462.60206     38.07
# 1    383.40326     28.02
# 2    480.31316     39.36
# 3    401.11436     28.24
# 4    369.17936      8.06
# ..         ...       ...
# 715  443.33998     41.54
# 716  467.49057     44.28
# 717  350.67712     23.70
# 718  422.11762     32.77
# 719  434.34841     32.40
#
# [720 rows x 2 columns]

# %% [markdown]
# ### 선형 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = ninth_c_df.iloc[:, :-1], ninth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 114.2947, RMSE: 10.6909, MSLE: 0.1398, RMSLE: 0.3739, R2: 0.4091

# %% [markdown]
# #### 9th Cycle - 선형 회귀 모델 학습 결과
# - 이전 사이클에 비해 R2가 크게 감소함

# %% [markdown]
# ### Polynomial(다항 회귀) 학습

# %%
from sklearn.preprocessing import PolynomialFeatures

# 다항 회귀: degree는 차수를 의미함
poly_features = PolynomialFeatures(degree=3).fit_transform(features)
poly_features
# Out:
# array([[1.00000000e+00, 4.62602060e+02, 2.14000666e+05, 9.89971489e+07],
#        [1.00000000e+00, 3.83403260e+02, 1.46998060e+05, 5.63595353e+07],
#        [1.00000000e+00, 4.80313160e+02, 2.30700732e+05, 1.10808597e+08],
#        ...,
#        [1.00000000e+00, 3.50677120e+02, 1.22974442e+05, 4.31243233e+07],
#        [1.00000000e+00, 4.22117620e+02, 1.78183285e+05, 7.52143042e+07],
#        [1.00000000e+00, 4.34348410e+02, 1.88658541e+05, 8.19435374e+07]])

# %%
X_train, X_test, y_train, y_test = \
train_test_split(poly_features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 테스트 데이터 예측 후 평가
prediction = l_r.predict(X_test)

get_evaluation(y_test, prediction)
# Out:
# MSE: 112.9796, RMSE: 10.6292, MSLE: 0.1377, RMSLE: 0.3711, R2: 0.4159

# %% [markdown]
# #### 9th Cycle - 다항 회귀 모델 학습 결과
# - 마찬가지로 이전 사이클에 비해 R2가 크게 감소함
# - 이전 사이클들과는 다르게 회귀선의 차수가 3일 떄 가장 높은 R2를 기록함

# %% [markdown]
# ### 각종 회귀 모델로 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 데이터 세트 분할 후 선형 회귀 모델로 훈련
features, targets = ninth_c_df.iloc[:, :-1], ninth_c_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# 회귀모델 선언
# 주의: poly랑 병행하지 말 것
dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=100)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

# 반복문으로 fit하기 위해 list 안에 담기
models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]

for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 202.2383, RMSE: 14.2211, MSLE: 0.2580, RMSLE: 0.5079, R2: -0.0456
# RandomForestRegressor
# MSE: 144.7119, RMSE: 12.0296, MSLE: 0.1714, RMSLE: 0.4140, R2: 0.2518
# GradientBoostingRegressor
# MSE: 115.3555, RMSE: 10.7404, MSLE: 0.1430, RMSLE: 0.3782, R2: 0.4036
# XGBRegressor
# MSE: 133.8165, RMSE: 11.5679, MSLE: 0.1563, RMSLE: 0.3953, R2: 0.3082
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 193
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 1
# [LightGBM] [Info] Start training from score 32.236667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor
# MSE: 114.6003, RMSE: 10.7052, MSLE: 0.1384, RMSLE: 0.3720, R2: 0.4075

# %% [markdown]
# #### 8th Cycle - 각종 회귀 모델 학습 결과
# - 모든 모델이 이전 사이클에 비해 R2가 크게 감소한 현상을 보임
# - 여전히 LightGBM 모델이 가장 높은 R2를 기록함

# %% [markdown]
# ### OLS 평가

# %%
from statsmodels.api import OLS

# 현재 데이터의 OLS 평가
model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Strength   R-squared (uncentered):                   0.896
# Model:                            OLS   Adj. R-squared (uncentered):              0.896
# Method:                 Least Squares   F-statistic:                              6187.
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        17:39:56   Log-Likelihood:                         -2771.2
# No. Observations:                 720   AIC:                                      5544.
# Df Residuals:                     719   BIC:                                      5549.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# FE             0.0825      0.001     78.661      0.000       0.080       0.085
# ==============================================================================
# Omnibus:                        4.541   Durbin-Watson:                   0.855
# Prob(Omnibus):                  0.103   Jarque-Bera (JB):                4.431
# Skew:                           0.157   Prob(JB):                        0.109
# Kurtosis:                       2.778   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 9th Cycle - OLS 출력 결과
# - 이전 사이클에 비해 R2가 감소함

# %% [markdown]
# #### 최종 정리
# - Cement, Blast Furnace SLag, Superplasticizer, Age의 4개 feature를 가진 데이터 세트를 사용했을 때
#   가장 신뢰할 수 있으면서도, 전반적으로 0.7 이상의 높은 R2 Score를 기록하는 모델들을 얻을 수 있었다.
# - 그 중에서도 XGB 회귀 모델의 경우, R2 Score 0.91로 매우 우수한 결과를 보여주었다.
# <br/><br/>
# - 위 데이터 세트에 피쳐 엔지니어링을 적용, 새롭게 얻은 feature 하나로 단변량 회귀 테스트를 해보았지만,
#   R2 Score가 큰 폭으로 하락했다.
# - 이에 따라 위 데이터 세트는 피쳐 엔지니어링을 하기에 적합하지 않다는 것을 알 수 있었다.
